# %%
import sys
# print(sys.executable)

# %%
import eurostat
from neo4j import GraphDatabase, basic_auth
import neo4j
import pandas as pd
import numpy as np
import time
import os
from dotenv import load_dotenv
from pathlib import Path
from functions import preprocessing_eurostat_data,import_sm_obs
from PyPDF2 import PdfReader
import re

# %%
#load the environment variables
dotenv_path = Path('~/.env')
load_dotenv(dotenv_path=dotenv_path)  # This line brings all environment variables from .env into os.environ

# Get variables
SUSTAINGRAPH_URI = os.getenv('SUSTAINGRAPH_URI')
SUSTAINGRAPH_USER = os.getenv('SUSTAINGRAPH_USER')
SUSTAINGRAPH_PASSWORD = os.getenv('SUSTAINGRAPH_PASSWORD')
database_name = os.getenv('DATABASE_NAME')

# Connect to database
driver = GraphDatabase.driver(SUSTAINGRAPH_URI, auth=(SUSTAINGRAPH_USER, SUSTAINGRAPH_PASSWORD))

# Verify connectivity
with driver.session(database=database_name) as session:
    print(session.run("RETURN 'Connected to ' + $db", db=database_name).single()[0])
# Out:
# Connected to neo4j

# %%
# Add the year
year='2025'

df_eu = pd.read_excel('Data/3.EU_SDGs/3.EU_Indicator_MPI_PolicyTarget.xlsx', sheet_name='eu_sdg')
df_pt = pd.read_excel('Data/3.EU_SDGs/3.EU_Indicator_MPI_PolicyTarget.xlsx',sheet_name ='policy_target')
df_eu_un = pd.read_excel('Data/3.EU_SDGs/3.EU_Indicator_MPI_PolicyTarget.xlsx',sheet_name ='eu_un')
df_mpi = pd.read_excel('Data/3.EU_SDGs/3.EU_Indicator_MPI_PolicyTarget.xlsx',sheet_name ='mpi')


# Get all the codes in the Eurostat database
toc_df = eurostat.get_toc_df()
toc_df = toc_df.map(lambda x: str(x).lower())

# %%
def write_eu_indicators(tx,statement, params_dict):
    tx.run(statement, parameters=params_dict)

def write_batch(tx,statement, params_list):
    tx.run(statement, parameters={"parameters": params_list})

# %% [markdown]
# [Eurostat](https://ec.europa.eu/eurostat/web/sdi) is called to regularly monitor progress towards the SDGs in an EU context. For this purpose it coordinated the development of the EU SDG indicator set and keeps it up to date. It also produces regular monitoring reports on progress towards the SDGs in an EU context.

# %% [markdown]
# > Create EU_SDG Source node
#
# Before importing the Eurostat data, the Source node with property name: "EU_SDG" is created and all the European SDG indicators will be connected with this node through the relationship 'COMES_FROM'.

# %%
records, summary, keys = driver.execute_query("""\
        MERGE (s:Source{name:'EU_SDG'})
        RETURN count(s) as Source_Data
        """,
        database_=database_name)
print("Created {nodes_created} nodes in {time} ms.".format(
    nodes_created=summary.counters.nodes_created,
    time=summary.result_available_after
))
# Out:
# Created 1 nodes in 17 ms.

# %% [markdown]
# ### Import EU_SDG indicators, series, policy targets, association with UN_SDG indicators
#
# At first, we create the EU_SDG Indicators with their respective series, policy targets and the association with the UN indicators. Then, we create the indicators coming from the European Union regarding the SDGs. There are EU_SDG indicators which are part of EU_SDG indicators.
# For this reason, we create the relationship (Indicator)-[:ASSOCIATED_WITH {relevance:'part of',dateOfReport:date($report_date)}]->(Indicator).Regarding the Series nodes, each EU_SDG Indicator has the one Series node with relavant properties with the Indicator node, in aligment with the schema of the SustainGraph.

# %% [markdown]
# Details regarding EU SDG Indicators, Policy Targets, Multi-Purpose Indicators (MPIs) and the association between EU and UN goals can be found in the '3.EU_Indicator_MPI_PolicyTarget' excel file.
#
# Explanatory comments regarding the file:
# - *summary sheet*: explanatory comments
# - *policy target sheet*:
#     -  EU_ind: EU SDG Indicator code
#     -  Value: absolute value to which the policy target refers
#     -  Unit: unit of measurement to which the value refers (percent, million)
#     -  Operator: comparative/arithmetic operator to which the policy target refers (greater than or equal to, less than or equal to, reduce by)
#     -  Year: goal year to which the policy target refers
#     -  Reference: publication to which the policy target refers
#     -  Comments: relevant comments as published in the Eurostat database
# - *mpi sheet*:
#     -  eu_sdg: EU SDG Indicator code
#     -  goal_code: Goal to which the EU SDG Indicator code is a multi-purpose indicator
#     -  DateOfReport: date of the latest report
#     -  Comments: relevant comments (detailed explanation found in *summary* sheet)
# - *eu_un sheet*:
#     -  eu_sdg: EU SDG Indicator code
#     -  un_sdg: corresponding UN SDG Indicator code
#     -  association: type of association between the two indicator codes (identical to, similar to, part of, not available)
# - *eu_sdg sheet*:
#     -  Goal: EU SDG Goal
#     -  Indicator_Code: EU SDG Indicator code corresponding to each Goal
#     -  Part_of: whether the EU SDG Indicator is part of another EU SDG Indicator (relevance:'part of' in the ASSOCIATED_WITH) relationship
#     -  DateOfReport: date of the latest report
#     -  Comments: relevant comments (detailed explanation found in *summary* sheet)
#
#
# The final graph schema is provided below:
# ![Alt text](wiki/SustainGraph-Indicators.png)

# %%
# Merge the two dataframes 
df = pd.merge(df_eu,toc_df, how='left', left_on='Indicator_Code', right_on='code')
print("Number of EU SDG Indicators to be imported:", len(df))
# Out:
# Number of EU SDG Indicators to be imported: 109

# %%
parent_statement= """
    MATCH(pi:Indicator{code:$parent_ind}), (i:Indicator{code:$ind})
    MERGE (i)-[:ASSOCIATED_WITH{relevance:'part of',dateOfReport:date($report_date)}]->(pi)
"""
statement_eu_ind = """
    MATCH (g:Goal{code:$goal}),(so:Source{name:'EU_SDG'})
    MERGE (i:Indicator{code:$ind,description:$desc})
    MERGE (s:Series{code:$ind,description:$desc,
                    dataProviderURL:"https://ec.europa.eu/eurostat/web/sdi/database"})
    MERGE (g)-[:HAS_INDICATOR]->(i)
    MERGE (i)-[:HAS_SERIES]->(s)
    MERGE (i)-[:COMES_FROM]->(so)    
    RETURN *
"""

i = 0
with driver.session(database=database_name) as session:
    for index,row in df.iterrows(): 
        session.execute_write(write_eu_indicators, 
                            params_dict = {
                                'goal': str(row.Goal), 
                                'desc': str(row.title),
                                'ind': str(row.Indicator_Code),
                                'parent_ind': row.Part_of
                            },
                            statement = statement_eu_ind)  
        if (pd.notna(row.Part_of)):
            i +=1
            session.execute_write(write_eu_indicators, 
                            params_dict = { 
                                'ind': str(row.Indicator_Code),
                                'parent_ind': row.Part_of,
                                'report_date':str(row['DateOfReport'])
                                },
                            statement = parent_statement)
expected = df_eu['Part_of'].notna().sum()
print('{} EU Indicators imported as part of the EU Indicators,'.format(i), 'expected:', expected)
# Out:
# 7 EU Indicators imported as part of the EU Indicators, expected: 7

# %% [markdown]
# ### Policy Targets
# The Policy Targets are collected from the annual "EU SDG Indicator set" report  by Eurostat. Policy targets from earlier years are maintained in the SustainGraph, unless there are confilcts or refer to outdated indicators
#
# ### MPI Indicators
# According to the EU Indicator Set, provided by the European Union each year, a set of indicators 33 of the 101 indicators are multipurpose, meaning they are used to monitor more than one SDG.
#
# ### Association with UN
# The EU SDG indicator set is aligned where appropriate with the UN list of global indicators.

# %% [markdown]
# #### Constraints
#
# > Property types

# %%
def create_constraint(tx,statement):
    tx.run(statement)

# %%
statement_pt_value = """ 
CREATE CONSTRAINT pt_value IF NOT EXISTS
FOR (pt:EUPolicyTarget) REQUIRE pt.value :: FLOAT
"""

statement_pt_unit = """ 
CREATE CONSTRAINT pt_unit IF NOT EXISTS
FOR (pt:EUPolicyTarget) REQUIRE pt.unit :: STRING
"""

statement_pt_operator = """ 
CREATE CONSTRAINT pt_operator IF NOT EXISTS
FOR (pt:EUPolicyTarget) REQUIRE pt.operator :: STRING
"""

statement_pt_year = """ 
CREATE CONSTRAINT pt_year IF NOT EXISTS
FOR (pt:EUPolicyTarget) REQUIRE pt.byYear :: INTEGER
"""

statement_pt_ref = """ 
CREATE CONSTRAINT pt_ref IF NOT EXISTS
FOR (pt:EUPolicyTarget) REQUIRE pt.reference :: STRING
"""

statement_pt_comment = """ 
CREATE CONSTRAINT pt_comment IF NOT EXISTS
FOR (pt:EUPolicyTarget) REQUIRE pt.comment :: STRING
"""

statement_pt_date = """ 
CREATE CONSTRAINT pt_date IF NOT EXISTS
FOR (pt:EUPolicyTarget) REQUIRE pt.dateOfReport :: DATE
"""

statement_mpi="""
CREATE CONSTRAINT is_mpi IF NOT EXISTS
FOR ()-[mpi:IS_MPI_TO]-() REQUIRE mpi.date IS TYPED DATE
"""

# %%
statements = [statement_pt_comment,statement_pt_date,statement_pt_operator,statement_pt_unit,statement_pt_ref,
              statement_pt_unit,statement_pt_value,statement_pt_year,statement_mpi]

with driver.session(database=database_name) as session:
    for statement in statements:
        session.execute_write(create_constraint, statement)

# %% [markdown]
# #### Import the data

# %%
## Policy Targets
statement_eu_policy_target = """
        MATCH (i:Indicator{code:$ind_code})
        MERGE (i)-[:HAS_POLICY_TARGET]->(pt:EUPolicyTarget{value:$val,unit:$un,operator:$oper,byYear:$year,
        reference:$ref,comment:$comm,dateOfReport:date($report_date)})
    """ 

## MPIs
statement_mpi = """ 
            MATCH (g:Goal{code:$goal_code})
            MATCH (i:Indicator{code:$ind_code})
            MERGE (i)-[:IS_MPI_TO{dateOfReport:date($report_date)}]->(g)
        """ 

## UN SDG Indicators
statement_eu_un = """ 
            MATCH (i1:Indicator{code:$eu_code})
            MATCH (i2:Indicator{code:$un_code})
            MERGE (i1)-[:ASSOCIATED_WITH{relevance:$association,dateOfReport:date($report_date)}]->(i2)
        """ 

with driver.session(database=database_name) as session:
    # EU_PolicyTargets
    for index, row in df_pt.iterrows():
        session.execute_write(write_eu_indicators, 
                                params_dict = {
                                    'ind_code':str(row['EU_ind']),
                                    'val':float(row['Value']),
                                    'un':str(row['Unit']),
                                    'oper':str(row['Operator']),
                                    'year':int(row['Year']),
                                    'ref':str(row['Reference']),
                                    'comm':str(row['Comments']),
                                    'report_date':str(row['DateOfReport'])},
                                statement = statement_eu_policy_target)  
    ## MPI
    for index, row in df_mpi.iterrows():
        session.execute_write(write_eu_indicators, 
                                params_dict = {
                                    'ind_code':str(row['eu_sdg']),
                                    'goal_code':str(row['goal_code']),
                                    'report_date':str(row['DateOfReport'])},
                                statement = statement_mpi)  
    ## UN-EU Association
    for index, row in df_eu_un.iterrows():
        session.execute_write(write_eu_indicators, 
                                params_dict = {
                                    'eu_code':str(row['eu_sdg']),
                                    'un_code':str(row['un_sdg']),
                                    'association':str(row['association']),
                                    'report_date':str(row['DateOfReport'])},
                                statement = statement_eu_un)

# %%
# specifically for sdg_04_40 which is connected to a policy target
# create new dimension code SCI_EF461_READ|A|T_A to average across the other three dimensions, for better aggregated visualisation
merge_query = """
    MATCH (i:Indicator {code: $indicator_code})--(s:Series)
    MERGE (newSm:SeriesMetadata {
        attributesCode: "PC",
        dimensionsCode: "SCI_EF461_READ|A|T_A",
        attributesDescription: "Percentage",
        dimensionsDescription: "Science_Math_Reading|Annual|Total_Average",
        seriesCode: $indicator_code
    })
    MERGE (s)-[:HAS_METADATA]->(newSm)
    WITH newSm, s, i
    MATCH (s)-[:HAS_METADATA]->(sm:SeriesMetadata)
    WHERE sm.dimensionsCode IN ["SCI|A|T", "EF461|A|T", "READ|A|T"]
    MATCH (sm)-[r:HAS_OBSERVATION]->(o:Observation)-[:REFERS_TO_AREA]->(ga:GeoArea)
    
    WITH DISTINCT newSm, i, o.time as time, ga, r.geoCode as geoCode, s
    
    // average for specific geo-time combination for each observation
    MATCH (s)-[:HAS_METADATA]->(sm2:SeriesMetadata)
    WHERE sm2.dimensionsCode IN ["SCI|A|T", "EF461|A|T", "READ|A|T"]
    MATCH (sm2)-[r2:HAS_OBSERVATION {time: time, geoCode: geoCode}]->(o2:Observation)
    
    WITH newSm, i, time, ga, geoCode, avg(o2.value) as avgValue
    MERGE (newObs:Observation {time: time)
    SET newObs.value = avgValue
    
    MERGE (newSm)-[:HAS_OBSERVATION {
        attributesCode: "PC",
        dimensionsCode: "SCI_EF461_READ|A|T_A",
        seriesCode: $indicator_code,
        time: time,
        geoCode: geoCode
    }]->(newObs)
    MERGE (newObs)-[:REFERS_TO_AREA]->(ga)
    MERGE (i)-[:HAS_OBSERVATIONS]->(ga)
    
    RETURN count(DISTINCT newObs) as mergedObservations
    """
    
with driver.session(database=database_name) as session:
        result = session.run(merge_query, indicator_code="sdg_04_40")
        record = result.single()
        merged_count = record["mergedObservations"]

# %% [markdown]
# > Check cypher query

# %%
records, summary, keys = driver.execute_query("""\
       MATCH (i:Indicator)-[r:COMES_FROM]->(s{name:'EU_SDG'}) WHERE i.code CONTAINS "sdg" RETURN count(i) as i
        """,routing_="r", database_=database_name)
print("{nodes_created} EU Indicators (expected {number} as of Report 2025) in {time} ms.".format(
    nodes_created=records[0]['i'],
    number=len(df),
    time=summary.result_available_after
))

records, summary, keys = driver.execute_query("""\
       MATCH (src:Source{name:'EU_SDG'})-[:COMES_FROM]-(eu_i:Indicator)-[a:ASSOCIATED_WITH]-(un_i:Indicator)-[:COMES_FROM]-(src1:Source{name:'UN_SDG'}) 
        return count(distinct eu_i.code) as i
        """,routing_="r",database_=database_name)
print("{nodes_created} EU Indicators associated with UN indicators (expected {number} as of Report 2025) in {time} ms.".format(  
    nodes_created=records[0]['i'],
    number=df_eu_un['eu_sdg'].nunique(),
    time=summary.result_available_after
))

records, summary, keys = driver.execute_query("""\
       MATCH(i:Indicator)-[m:IS_MPI_TO]-(g:Goal) return count(m) as i
        """,routing_="r",database_=database_name)
print("{nodes_created} EU MPIs (expected {number} as of Report 2025) in {time} ms.".format(
    nodes_created=records[0]['i'],
    number=len(df_mpi),
    time=summary.result_available_after
))

records = driver.execute_query("""\
       MATCH (g:Goal)--(i:Indicator)-[r:COMES_FROM]->(s{name:'EU_SDG'}) WHERE i.code CONTAINS "sdg" RETURN g.code as goal,count(i) as indicators
        """,routing_="r",database_=database_name,
    result_transformer_=neo4j.Result.to_df)
print("\nTotal Indicators per goal:")
print("{records}".format(
    records=records,
))

records = driver.execute_query("""\
       MATCH (g:Goal)<-[]-(i:Indicator)-[r:COMES_FROM]->(s{name:'EU_SDG'}) RETURN g.code as goal,count(i) as indicators
        """,routing_="r",database_=database_name,
    result_transformer_=neo4j.Result.to_df)
print("\nTotal MPIs per goal:")
print("{records}".format(
    records=records,
))
# Out:
# 109 EU Indicators (expected 109 as of Report 2025) in 1 ms.
# 64 EU Indicators associated with UN indicators (expected 64 as of Report 2025) in 1 ms.
# 35 EU MPIs (expected 35 as of Report 2025) in 1 ms.
#
# Total Indicators per goal:
#    goal  indicators
# 0     1          11
# 1    10          11
# 2    11           9
# 3    12           8
# 4    13           8
# 5    14           6
# 6    15           9
# 7    16           6
# 8    17           6
# 9     2           9
# 10    3          11
# 11    4           7
# 12    5           8
# 13    6           8
# 14    7           7
# 15    8          11
# 16    9           9
#
# Total MPIs per goal:
#    goal  indicators
# 0     1           3
# 1    10           5
# 2    11           3
# 3    12           2
# 4    13           1
# 5    15           3
# 6     2           3
# 7     3           5
# 8     5           2
# 9     6           2
# 10    8           3
# 11    9           3

# %%
# check for sdg_04_40's extra dimension code specifically
records = driver.execute_query("""\
    MATCH (s:Series)-[:HAS_METADATA]->(sm:SeriesMetadata)
    WHERE sm.dimensionsCode IN ["SCI|A|T", "EF461|A|T", "READ|A|T"] AND sm.seriesCode = 'sdg_04_40' //counts the number of unique time-geoCode combinations
    MATCH (sm)-[r:HAS_OBSERVATION]->(o:Observation)
    WITH DISTINCT r.time as time, r.geoCode as geoCode
    WITH count(*) as expectedCount
    
    MATCH (newSm:SeriesMetadata {dimensionsCode: "SCI_EF461_READ|A|T_A", seriesCode: "sdg_04_40"})
    MATCH (newSm)-[r:HAS_OBSERVATION]->(o:Observation)
    
    RETURN expectedCount, count(o) as actualCount
    """, routing_="r", database_=database_name,
    result_transformer_=neo4j.Result.to_df
)
expected = records['expectedCount'].iloc[0]
actual = records['actualCount'].iloc[0]

print(f"Created {actual} nodes, expected {expected}")
# Out:
# Created 250 nodes, expected 250

# %% [markdown]
# ### Import data from Eurostat Library
#
# After that, by using the **preprocessing_eurostat_data** function we read the datasets regarding the EU_SDG indicators and preprocess them in order to get the desired output dataframe, which will be used as input by the function **import_sm_obs** that imports the data in the SustainGraph.
#
# The **preprocessing_eurostat_data** function:
# - Drops NA values
# - Create new columns about the dimensions and the attributes of each un sdg indicator

# %% [markdown]
# ### Import National data

# %%
records, summary, keys = driver.execute_query("""\
        MATCH (r:Region{name:'Europe'})-[:HAS_SUBREGION]->(sr:SubRegion)-[:HAS_AREA]->(a:Area)
        MATCH (eu:EuropeanUnion)<-[:BELONGS_TO]-(eua:Area)
        WITH COLLECT(DISTINCT a.EUcode)+COLLECT(DISTINCT eua.EUcode) as geocodes
        UNWIND geocodes as codes
        RETURN COLLECT(DISTINCT codes) as geo
        """,routing_="r",database_=database_name)
available_areas = list(map(str,records[0]['geo']))

# %%
codes = ['sdg_08_10','sdg_13_40','sdg_07_40','sdg_06_60','sdg_14_60','sdg_15_20','sdg_14_10']

# %%
df_vi = df[df.Indicator_Code.isin(codes)].reset_index()

# %%
batch = 5000
isNUTS = False

# get the start time
st1 = time.time()

total_number_of_observations = 0
observations_per_indicator = {} 
series_metadata_expected = []

for index,row in df_vi.iterrows():   
    # preprocess eusgd indicators data
    df_eucode = preprocessing_eurostat_data(row.code,available_geoCodes = available_areas,is_local_level=isNUTS,filtering_params=None)

    if df_eucode is not None: 

        obs_count = len(df_eucode)
        total_number_of_observations += obs_count 
        observations_per_indicator[row.code] = obs_count 

        for _, r in df_eucode.iterrows():  
            series_metadata_expected.append({
                'indicator': row.code,
                'dim_code': r['dim_codes'],
                'att_code': r['att_codes']
            })
        
        st = time.time()

        print()
        # import data in the SustainGraph
        import_sm_obs(df_eucode,row.code,batch_size=batch,driver=driver,geoEUcode=True)

        # get the end time
        et = time.time()

        # get the execution time
        elapsed_time = et - st
        print('Time:', elapsed_time/60, 'minutes')
    
    if df_eucode is None:
        observations_per_indicator[row.code] = 0
        
# get the end time
et1 = time.time()

# get the execution time
elapsed_time_total = et1 - st1
print('Total execution time:', elapsed_time_total/60, 'minutes')
# Out:
# Indicator code:  sdg_06_60
#
# Length of df before removing NA values: 888
# Length of df after removing NA values: 887
# Length of df after selecting only areas existing in neo4j SustainGraph: 816
#
# Columns of df: ['unit', 'geo', 'freq', 'time', 'value']
# Dimension columns: ['freq']
#
# Attribute columns: unit
#
# ----------------------------------------------------------
#
# 816 observations: Done! (0.003565263748168945 minutes)
# Time: 0.004731237888336182 minutes
#
# Indicator code:  sdg_07_40
#
# Length of df before removing NA values: 3276
# Length of df after removing NA values: 3084
# Length of df after selecting only areas existing in neo4j SustainGraph: 2892
#
# Columns of df: ['unit', 'geo', 'nrg_bal', 'freq', 'time', 'value']
# Dimension columns: ['freq', 'nrg_bal']
#
# Attribute columns: unit
#
# ----------------------------------------------------------
#
# 2892 observations: Done! (0.008904147148132324 minutes)
# Time: 0.012747430801391601 minutes
#
# Indicator code:  sdg_08_10
#
# Length of df before removing NA values: 1925
# Length of df after removing NA values: 1898
# Length of df after selecting only areas existing in neo4j SustainGraph: 1698
#
# Columns of df: ['unit', 'na_item', 'geo', 'freq', 'time', 'value']
# Dimension columns: ['freq', 'na_item']
#
# Attribute columns: unit
#
# ----------------------------------------------------------
#
# 1698 observations: Done! (0.007029195626576741 minutes)
# Time: 0.014759365717569988 minutes
#
# Indicator code:  sdg_13_40
#
# Length of df before removing NA values: 7020
# Length of df after removing NA values: 4721
# Length of df after selecting only areas existing in neo4j SustainGraph: 4360
#
# Columns of df: ['statinfo', 'unit', 'freq', 'geo', 'stk_flow', 'time', 'value']
# Dimension columns: ['freq', 'statinfo', 'stk_flow']
#
# Attribute columns: unit
#
# ----------------------------------------------------------
#
# 4360 observations: Done! (0.01555338700612386 minutes)
# Time: 0.025073150793711346 minutes
#
# Indicator code:  sdg_14_10
#
# Length of df before removing NA values: 336
# Length of df after removing NA values: 276
# Length of df after selecting only areas existing in neo4j SustainGraph: 264
#
# Columns of df: ['geo', 'freq', 'unit', 'areaprot', 'time', 'value']
# Dimension columns: ['areaprot', 'freq']
#
# Attribute columns: unit
#
# ----------------------------------------------------------
#
# 264 observations: Done! (0.00166168212890625 minutes)
# Time: 0.003343820571899414 minutes
#
# Indicator code:  sdg_14_60
#
# Length of df before removing NA values: 1550
# Length of df after removing NA values: 1300
# Length of df after selecting only areas existing in neo4j SustainGraph: 1250
#
# Columns of df: ['unit', 'geo', 'indic_env', 'freq', 'time', 'value']
# Dimension columns: ['freq', 'indic_env']
#
# Attribute columns: unit
#
# ----------------------------------------------------------
#
# 1250 observations: Done! (0.0033692240715026854 minutes)
# Time: 0.005119971434275309 minutes
#
# Indicator code:  sdg_15_20
#
# Length of df before removing NA values: 728
# Length of df after removing NA values: 728
# Length of df after selecting only areas existing in neo4j SustainGraph: 702
#
# Columns of df: ['geo', 'freq', 'unit', 'areaprot', 'time', 'value']
# Dimension columns: ['areaprot', 'freq']
#
# Attribute columns: unit
#
# ----------------------------------------------------------
#
# 702 observations: Done! (0.0035199562708536783 minutes)
# Time: 0.005861024061838786 minutes
# Total execution time: 0.868543024857839 minutes

# %%
records = driver.execute_query("""\
       MATCH (so:Source{name:'EU_SDG'})<-[:COMES_FROM]-(i:Indicator)--(s:Series)--(sm:SeriesMetadata)--(o:Observation)--(ga:Area)
       RETURN s.code as indicator, COUNT(DISTINCT o) as observations
       order by indicator
        """,routing_="r",database_=database_name,
    result_transformer_=neo4j.Result.to_df)
records

set_eu = set(df_eu['Indicator_Code'])
set_graph = set(records['indicator'])
exempt_from_graph = set_eu - set_graph 

print("EU SDG Indicators by Eurostat:", len(df_eu))
print("EU SDG Indicators with series information in the graph:", len(records))
print("EU SDG Indicators with no series information in the graph:", len(exempt_from_graph), ", listed:")
for i in exempt_from_graph:
    print(i)
# Out:
# EU SDG Indicators by Eurostat: 109
# EU SDG Indicators with series information in the graph: 101
# EU SDG Indicators with no series information in the graph: 8 , listed:
# sdg_14_51
# sdg_13_70
# sdg_12_10
# sdg_10_20
# sdg_14_30
# sdg_15_60
# sdg_14_21
# sdg_15_61

# %% [markdown]
# > Check cypher query

# %% [markdown]
# Checking for EU SDG Indicator observations that weren't imported properly to the graph ('mismatches' between graph and Eurostat database)

# %%
# checking for data that weren't imported correctly to the graph for each EU SDG Indicator per series metadata from Eurostat database, labeled 'mismatches'
check_statement = """ 
UNWIND $parameters AS row
MATCH (so:Source{name:'EU_SDG'})<-[:COMES_FROM]-(i:Indicator {code: row.code})
      --(s:Series)--(sm:SeriesMetadata)--(o:Observation)
WHERE i.code CONTAINS "sdg"
RETURN i.code AS indicator, 
       s.code AS series_code,
       sm.dimensionsCode AS dim_code, 
       sm.attributesCode AS att_code, 
       count(distinct o) AS imported
"""

check_results = []

for indicator in df['code'].unique():
    records, summary, keys = driver.execute_query(
        check_statement,
        parameters={"code": indicator},
        database_=database_name,
        routing_="r"
    )
    for r in records: 
        check_results.append({
            "indicator": r["indicator"],
            "series": r["series_code"],
            "dim_code": r["dim_code"],
            "att_code": r["att_code"],
            "series metadata": f"{r['dim_code']}|{r['att_code']}",
            "imported": r["imported"]
        })

expected_df = pd.DataFrame(series_metadata_expected)
expected_grouped = expected_df.groupby( #group expected counts per (indicator), (dim_code, att_code)->series metadata
    ['indicator', 'dim_code', 'att_code']
).size().reset_index(name='to_import')

actual_df = pd.DataFrame(check_results)
actual_df['series metadata'] = actual_df['dim_code'] + "|" + actual_df['att_code']

# merge dataframes
check_final_df = pd.merge(
    expected_grouped,
    actual_df,
    on=['indicator', 'dim_code', 'att_code'],
    how='outer'
).fillna(0)
check_final_df = check_final_df[
    ["indicator", "series", "dim_code", "att_code", "series metadata", "to_import", "imported"]
]

# %%
records = driver.execute_query("""\
    MATCH (so:Source{name:'EU_SDG'})<-[:COMES_FROM]-(i:Indicator)--(s:Series)--(sm:SeriesMetadata)--(o:Observation)--(ga:Area)
    WHERE i.code CONTAINS "sdg"
    RETURN count(distinct o) as observations
        """,routing_="r",database_=database_name,
    result_transformer_=neo4j.Result.to_df)
print('{} observations imported in total to SustainGraph,'.format(records['observations'][0]), "expected:", total_number_of_observations)
# Out:
# 143932 observations imported in total to SustainGraph, expected: 143932

# %%
mismatches = check_final_df[check_final_df['to_import'] != check_final_df['imported']]
if len(mismatches)==0:
    print("Mismatches: 0")
else:
    print("\nMismatches:\n", mismatches)
# Out:
# Mismatches: 0

# %%
check_final_df
# Out:
#       indicator      series         dim_code        att_code  \
# 0     sdg_01_10   sdg_01_10          TOTAL|A              PC
# 1     sdg_01_10   sdg_01_10          TOTAL|A         THS_PER
# 2     sdg_01_10   sdg_01_10         Y_LT18|A              PC
# 3     sdg_01_10   sdg_01_10         Y_LT18|A         THS_PER
# 4    sdg_01_10a  sdg_01_10a           DEG1|A              PC
# ..          ...         ...              ...             ...
# 265   sdg_17_40   sdg_17_40         A|GD|S13         MIO_EUR
# 266   sdg_17_40   sdg_17_40         A|GD|S13          PC_GDP
# 267   sdg_17_50   sdg_17_50            A|ENV  PC_TSCO_X_ISCO
# 268   sdg_17_60   sdg_17_60   A|VHCN_FX|DEG3           PC_HH
# 269   sdg_17_60   sdg_17_60  A|VHCN_FX|TOTAL           PC_HH
#
#            series metadata  to_import  imported
# 0               TOTAL|A|PC        320       320
# 1          TOTAL|A|THS_PER        320       320
# 2              Y_LT18|A|PC        320       320
# 3         Y_LT18|A|THS_PER        320       320
# 4                DEG1|A|PC        322       322
# ..                     ...        ...       ...
# 265       A|GD|S13|MIO_EUR        675       675
# 266        A|GD|S13|PC_GDP        675       675
# 267   A|ENV|PC_TSCO_X_ISCO        712       712
# 268   A|VHCN_FX|DEG3|PC_HH        186       186
# 269  A|VHCN_FX|TOTAL|PC_HH        186       186
#
# [270 rows x 7 columns]

# %% [markdown]
# ### NUTS data

# %% [markdown]
# #### Retrieve NUTS data

# %%
records, summary, keys = driver.execute_query("""\
        MATCH (r:Region{name:'Europe'})-[:HAS_SUBREGION]->(sr:SubRegion)-[:HAS_AREA]->(a:Area)
        MATCH (eu:EuropeanUnion)<-[:BELONGS_TO]-(eua:Area)
        WITH COLLECT(DISTINCT a.EUcode)+COLLECT(DISTINCT eua.EUcode) as geocodes
        UNWIND geocodes as codes
        WITH COLLECT(DISTINCT codes) as geo
        MATCH (nuts3:NUTS3)<-[:HAS_NUTS3]-(nuts2:NUTS2)-[:HAS_NUTS2]-(nuts1:NUTS1)-[r:HAS_NUTS1]-(ar:Area)
        where ar.EUcode in geo
        RETURN COLLECT(DISTINCT nuts2.EUcode) + COLLECT(DISTINCT nuts3.EUcode) + COLLECT(DISTINCT nuts1.EUcode) as g
        """,routing_="r",database_=database_name)
available_nuts = list(map(str,records[0]['g']))

# %% [markdown]
# #### Associate NUTS regional dataset Indicator codes to EU SDG Indicator Codes as specified by Eurostat according to the relevant [Information Note](.\Data\3.EU_SDGs\Info-note_sdg_reg_20250206.pdf) .

# %%
# Read NUTS regional dataset Indicator codes, corresponding EU SDG Indicator codes from the Information Note pdf
# Note that the Information Note contains the same information 3 times, in English, German and French
reader = PdfReader("Data/3.EU_SDGs/Info-note_sdg_reg_20250206.pdf")

all_text = "" # initialise empty string to accummulate the text
for page in reader.pages:
    all_text += page.extract_text() # pass the text

# establish pattern to match EU SDG Indicator and NUTS Indicator codes as follows:
# r: raw string, to treat everything as a character
# EU SDG Indicator codes follow the patter of "sdg_xx_xx", x is an integer -> matched by sdg_\d{2}_\d{2})
# .*? matches the description in between, not needed for our dictionary
# NUTS Indicator codes are lowercase strings in the same line as EU SDG Indicator codes -> matched by [a-z]{2,}_[a-z0-9_]+: 2 or more lowercase letters, underscore, 1 or more lowercase letters, digits, or underscores
pattern = r"(sdg_\d{2}_\d{2}).*?\b([a-z]{2,}_[a-z0-9_]+)" 
matches = re.findall(pattern, all_text, re.DOTALL) # find matches, re.DOTALL to match newline characters too

codes_nuts_dict={dataset:indicator for indicator, dataset in matches} # create dictionary mapping

# %%
# Get description form toc_df for NUTS regional dataset Indicators
nuts_codes = []
corresponding_sdgs = []

for nuts_code, sdg_code in codes_nuts_dict.items():
    nuts_codes.append(nuts_code)
    corresponding_sdgs.append(sdg_code)

nuts_df = toc_df[toc_df['code'].isin(nuts_codes)][['code', 'title']] # NUTS Indicator codes from toc_df
nuts_to_sdg_mapping = dict(zip(nuts_codes, corresponding_sdgs))
nuts_df['sdg_code'] = nuts_df['code'].map(nuts_to_sdg_mapping)

first_dateofreport = df_eu['DateOfReport'].iloc[0] 
nuts_df['DateOfReport'] = first_dateofreport # add DateOfReport column from annual report
nuts_df
# Out:
#                   code                                              title  \
# 59    lfst_r_lfe2emprt                  employment rates by nuts 2 region
# 77      lfst_r_lfu2ltu  persons in long-term unemployment (12 months o...
# 634    hlth_silc_08b_r  self-reported unmet needs for medical examinat...
# 1161     nama_10r_2gdp  gross domestic product (gdp) at current market...
# 1457     hlth_cd_asdr2  causes of death - standardised death rate by n...
# 3389          ilc_li41           at-risk-of-poverty rate by nuts 2 region
# 3475       ilc_lvhl21n  persons living in households with very low wor...
# 3864        ilc_mdsd18  severe material and social deprivation by nuts...
# 3957       ilc_peps11n  persons at risk of poverty or social exclusion...
# 4196      edat_lfse_04  population in private households by educationa...
# 4205      edat_lfse_16  early leavers from education and training by n...
# 4222      edat_lfse_22  young persons neither in employment nor in edu...
# 4460   educ_uoe_enra22  pupils from age 3 to the starting age of compu...
# 5013       tran_r_acci         victims in road accidents by nuts 2 region
# 5405      trng_lfse_04  participation rate in education and training (...
# 6995     aei_pr_soiler  estimated soil erosion by water, by erosion le...
# 7071      rd_e_gerdreg    gerd by sector of performance and nuts 2 region
# 7105      rd_p_persreg  r&d personnel and researchers by sector of per...
# 7857       tepsr_lm220             gender employment gap by nuts 2 region
#
#        sdg_code DateOfReport
# 59    sdg_08_30   2025-01-10
# 77    sdg_08_40   2025-01-10
# 634   sdg_03_60   2025-01-10
# 1161  sdg_10_10   2025-01-10
# 1457  sdg_16_10   2025-01-10
# 3389  sdg_01_20   2025-01-10
# 3475  sdg_01_40   2025-01-10
# 3864  sdg_01_31   2025-01-10
# 3957  sdg_01_10   2025-01-10
# 4196  sdg_04_20   2025-01-10
# 4205  sdg_04_10   2025-01-10
# 4222  sdg_08_20   2025-01-10
# 4460  sdg_04_31   2025-01-10
# 5013  sdg_11_40   2025-01-10
# 5405  sdg_04_60   2025-01-10
# 6995  sdg_15_50   2025-01-10
# 7071  sdg_09_10   2025-01-10
# 7105  sdg_09_30   2025-01-10
# 7857  sdg_05_30   2025-01-10

# %%
def write_nuts_indicators(tx,statement, params_dict):
    tx.run(statement, parameters=params_dict)

# %%
# Import NUTS regional dataset Indicator codes, add 'corespondant' relationships with EU SDG indicator nodes, add COMES_FROM relationship with the EU_SDG node
parent_statement= """
    MATCH(pi:Indicator{code:$sdg_ind}), (i:Indicator{code:$nuts_ind}), (so:Source{name:'EU_SDG'})
    MERGE (i)-[:ASSOCIATED_WITH{relevance:'correspondant',dateOfReport:date($report_date)}]->(pi)
    MERGE (i)-[:COMES_FROM]->(so)
"""
statement_nuts_ind = """
    MERGE (i:Indicator{code:$nuts_ind,description:$desc})
    MERGE (s:Series{code:$nuts_ind,description:$desc,
                    dataProviderURL:"https://ec.europa.eu/eurostat/web/sdi/database"})
    MERGE (i)-[:HAS_SERIES]->(s)
    RETURN *
"""

i = 0
with driver.session(database=database_name) as session:
    for index,row in nuts_df.iterrows(): 
        session.execute_write(write_nuts_indicators, 
                            params_dict = {
                                'desc': str(row.title),
                                'nuts_ind': str(row.code)
                            },
                            statement = statement_nuts_ind)  
        i +=1
        session.execute_write(write_nuts_indicators, 
                        params_dict = { 
                            'nuts_ind': str(row.code),
                            'sdg_ind': str(row.sdg_code),
                            'report_date':str(row['DateOfReport'])
                            },
                        statement = parent_statement)

# %% [markdown]
# #### Import NUTS regional dataset data

# %%
# Import NUTS Indicator codes metadata
isNUTS = True
batch_size = 10000

number_of_nuts_observations = 0
observations_per_nuts_indicator = {}
series_metadata_expected_nuts = []

# if statement is commented out, needed in case there are NUTS indicators correlated to multiple EU SDG indicators
# filtering_params is commented out, needed in case specific filtering parameters are applied for each NUTS Indicator dataset

st1 = time.time()
for online_code, eu_code in codes_nuts_dict.items():
    # if isinstance(eu_code, list): 
    #     for i, element in enumerate(eu_code):
    #         #filtering_params_i = filter_params[online_code][i] if filter_params[online_code] else None #needed if filtering parameters are applied in NUTS datasets
    #         df_eucode = preprocessing_eurostat_data(online_code, available_geoCodes=available_nuts, is_local_level=isNUTS,
    #                                                       #filtering_params=filtering_params_i)
    #         )
    #         if df_eucode is not None:
    #             number_of_nuts_observations += len(df_eucode)
    #             st = time.time()
    #             import_sm_obs(df_eucode, online_code, batch_size=batch_size, driver=driver)
    #             et = time.time()
    #             elapsed_time = et - st
    #             print(f'Time for {online_code}-{element}: {elapsed_time/60:.2f} minutes')
    # else:
    #     #filtering_params_single = filter_params[online_code] if filter_params[online_code] else None #needed if filtering parameters are applied in NUTS datasets
        df_eucode = preprocessing_eurostat_data(online_code, available_geoCodes=available_nuts, is_local_level=isNUTS,
                                                      #filtering_params=filtering_params_single)
        )
        if df_eucode is not None:
            number_of_nuts_observations += len(df_eucode)
            observations_per_nuts_indicator[online_code] = len(df_eucode)

            for _, r in df_eucode.iterrows():  # check per series metadata, add dimensions dim_cod and att_code
                series_metadata_expected_nuts.append({
                'indicator': online_code,
                'dim_code': r['dim_codes'],
                'att_code': r['att_codes']
                })

            st = time.time()

            import_sm_obs(df_eucode, online_code, batch_size=batch_size, driver=driver)

            et = time.time()
            elapsed_time = et - st
            
            print(f'Time for {online_code}: {elapsed_time/60:.2f} minutes')

et1 = time.time()
elapsed_time_total = et1 - st1
print('Total execution time:', elapsed_time_total / 60, 'minutes')
# Out:
# Indicator code:  ilc_peps11n
#
# Length of df before removing NA values: 3450
# Length of df after removing NA values: 2342
# Length of df after selecting only areas existing in neo4j SustainGraph: 2290
#
# Columns of df: ['unit', 'geo', 'freq', 'time', 'value']
# Dimension columns: ['freq']
#
# Attribute columns: unit
#
# ----------------------------------------------------------
# 2290 observations: Done! (0.0582489291826884 minutes)
# Time for ilc_peps11n: 0.06 minutes
#
# Indicator code:  ilc_li41
#
# Length of df before removing NA values: 7700
# Length of df after removing NA values: 3746
# Length of df after selecting only areas existing in neo4j SustainGraph: 3588
#
# Columns of df: ['unit', 'geo', 'freq', 'time', 'value']
# Dimension columns: ['freq']
#
# Attribute columns: unit
#
# ----------------------------------------------------------
# 3588 observations: Done! (0.051470569769541424 minutes)
# Time for ilc_li41: 0.06 minutes
#
# Indicator code:  ilc_mdsd18
#
# Length of df before removing NA values: 3795
# Length of df after removing NA values: 2213
# Length of df after selecting only areas existing in neo4j SustainGraph: 2164
#
# Columns of df: ['unit', 'geo', 'freq', 'time', 'value']
# Dimension columns: ['freq']
#
# Attribute columns: unit
#
# ----------------------------------------------------------
# 2164 observations: Done! (0.05523241360982259 minutes)
# Time for ilc_mdsd18: 0.06 minutes
#
# Indicator code:  ilc_lvhl21n
#
# Length of df before removing NA values: 3795
# Length of df after removing NA values: 2348
# Length of df after selecting only areas existing in neo4j SustainGraph: 2295
#
# Columns of df: ['unit', 'geo', 'freq', 'time', 'value']
# Dimension columns: ['freq']
#
# Attribute columns: unit
#
# ----------------------------------------------------------
# 2295 observations: Done! (0.017033076286315917 minutes)
# Time for ilc_lvhl21n: 0.02 minutes
#
# Indicator code:  hlth_silc_08b_r
#
# Length of df before removing NA values: 832
# Length of df after removing NA values: 734
# Length of df after selecting only areas existing in neo4j SustainGraph: 729
#
# Columns of df: ['reason', 'unit', 'geo', 'freq', 'time', 'value']
# Dimension columns: ['freq', 'reason']
#
# Attribute columns: unit
#
# ----------------------------------------------------------
# 729 observations: Done! (0.015112984180450439 minutes)
# Time for hlth_silc_08b_r: 0.02 minutes
#
# Indicator code:  edat_lfse_16
#
# Length of df before removing NA values: 38250
# Length of df after removing NA values: 26378
# Length of df after selecting only areas existing in neo4j SustainGraph: 23446
#
# Columns of df: ['sex', 'geo', 'freq', 'age', 'unit', 'time', 'value']
# Dimension columns: ['age', 'freq', 'sex']
#
# Attribute columns: unit
#
# ----------------------------------------------------------
# Batch 1 with 10001 observations : Done! (0.25975154638290404 minutes)
# Batch 2 with 10000 observations : Done! (0.16287816365559896 minutes)
# 3445 observations: Done! (0.030301904678344725 minutes)
# Time for edat_lfse_16: 0.51 minutes
#
# Indicator code:  edat_lfse_04
#
# Length of df before removing NA values: 880650
# Length of df after removing NA values: 566373
# Length of df after selecting only areas existing in neo4j SustainGraph: 507263
#
# Columns of df: ['sex', 'geo', 'isced11', 'freq', 'age', 'unit', 'time', 'value']
# Dimension columns: ['age', 'freq', 'isced11', 'sex']
#
# Attribute columns: unit
#
# ----------------------------------------------------------
# Batch 1 with 10001 observations : Done! (0.0914011557896932 minutes)
# Batch 2 with 10000 observations : Done! (0.07438422441482544 minutes)
# Batch 3 with 10000 observations : Done! (0.07498434782028199 minutes)
# Batch 4 with 10000 observations : Done! (0.07446376085281373 minutes)
# Batch 5 with 10000 observations : Done! (0.07445111672083536 minutes)
# Batch 6 with 10000 observations : Done! (0.07404555877049764 minutes)
# Batch 7 with 10000 observations : Done! (0.07428143819173177 minutes)
# Batch 8 with 10000 observations : Done! (0.0736760417620341 minutes)
# Batch 9 with 10000 observations : Done! (0.07364648977915446 minutes)
# Batch 10 with 10000 observations : Done! (0.07384113470713298 minutes)
# Batch 11 with 10000 observations : Done! (0.07370591958363851 minutes)
# Batch 12 with 10000 observations : Done! (0.07504652341206869 minutes)
# Batch 13 with 10000 observations : Done! (0.07455402612686157 minutes)
# Batch 14 with 10000 observations : Done! (0.07336151997248332 minutes)
# Batch 15 with 10000 observations : Done! (0.07435164451599122 minutes)
# Batch 16 with 10000 observations : Done! (0.07493109703063965 minutes)
# Batch 17 with 10000 observations : Done! (0.07411866188049317 minutes)
# Batch 18 with 10000 observations : Done! (0.07425920963287354 minutes)
# Batch 19 with 10000 observations : Done! (0.07395213842391968 minutes)
# Batch 20 with 10000 observations : Done! (0.0744473934173584 minutes)
# Batch 21 with 10000 observations : Done! (0.07473754088083903 minutes)
# Batch 22 with 10000 observations : Done! (0.0737863024075826 minutes)
# Batch 23 with 10000 observations : Done! (0.07485435009002686 minutes)
# Batch 24 with 10000 observations : Done! (0.07400815486907959 minutes)
# Batch 25 with 10000 observations : Done! (0.0739090085029602 minutes)
# Batch 26 with 10000 observations : Done! (0.07350121339162191 minutes)
# Batch 27 with 10000 observations : Done! (0.07477003733317057 minutes)
# Batch 28 with 10000 observations : Done! (0.07457640171051025 minutes)
# Batch 29 with 10000 observations : Done! (0.1649816632270813 minutes)
# Batch 30 with 10000 observations : Done! (0.16473703384399413 minutes)
# Batch 31 with 10000 observations : Done! (0.1659655451774597 minutes)
# Batch 32 with 10000 observations : Done! (0.1656051794687907 minutes)
# Batch 33 with 10000 observations : Done! (0.16594057083129882 minutes)
# Batch 34 with 10000 observations : Done! (0.16055688858032227 minutes)
# Batch 35 with 10000 observations : Done! (0.07426023880640666 minutes)
# Batch 36 with 10000 observations : Done! (0.07709428071975707 minutes)
# Batch 37 with 10000 observations : Done! (0.0741817553838094 minutes)
# Batch 38 with 10000 observations : Done! (0.07479761838912964 minutes)
# Batch 39 with 10000 observations : Done! (0.07424981594085693 minutes)
# Batch 40 with 10000 observations : Done! (0.07436760266621907 minutes)
# Batch 41 with 10000 observations : Done! (0.07629350026448568 minutes)
# Batch 42 with 10000 observations : Done! (0.07712218364079794 minutes)
# Batch 43 with 10000 observations : Done! (0.07494447628657024 minutes)
# Batch 44 with 10000 observations : Done! (0.07418418327967326 minutes)
# Batch 45 with 10000 observations : Done! (0.07488746643066406 minutes)
# Batch 46 with 10000 observations : Done! (0.07557216087977091 minutes)
# Batch 47 with 10000 observations : Done! (0.07524904012680053 minutes)
# Batch 48 with 10000 observations : Done! (0.07416801850001017 minutes)
# Batch 49 with 10000 observations : Done! (0.07447293599446615 minutes)
# Batch 50 with 10000 observations : Done! (0.07472335497538249 minutes)
# 7262 observations: Done! (0.05412238438924154 minutes)
# Time for edat_lfse_04: 4.90 minutes
#
# Indicator code:  educ_uoe_enra22
#
# Length of df before removing NA values: 4180
# Length of df after removing NA values: 3412
# Length of df after selecting only areas existing in neo4j SustainGraph: 2985
#
# Columns of df: ['unit', 'geo', 'freq', 'time', 'value']
# Dimension columns: ['freq']
#
# Attribute columns: unit
#
# ----------------------------------------------------------
# 2985 observations: Done! (0.044598627090454104 minutes)
# Time for educ_uoe_enra22: 0.05 minutes
#
# Indicator code:  trng_lfse_04
#
# Length of df before removing NA values: 35550
# Length of df after removing NA values: 29882
# Length of df after selecting only areas existing in neo4j SustainGraph: 27033
#
# Columns of df: ['sex', 'geo', 'freq', 'age', 'unit', 'time', 'value']
# Dimension columns: ['age', 'freq', 'sex']
#
# Attribute columns: unit
#
# ----------------------------------------------------------
# Batch 1 with 10001 observations : Done! (0.15321425994237264 minutes)
# Batch 2 with 10000 observations : Done! (0.15283053716023762 minutes)
# 7032 observations: Done! (0.10797866582870483 minutes)
# Time for trng_lfse_04: 0.44 minutes
#
# Indicator code:  tepsr_lm220
#
# Length of df before removing NA values: 7040
# Length of df after removing NA values: 6252
# Length of df after selecting only areas existing in neo4j SustainGraph: 5585
#
# Columns of df: ['unit', 'geo', 'freq', 'time', 'value']
# Dimension columns: ['freq']
#
# Attribute columns: unit
#
# ----------------------------------------------------------
# 5585 observations: Done! (0.0856635332107544 minutes)
# Time for tepsr_lm220: 0.09 minutes
#
# Indicator code:  edat_lfse_22
#
# Length of df before removing NA values: 153000
# Length of df after removing NA values: 114048
# Length of df after selecting only areas existing in neo4j SustainGraph: 101950
#
# Columns of df: ['wstatus', 'sex', 'geo', 'freq', 'age', 'unit', 'training', 'time', 'value']
# Dimension columns: ['age', 'freq', 'sex', 'training', 'wstatus']
#
# Attribute columns: unit
#
# ----------------------------------------------------------
# Batch 1 with 10001 observations : Done! (0.08088967402776083 minutes)
# Batch 2 with 10000 observations : Done! (0.07853408654530843 minutes)
# Batch 3 with 10000 observations : Done! (0.0789558211962382 minutes)
# Batch 4 with 10000 observations : Done! (0.07803800900777182 minutes)
# Batch 5 with 10000 observations : Done! (0.07899978558222452 minutes)
# Batch 6 with 10000 observations : Done! (0.07801373402277628 minutes)
# Batch 7 with 10000 observations : Done! (0.077737824122111 minutes)
# Batch 8 with 10000 observations : Done! (0.07847973505655924 minutes)
# Batch 9 with 10000 observations : Done! (0.0777947465578715 minutes)
# Batch 10 with 10000 observations : Done! (0.07804170449574789 minutes)
# 1949 observations: Done! (0.01612225373586019 minutes)
# Time for edat_lfse_22: 0.91 minutes
#
# Indicator code:  lfst_r_lfe2emprt
#
# Length of df before removing NA values: 444600
# Length of df after removing NA values: 380302
# Length of df after selecting only areas existing in neo4j SustainGraph: 345153
#
# Columns of df: ['sex', 'geo', 'freq', 'age', 'unit', 'time', 'value']
# Dimension columns: ['age', 'freq', 'sex']
#
# Attribute columns: unit
#
# ----------------------------------------------------------
# Batch 1 with 10001 observations : Done! (0.10562535921732584 minutes)
# Batch 2 with 10000 observations : Done! (0.07443162202835082 minutes)
# Batch 3 with 10000 observations : Done! (0.07401284774144491 minutes)
# Batch 4 with 10000 observations : Done! (0.07443021535873413 minutes)
# Batch 5 with 10000 observations : Done! (0.07505090236663818 minutes)
# Batch 6 with 10000 observations : Done! (0.07336989243825277 minutes)
# Batch 7 with 10000 observations : Done! (0.07309937874476115 minutes)
# Batch 8 with 10000 observations : Done! (0.07624303499857585 minutes)
# Batch 9 with 10000 observations : Done! (0.07471887667973837 minutes)
# Batch 10 with 10000 observations : Done! (0.07418973843256632 minutes)
# Batch 11 with 10000 observations : Done! (0.07356324593226114 minutes)
# Batch 12 with 10000 observations : Done! (0.07483107248942057 minutes)
# Batch 13 with 10000 observations : Done! (0.07474934260050456 minutes)
# Batch 14 with 10000 observations : Done! (0.07428364356358846 minutes)
# Batch 15 with 10000 observations : Done! (0.07420584758122763 minutes)
# Batch 16 with 10000 observations : Done! (0.07360555330912272 minutes)
# Batch 17 with 10000 observations : Done! (0.07430442174275716 minutes)
# Batch 18 with 10000 observations : Done! (0.07392588059107462 minutes)
# Batch 19 with 10000 observations : Done! (0.07488028208414714 minutes)
# Batch 20 with 10000 observations : Done! (0.07417652209599813 minutes)
# Batch 21 with 10000 observations : Done! (0.07459757725397746 minutes)
# Batch 22 with 10000 observations : Done! (0.07341165542602539 minutes)
# Batch 23 with 10000 observations : Done! (0.07415527105331421 minutes)
# Batch 24 with 10000 observations : Done! (0.07354119221369425 minutes)
# Batch 25 with 10000 observations : Done! (0.09719644784927368 minutes)
# Batch 26 with 10000 observations : Done! (0.1624753713607788 minutes)
# Batch 27 with 10000 observations : Done! (0.1604565978050232 minutes)
# Batch 28 with 10000 observations : Done! (0.17056629260381062 minutes)
# Batch 29 with 10000 observations : Done! (0.16049720843633017 minutes)
# Batch 30 with 10000 observations : Done! (0.16458967526753743 minutes)
# Batch 31 with 10000 observations : Done! (0.15916013717651367 minutes)
# Batch 32 with 10000 observations : Done! (0.0735618273417155 minutes)
# Batch 33 with 10000 observations : Done! (0.07391771475474039 minutes)
# Batch 34 with 10000 observations : Done! (0.0732409159342448 minutes)
# 5152 observations: Done! (0.03909304936726888 minutes)
# Time for lfst_r_lfe2emprt: 3.51 minutes
#
# Indicator code:  lfst_r_lfu2ltu
#
# Length of df before removing NA values: 3336684
# Length of df after removing NA values: 1448574
# Length of df after selecting only areas existing in neo4j SustainGraph: 1266726
#
# Columns of df: ['sex', 'geo', 'isced11', 'freq', 'age', 'unit', 'time', 'value']
# Dimension columns: ['age', 'freq', 'isced11', 'sex']
#
# Attribute columns: unit
#
# ----------------------------------------------------------
# Batch 1 with 10001 observations : Done! (0.17416938543319702 minutes)
# Batch 2 with 10000 observations : Done! (0.18217074473698933 minutes)
# Batch 3 with 10000 observations : Done! (0.12240251302719116 minutes)
# Batch 4 with 10000 observations : Done! (0.07639680703481039 minutes)
# Batch 5 with 10000 observations : Done! (0.07813014189402262 minutes)
# Batch 6 with 10000 observations : Done! (0.07585676511128743 minutes)
# Batch 7 with 10000 observations : Done! (0.0767246683438619 minutes)
# Batch 8 with 10000 observations : Done! (0.07612429857254029 minutes)
# Batch 9 with 10000 observations : Done! (0.07673497597376505 minutes)
# Batch 10 with 10000 observations : Done! (0.07602887153625489 minutes)
# Batch 11 with 10000 observations : Done! (0.18000983397165934 minutes)
# Batch 12 with 10000 observations : Done! (0.17472720940907796 minutes)
# Batch 13 with 10000 observations : Done! (0.1729464332262675 minutes)
# Batch 14 with 10000 observations : Done! (0.17651434342066447 minutes)
# Batch 15 with 10000 observations : Done! (0.17377229928970336 minutes)
# Batch 16 with 10000 observations : Done! (0.13125678300857543 minutes)
# Batch 17 with 10000 observations : Done! (0.07634373505910237 minutes)
# Batch 18 with 10000 observations : Done! (0.07679460843404134 minutes)
# Batch 19 with 10000 observations : Done! (0.0772718071937561 minutes)
# Batch 20 with 10000 observations : Done! (0.07557421525319417 minutes)
# Batch 21 with 10000 observations : Done! (0.07742568254470825 minutes)
# Batch 22 with 10000 observations : Done! (0.07615329424540201 minutes)
# Batch 23 with 10000 observations : Done! (0.07680352528889973 minutes)
# Batch 24 with 10000 observations : Done! (0.07644703388214111 minutes)
# Batch 25 with 10000 observations : Done! (0.07765418688456217 minutes)
# Batch 26 with 10000 observations : Done! (0.07525951464970906 minutes)
# Batch 27 with 10000 observations : Done! (0.0767147978146871 minutes)
# Batch 28 with 10000 observations : Done! (0.07642235358556111 minutes)
# Batch 29 with 10000 observations : Done! (0.07686954339345296 minutes)
# Batch 30 with 10000 observations : Done! (0.07714643478393554 minutes)
# Batch 31 with 10000 observations : Done! (0.07642205158869425 minutes)
# Batch 32 with 10000 observations : Done! (0.0767768661181132 minutes)
# Batch 33 with 10000 observations : Done! (0.07615753809611002 minutes)
# Batch 34 with 10000 observations : Done! (0.07612183094024658 minutes)
# Batch 35 with 10000 observations : Done! (0.08043010234832763 minutes)
# Batch 36 with 10000 observations : Done! (0.08109583457310994 minutes)
# Batch 37 with 10000 observations : Done! (0.07951374848683675 minutes)
# Batch 38 with 10000 observations : Done! (0.07646838426589966 minutes)
# Batch 39 with 10000 observations : Done! (0.07677716414133708 minutes)
# Batch 40 with 10000 observations : Done! (0.07802304029464721 minutes)
# Batch 41 with 10000 observations : Done! (0.07881985902786255 minutes)
# Batch 42 with 10000 observations : Done! (0.07608131965001425 minutes)
# Batch 43 with 10000 observations : Done! (0.07630431254704793 minutes)
# Batch 44 with 10000 observations : Done! (0.17443002462387086 minutes)
# Batch 45 with 10000 observations : Done! (0.17445858319600424 minutes)
# Batch 46 with 10000 observations : Done! (0.20248744487762452 minutes)
# Batch 47 with 10000 observations : Done! (0.17688502073287965 minutes)
# Batch 48 with 10000 observations : Done! (0.1757668177286784 minutes)
# Batch 49 with 10000 observations : Done! (0.11173003911972046 minutes)
# Batch 50 with 10000 observations : Done! (0.07712024450302124 minutes)
# Batch 51 with 10000 observations : Done! (0.07666736443837484 minutes)
# Batch 52 with 10000 observations : Done! (0.07699480851491293 minutes)
# Batch 53 with 10000 observations : Done! (0.07611859242121378 minutes)
# Batch 54 with 10000 observations : Done! (0.07701549927393596 minutes)
# Batch 55 with 10000 observations : Done! (0.07632749080657959 minutes)
# Batch 56 with 10000 observations : Done! (0.0811028281847636 minutes)
# Batch 57 with 10000 observations : Done! (0.07797646919886271 minutes)
# Batch 58 with 10000 observations : Done! (0.07863046725591023 minutes)
# Batch 59 with 10000 observations : Done! (0.07587830225626628 minutes)
# Batch 60 with 10000 observations : Done! (0.07559034824371338 minutes)
# Batch 61 with 10000 observations : Done! (0.07553651730219522 minutes)
# Batch 62 with 10000 observations : Done! (0.07584843238194784 minutes)
# Batch 63 with 10000 observations : Done! (0.07671385606129964 minutes)
# Batch 64 with 10000 observations : Done! (0.07677805423736572 minutes)
# Batch 65 with 10000 observations : Done! (0.0774273951848348 minutes)
# Batch 66 with 10000 observations : Done! (0.07557189464569092 minutes)
# Batch 67 with 10000 observations : Done! (0.07617082198460896 minutes)
# Batch 68 with 10000 observations : Done! (0.0752480149269104 minutes)
# Batch 69 with 10000 observations : Done! (0.07722649574279786 minutes)
# Batch 70 with 10000 observations : Done! (0.0763857364654541 minutes)
# Batch 71 with 10000 observations : Done! (0.07786080042521158 minutes)
# Batch 72 with 10000 observations : Done! (0.07617284854253133 minutes)
# Batch 73 with 10000 observations : Done! (0.07539514700571696 minutes)
# Batch 74 with 10000 observations : Done! (0.07527740399042765 minutes)
# Batch 75 with 10000 observations : Done! (0.0755825122197469 minutes)
# Batch 76 with 10000 observations : Done! (0.07557382583618164 minutes)
# Batch 77 with 10000 observations : Done! (0.07620303630828858 minutes)
# Batch 78 with 10000 observations : Done! (0.07567092577616373 minutes)
# Batch 79 with 10000 observations : Done! (0.07554069757461548 minutes)
# Batch 80 with 10000 observations : Done! (0.07648109594980876 minutes)
# Batch 81 with 10000 observations : Done! (0.075832466284434 minutes)
# Batch 82 with 10000 observations : Done! (0.07766307592391967 minutes)
# Batch 83 with 10000 observations : Done! (0.07648186286290487 minutes)
# Batch 84 with 10000 observations : Done! (0.07613931099573772 minutes)
# Batch 85 with 10000 observations : Done! (0.07513682842254639 minutes)
# Batch 86 with 10000 observations : Done! (0.08087568283081055 minutes)
# Batch 87 with 10000 observations : Done! (0.07646058003107707 minutes)
# Batch 88 with 10000 observations : Done! (0.07594980398813883 minutes)
# Batch 89 with 10000 observations : Done! (0.07519588073094687 minutes)
# Batch 90 with 10000 observations : Done! (0.07729886372884115 minutes)
# Batch 91 with 10000 observations : Done! (0.07601003646850586 minutes)
# Batch 92 with 10000 observations : Done! (0.07722087701161702 minutes)
# Batch 93 with 10000 observations : Done! (0.17433944940567017 minutes)
# Batch 94 with 10000 observations : Done! (0.1750793695449829 minutes)
# Batch 95 with 10000 observations : Done! (0.17505332231521606 minutes)
# Batch 96 with 10000 observations : Done! (0.18146605094273885 minutes)
# Batch 97 with 10000 observations : Done! (0.17473549842834474 minutes)
# Batch 98 with 10000 observations : Done! (0.13023369312286376 minutes)
# Batch 99 with 10000 observations : Done! (0.07563860416412353 minutes)
# Batch 100 with 10000 observations : Done! (0.07890196243921915 minutes)
# Batch 101 with 10000 observations : Done! (0.07729670206705729 minutes)
# Batch 102 with 10000 observations : Done! (0.07660787105560303 minutes)
# Batch 103 with 10000 observations : Done! (0.0758483608563741 minutes)
# Batch 104 with 10000 observations : Done! (0.07675955295562745 minutes)
# Batch 105 with 10000 observations : Done! (0.0775944709777832 minutes)
# Batch 106 with 10000 observations : Done! (0.07585349082946777 minutes)
# Batch 107 with 10000 observations : Done! (0.07647709846496582 minutes)
# Batch 108 with 10000 observations : Done! (0.07756930987040202 minutes)
# Batch 109 with 10000 observations : Done! (0.07680654923121134 minutes)
# Batch 110 with 10000 observations : Done! (0.07735644578933716 minutes)
# Batch 111 with 10000 observations : Done! (0.07615921099980673 minutes)
# Batch 112 with 10000 observations : Done! (0.07791084051132202 minutes)
# Batch 113 with 10000 observations : Done! (0.07623616456985474 minutes)
# Batch 114 with 10000 observations : Done! (0.18370433648427328 minutes)
# Batch 115 with 10000 observations : Done! (0.17628222306569416 minutes)
# Batch 116 with 10000 observations : Done! (0.17522847255071003 minutes)
# Batch 117 with 10000 observations : Done! (0.17473082145055135 minutes)
# Batch 118 with 10000 observations : Done! (0.175347105662028 minutes)
# Batch 119 with 10000 observations : Done! (0.12857091029485065 minutes)
# Batch 120 with 10000 observations : Done! (0.07728472153345743 minutes)
# Batch 121 with 10000 observations : Done! (0.07719495296478271 minutes)
# Batch 122 with 10000 observations : Done! (0.07656387885411581 minutes)
# Batch 123 with 10000 observations : Done! (0.07922549645105997 minutes)
# Batch 124 with 10000 observations : Done! (0.0763302763303121 minutes)
# Batch 125 with 10000 observations : Done! (0.07725474039713541 minutes)
# Batch 126 with 10000 observations : Done! (0.17403240203857423 minutes)
# 6725 observations: Done! (0.12123446861902873 minutes)
# Time for lfst_r_lfu2ltu: 13.81 minutes
#
# Indicator code:  rd_e_gerdreg
#
# Length of df before removing NA values: 795872
# Length of df after removing NA values: 245426
# Length of df after selecting only areas existing in neo4j SustainGraph: 202759
#
# Columns of df: ['unit', 'geo', 'sectperf', 'freq', 'time', 'value']
# Dimension columns: ['freq', 'sectperf']
#
# Attribute columns: unit
#
# ----------------------------------------------------------
# Batch 1 with 10001 observations : Done! (0.17406072616577148 minutes)
# Batch 2 with 10000 observations : Done! (0.10410417715708414 minutes)
# Batch 3 with 10000 observations : Done! (0.07596129576365153 minutes)
# Batch 4 with 10000 observations : Done! (0.07554958661397299 minutes)
# Batch 5 with 10000 observations : Done! (0.0762075940767924 minutes)
# Batch 6 with 10000 observations : Done! (0.07624912659327189 minutes)
# Batch 7 with 10000 observations : Done! (0.07763047615687052 minutes)
# Batch 8 with 10000 observations : Done! (0.0771929144859314 minutes)
# Batch 9 with 10000 observations : Done! (0.07554865678151448 minutes)
# Batch 10 with 10000 observations : Done! (0.07721561590830485 minutes)
# Batch 11 with 10000 observations : Done! (0.07814089854558309 minutes)
# Batch 12 with 10000 observations : Done! (0.07615627845128377 minutes)
# Batch 13 with 10000 observations : Done! (0.07619578043619792 minutes)
# Batch 14 with 10000 observations : Done! (0.07874348560969034 minutes)
# Batch 15 with 10000 observations : Done! (0.0757520079612732 minutes)
# Batch 16 with 10000 observations : Done! (0.18510611454645792 minutes)
# Batch 17 with 10000 observations : Done! (0.156866459051768 minutes)
# Batch 18 with 10000 observations : Done! (0.15672844648361206 minutes)
# Batch 19 with 10000 observations : Done! (0.15686612923940021 minutes)
# Batch 20 with 10000 observations : Done! (0.1567811608314514 minutes)
# 2758 observations: Done! (0.04364152352015178 minutes)
# Time for rd_e_gerdreg: 2.36 minutes
#
# Indicator code:  rd_p_persreg
#
# Length of df before removing NA values: 1911844
# Length of df after removing NA values: 519640
# Length of df after selecting only areas existing in neo4j SustainGraph: 462936
#
# Columns of df: ['sex', 'geo', 'freq', 'unit', 'sectperf', 'prof_pos', 'time', 'value']
# Dimension columns: ['freq', 'prof_pos', 'sectperf', 'sex']
#
# Attribute columns: unit
#
# ----------------------------------------------------------
# Batch 1 with 10001 observations : Done! (0.1595657706260681 minutes)
# Batch 2 with 10000 observations : Done! (0.2132548451423645 minutes)
# Batch 3 with 10000 observations : Done! (0.0752664844195048 minutes)
# Batch 4 with 10000 observations : Done! (0.07327510913213094 minutes)
# Batch 5 with 10000 observations : Done! (0.07451812823613485 minutes)
# Batch 6 with 10000 observations : Done! (0.07643746137619019 minutes)
# Batch 7 with 10000 observations : Done! (0.07407551606496175 minutes)
# Batch 8 with 10000 observations : Done! (0.07513485749562582 minutes)
# Batch 9 with 10000 observations : Done! (0.07435907920201619 minutes)
# Batch 10 with 10000 observations : Done! (0.07527784109115601 minutes)
# Batch 11 with 10000 observations : Done! (0.07393469015757242 minutes)
# Batch 12 with 10000 observations : Done! (0.07538490692774455 minutes)
# Batch 13 with 10000 observations : Done! (0.07429898579915364 minutes)
# Batch 14 with 10000 observations : Done! (0.07602217197418212 minutes)
# Batch 15 with 10000 observations : Done! (0.07483421166737875 minutes)
# Batch 16 with 10000 observations : Done! (0.07447107632954915 minutes)
# Batch 17 with 10000 observations : Done! (0.07563320795694987 minutes)
# Batch 18 with 10000 observations : Done! (0.07584835290908813 minutes)
# Batch 19 with 10000 observations : Done! (0.07434317668279013 minutes)
# Batch 20 with 10000 observations : Done! (0.07403742869695028 minutes)
# Batch 21 with 10000 observations : Done! (0.07498862743377685 minutes)
# Batch 22 with 10000 observations : Done! (0.16825267871220906 minutes)
# Batch 23 with 10000 observations : Done! (0.17156861225763956 minutes)
# Batch 24 with 10000 observations : Done! (0.18426174720128377 minutes)
# Batch 25 with 10000 observations : Done! (0.16427008708318075 minutes)
# Batch 26 with 10000 observations : Done! (0.16856006781260172 minutes)
# Batch 27 with 10000 observations : Done! (0.1466117779413859 minutes)
# Batch 28 with 10000 observations : Done! (0.07507871786753337 minutes)
# Batch 29 with 10000 observations : Done! (0.07398231426874796 minutes)
# Batch 30 with 10000 observations : Done! (0.073124098777771 minutes)
# Batch 31 with 10000 observations : Done! (0.07469163338343303 minutes)
# Batch 32 with 10000 observations : Done! (0.07309990326563517 minutes)
# Batch 33 with 10000 observations : Done! (0.0764055848121643 minutes)
# Batch 34 with 10000 observations : Done! (0.074669349193573 minutes)
# Batch 35 with 10000 observations : Done! (0.07560047705968222 minutes)
# Batch 36 with 10000 observations : Done! (0.07591483195622763 minutes)
# Batch 37 with 10000 observations : Done! (0.07439112265904745 minutes)
# Batch 38 with 10000 observations : Done! (0.07440026601155598 minutes)
# Batch 39 with 10000 observations : Done! (0.07337327400843302 minutes)
# Batch 40 with 10000 observations : Done! (0.07445023059844971 minutes)
# Batch 41 with 10000 observations : Done! (0.07208899259567261 minutes)
# Batch 42 with 10000 observations : Done! (0.07266334692637126 minutes)
# Batch 43 with 10000 observations : Done! (0.07308078606923421 minutes)
# Batch 44 with 10000 observations : Done! (0.07464419603347779 minutes)
# Batch 45 with 10000 observations : Done! (0.07361455758412679 minutes)
# Batch 46 with 10000 observations : Done! (0.07440362373987834 minutes)
# 2935 observations: Done! (0.0218164324760437 minutes)
# Time for rd_p_persreg: 4.76 minutes
#
# Indicator code:  nama_10r_2gdp
#
# Length of df before removing NA values: 70080
# Length of df after removing NA values: 66013
# Length of df after selecting only areas existing in neo4j SustainGraph: 58166
#
# Columns of df: ['unit', 'geo', 'freq', 'time', 'value']
# Dimension columns: ['freq']
#
# Attribute columns: unit
#
# ----------------------------------------------------------
# Batch 1 with 10001 observations : Done! (0.0709096352259318 minutes)
# Batch 2 with 10000 observations : Done! (0.07405381202697754 minutes)
# Batch 3 with 10000 observations : Done! (0.07380148967107138 minutes)
# Batch 4 with 10000 observations : Done! (0.15657174984614056 minutes)
# Batch 5 with 10000 observations : Done! (0.15819861888885497 minutes)
# 8165 observations: Done! (0.1310575008392334 minutes)
# Time for nama_10r_2gdp: 0.72 minutes
#
# Indicator code:  tran_r_acci
#
# Length of df before removing NA values: 63240
# Length of df after removing NA values: 50553
# Length of df after selecting only areas existing in neo4j SustainGraph: 46341
#
# Columns of df: ['unit', 'geo', 'victim', 'freq', 'time', 'value']
# Dimension columns: ['freq', 'victim']
#
# Attribute columns: unit
#
# ----------------------------------------------------------
# Batch 1 with 10001 observations : Done! (0.14534639517466227 minutes)
# Batch 2 with 10000 observations : Done! (0.1457624117533366 minutes)
# Batch 3 with 10000 observations : Done! (0.10476944049199423 minutes)
# Batch 4 with 10000 observations : Done! (0.06664028962453207 minutes)
# 6340 observations: Done! (0.04485762119293213 minutes)
# Time for tran_r_acci: 0.55 minutes
#
# Indicator code:  aei_pr_soiler
#
# Length of df before removing NA values: 385440
# Length of df after removing NA values: 385440
# Length of df after selecting only areas existing in neo4j SustainGraph: 375120
#
# Columns of df: ['clc18', 'geo', 'freq', 'unit', 'levels', 'time', 'value']
# Dimension columns: ['clc18', 'freq', 'levels']
#
# Attribute columns: unit
#
# ----------------------------------------------------------
# Batch 1 with 10001 observations : Done! (0.19262873729070026 minutes)
# Batch 2 with 10000 observations : Done! (0.16635989745457966 minutes)
# Batch 3 with 10000 observations : Done! (0.0766727606455485 minutes)
# Batch 4 with 10000 observations : Done! (0.07502162456512451 minutes)
# Batch 5 with 10000 observations : Done! (0.07702775398890177 minutes)
# Batch 6 with 10000 observations : Done! (0.07859970728556315 minutes)
# Batch 7 with 10000 observations : Done! (0.072548508644104 minutes)
# Batch 8 with 10000 observations : Done! (0.07076525688171387 minutes)
# Batch 9 with 10000 observations : Done! (0.07445588111877441 minutes)
# Batch 10 with 10000 observations : Done! (0.07403802871704102 minutes)
# Batch 11 with 10000 observations : Done! (0.07846779823303222 minutes)
# Batch 12 with 10000 observations : Done! (0.07721108595530192 minutes)
# Batch 13 with 10000 observations : Done! (0.07446270783742269 minutes)
# Batch 14 with 10000 observations : Done! (0.073977530002594 minutes)
# Batch 15 with 10000 observations : Done! (0.07320579687754313 minutes)
# Batch 16 with 10000 observations : Done! (0.07307161490122477 minutes)
# Batch 17 with 10000 observations : Done! (0.07337061961491903 minutes)
# Batch 18 with 10000 observations : Done! (0.0738247791926066 minutes)
# Batch 19 with 10000 observations : Done! (0.0772428313891093 minutes)
# Batch 20 with 10000 observations : Done! (0.06996405124664307 minutes)
# Batch 21 with 10000 observations : Done! (0.0710966149965922 minutes)
# Batch 22 with 10000 observations : Done! (0.07473325332005819 minutes)
# Batch 23 with 10000 observations : Done! (0.07049824396769205 minutes)
# Batch 24 with 10000 observations : Done! (0.06970076163609823 minutes)
# Batch 25 with 10000 observations : Done! (0.08278202215830485 minutes)
# Batch 26 with 10000 observations : Done! (0.07097445329030355 minutes)
# Batch 27 with 10000 observations : Done! (0.07140151659647624 minutes)
# Batch 28 with 10000 observations : Done! (0.07554459969202677 minutes)
# Batch 29 with 10000 observations : Done! (0.07287983496983846 minutes)
# Batch 30 with 10000 observations : Done! (0.07332950433095296 minutes)
# Batch 31 with 10000 observations : Done! (0.07747992674509684 minutes)
# Batch 32 with 10000 observations : Done! (0.07099378903706868 minutes)
# Batch 33 with 10000 observations : Done! (0.0699557622273763 minutes)
# Batch 34 with 10000 observations : Done! (0.07239150603612264 minutes)
# Batch 35 with 10000 observations : Done! (0.07298502127329508 minutes)
# Batch 36 with 10000 observations : Done! (0.06989612976710001 minutes)
# Batch 37 with 10000 observations : Done! (0.07196349302927653 minutes)
# 5119 observations: Done! (0.04097893238067627 minutes)
# Time for aei_pr_soiler: 3.39 minutes
#
# Indicator code:  hlth_cd_asdr2
#
# Length of df before removing NA values: 4431420
# Length of df after removing NA values: 3836289
# Length of df after selecting only areas existing in neo4j SustainGraph: 3461934
#
# Columns of df: ['sex', 'geo', 'icd10', 'freq', 'age', 'unit', 'time', 'value']
# Dimension columns: ['age', 'freq', 'icd10', 'sex']
#
# Attribute columns: unit
#
# ----------------------------------------------------------
# Batch 1 with 10001 observations : Done! (0.07640164693196615 minutes)
# Batch 2 with 10000 observations : Done! (0.07723175287246704 minutes)
# Batch 3 with 10000 observations : Done! (0.07909395297368367 minutes)
# Batch 4 with 10000 observations : Done! (0.07667061487833658 minutes)
# Batch 5 with 10000 observations : Done! (0.08697074254353841 minutes)
# Batch 6 with 10000 observations : Done! (0.08901001612345377 minutes)
# Batch 7 with 10000 observations : Done! (0.0794386347134908 minutes)
# Batch 8 with 10000 observations : Done! (0.07687219381332397 minutes)
# Batch 9 with 10000 observations : Done! (0.08416944742202759 minutes)
# Batch 10 with 10000 observations : Done! (0.20578766663869222 minutes)
# Batch 11 with 10000 observations : Done! (0.1727160414059957 minutes)
# Batch 12 with 10000 observations : Done! (0.19157543579737346 minutes)
# Batch 13 with 10000 observations : Done! (0.19614291588465374 minutes)
# Batch 14 with 10000 observations : Done! (0.16719314654668171 minutes)
# Batch 15 with 10000 observations : Done! (0.08632995287577311 minutes)
# Batch 16 with 10000 observations : Done! (0.07986424366633098 minutes)
# Batch 17 with 10000 observations : Done! (0.07836731274922688 minutes)
# Batch 18 with 10000 observations : Done! (0.07668799956639608 minutes)
# Batch 19 with 10000 observations : Done! (0.07653881708780924 minutes)
# Batch 20 with 10000 observations : Done! (0.0744215726852417 minutes)
# Batch 21 with 10000 observations : Done! (0.0749247670173645 minutes)
# Batch 22 with 10000 observations : Done! (0.07606416940689087 minutes)
# Batch 23 with 10000 observations : Done! (0.07750793695449829 minutes)
# Batch 24 with 10000 observations : Done! (0.07746269305547078 minutes)
# Batch 25 with 10000 observations : Done! (0.07729753653208414 minutes)
# Batch 26 with 10000 observations : Done! (0.07545733054478963 minutes)
# Batch 27 with 10000 observations : Done! (0.07721522649129232 minutes)
# Batch 28 with 10000 observations : Done! (0.07725739479064941 minutes)
# Batch 29 with 10000 observations : Done! (0.07623655796051025 minutes)
# Batch 30 with 10000 observations : Done! (0.07718502680460612 minutes)
# Batch 31 with 10000 observations : Done! (0.07461051146189372 minutes)
# Batch 32 with 10000 observations : Done! (0.07629632552464803 minutes)
# Batch 33 with 10000 observations : Done! (0.0770413637161255 minutes)
# Batch 34 with 10000 observations : Done! (0.074359929561615 minutes)
# Batch 35 with 10000 observations : Done! (0.07522954940795898 minutes)
# Batch 36 with 10000 observations : Done! (0.07523463567097982 minutes)
# Batch 37 with 10000 observations : Done! (0.07547704776128134 minutes)
# Batch 38 with 10000 observations : Done! (0.0760007381439209 minutes)
# Batch 39 with 10000 observations : Done! (0.075240425268809 minutes)
# Batch 40 with 10000 observations : Done! (0.07733471790949503 minutes)
# Batch 41 with 10000 observations : Done! (0.07647412618001302 minutes)
# Batch 42 with 10000 observations : Done! (0.07748738129933676 minutes)
# Batch 43 with 10000 observations : Done! (0.07440119584401449 minutes)
# Batch 44 with 10000 observations : Done! (0.08907315731048585 minutes)
# Batch 45 with 10000 observations : Done! (0.07675137519836425 minutes)
# Batch 46 with 10000 observations : Done! (0.0746083935101827 minutes)
# Batch 47 with 10000 observations : Done! (0.07523231506347657 minutes)
# Batch 48 with 10000 observations : Done! (0.07496844132741293 minutes)
# Batch 49 with 10000 observations : Done! (0.0731435497601827 minutes)
# Batch 50 with 10000 observations : Done! (0.07488330602645873 minutes)
# Batch 51 with 10000 observations : Done! (0.07996511459350586 minutes)
# Batch 52 with 10000 observations : Done! (0.07746127843856812 minutes)
# Batch 53 with 10000 observations : Done! (0.07817582289377849 minutes)
# Batch 54 with 10000 observations : Done! (0.07493810256322225 minutes)
# Batch 55 with 10000 observations : Done! (0.07595853408177694 minutes)
# Batch 56 with 10000 observations : Done! (0.07470591862996419 minutes)
# Batch 57 with 10000 observations : Done! (0.07382137378056844 minutes)
# Batch 58 with 10000 observations : Done! (0.07428605556488037 minutes)
# Batch 59 with 10000 observations : Done! (0.07645047108332316 minutes)
# Batch 60 with 10000 observations : Done! (0.07456691265106201 minutes)
# Batch 61 with 10000 observations : Done! (0.07648055950800578 minutes)
# Batch 62 with 10000 observations : Done! (0.07517520189285279 minutes)
# Batch 63 with 10000 observations : Done! (0.08163696924845378 minutes)
# Batch 64 with 10000 observations : Done! (0.07678138812383016 minutes)
# Batch 65 with 10000 observations : Done! (0.07519126733144124 minutes)
# Batch 66 with 10000 observations : Done! (0.07496946652730306 minutes)
# Batch 67 with 10000 observations : Done! (0.07452474037806193 minutes)
# Batch 68 with 10000 observations : Done! (0.07972479263941447 minutes)
# Batch 69 with 10000 observations : Done! (0.07489628394444783 minutes)
# Batch 70 with 10000 observations : Done! (0.0761058489481608 minutes)
# Batch 71 with 10000 observations : Done! (0.16748555501302084 minutes)
# Batch 72 with 10000 observations : Done! (0.16651863257090252 minutes)
# Batch 73 with 10000 observations : Done! (0.1641687830289205 minutes)
# Batch 74 with 10000 observations : Done! (0.1655598799387614 minutes)
# Batch 75 with 10000 observations : Done! (0.16501259009043376 minutes)
# Batch 76 with 10000 observations : Done! (0.1640864570935567 minutes)
# Batch 77 with 10000 observations : Done! (0.07575997908910116 minutes)
# Batch 78 with 10000 observations : Done! (0.07560882965723674 minutes)
# Batch 79 with 10000 observations : Done! (0.07582070032755533 minutes)
# Batch 80 with 10000 observations : Done! (0.07619341611862182 minutes)
# Batch 81 with 10000 observations : Done! (0.07714889446894328 minutes)
# Batch 82 with 10000 observations : Done! (0.09098937511444091 minutes)
# Batch 83 with 10000 observations : Done! (0.0918812354405721 minutes)
# Batch 84 with 10000 observations : Done! (0.08916022777557372 minutes)
# Batch 85 with 10000 observations : Done! (0.10517423550287883 minutes)
# Batch 86 with 10000 observations : Done! (0.11147574583689372 minutes)
# Batch 87 with 10000 observations : Done! (0.09224526087443034 minutes)
# Batch 88 with 10000 observations : Done! (0.1035774827003479 minutes)
# Batch 89 with 10000 observations : Done! (0.10195973316828409 minutes)
# Batch 90 with 10000 observations : Done! (0.09120893478393555 minutes)
# Batch 91 with 10000 observations : Done! (0.0918707529703776 minutes)
# Batch 92 with 10000 observations : Done! (0.08862478733062744 minutes)
# Batch 93 with 10000 observations : Done! (0.09829578797022502 minutes)
# Batch 94 with 10000 observations : Done! (0.1285375197728475 minutes)
# Batch 95 with 10000 observations : Done! (0.09060995976130168 minutes)
# Batch 96 with 10000 observations : Done! (0.09115811189015706 minutes)
# Batch 97 with 10000 observations : Done! (0.09613715012868246 minutes)
# Batch 98 with 10000 observations : Done! (0.09343317349751791 minutes)
# Batch 99 with 10000 observations : Done! (0.09103975693384807 minutes)
# Batch 100 with 10000 observations : Done! (0.09113810857137045 minutes)
# Batch 101 with 10000 observations : Done! (0.09087826410929362 minutes)
# Batch 102 with 10000 observations : Done! (0.09010093212127686 minutes)
# Batch 103 with 10000 observations : Done! (0.09008748531341552 minutes)
# Batch 104 with 10000 observations : Done! (0.09209944407145182 minutes)
# Batch 105 with 10000 observations : Done! (0.08988049030303955 minutes)
# Batch 106 with 10000 observations : Done! (0.09064896504084269 minutes)
# Batch 107 with 10000 observations : Done! (0.08905165592829387 minutes)
# Batch 108 with 10000 observations : Done! (0.08925903638203939 minutes)
# Batch 109 with 10000 observations : Done! (0.091182808081309 minutes)
# Batch 110 with 10000 observations : Done! (0.10290406147638957 minutes)
# Batch 111 with 10000 observations : Done! (0.09038646618525187 minutes)
# Batch 112 with 10000 observations : Done! (0.09028691053390503 minutes)
# Batch 113 with 10000 observations : Done! (0.09180285135904948 minutes)
# Batch 114 with 10000 observations : Done! (0.17985866069793702 minutes)
# Batch 115 with 10000 observations : Done! (0.17864497105280558 minutes)
# Batch 116 with 10000 observations : Done! (0.1810248851776123 minutes)
# Batch 117 with 10000 observations : Done! (0.1766353686650594 minutes)
# Batch 118 with 10000 observations : Done! (0.17711735566457112 minutes)
# Batch 119 with 10000 observations : Done! (0.1319040815035502 minutes)
# Batch 120 with 10000 observations : Done! (0.09003601868947347 minutes)
# Batch 121 with 10000 observations : Done! (0.09183159669240316 minutes)
# Batch 122 with 10000 observations : Done! (0.09886121352513631 minutes)
# Batch 123 with 10000 observations : Done! (0.08982727527618409 minutes)
# Batch 124 with 10000 observations : Done! (0.09026165008544922 minutes)
# Batch 125 with 10000 observations : Done! (0.18616360028584797 minutes)
# Batch 126 with 10000 observations : Done! (0.18101732730865477 minutes)
# Batch 127 with 10000 observations : Done! (0.17546254793802898 minutes)
# Batch 128 with 10000 observations : Done! (0.18213647206624348 minutes)
# Batch 129 with 10000 observations : Done! (0.1840909997622172 minutes)
# Batch 130 with 10000 observations : Done! (0.1222118854522705 minutes)
# Batch 131 with 10000 observations : Done! (0.09799431562423706 minutes)
# Batch 132 with 10000 observations : Done! (0.09120421012242635 minutes)
# Batch 133 with 10000 observations : Done! (0.08973249594370523 minutes)
# Batch 134 with 10000 observations : Done! (0.08994220892588298 minutes)
# Batch 135 with 10000 observations : Done! (0.09419997930526733 minutes)
# Batch 136 with 10000 observations : Done! (0.17963244120279948 minutes)
# Batch 137 with 10000 observations : Done! (0.17685272693634033 minutes)
# Batch 138 with 10000 observations : Done! (0.17718352476755778 minutes)
# Batch 139 with 10000 observations : Done! (0.1958060105641683 minutes)
# Batch 140 with 10000 observations : Done! (0.17929827372233073 minutes)
# Batch 141 with 10000 observations : Done! (0.11697263320287068 minutes)
# Batch 142 with 10000 observations : Done! (0.08982401291529338 minutes)
# Batch 143 with 10000 observations : Done! (0.09101955890655518 minutes)
# Batch 144 with 10000 observations : Done! (0.09065638383229574 minutes)
# Batch 145 with 10000 observations : Done! (0.09050245682398478 minutes)
# Batch 146 with 10000 observations : Done! (0.09097338517506917 minutes)
# Batch 147 with 10000 observations : Done! (0.08945552905400594 minutes)
# Batch 148 with 10000 observations : Done! (0.08913986682891846 minutes)
# Batch 149 with 10000 observations : Done! (0.09001360336939494 minutes)
# Batch 150 with 10000 observations : Done! (0.09054449796676636 minutes)
# Batch 151 with 10000 observations : Done! (0.0906996210416158 minutes)
# Batch 152 with 10000 observations : Done! (0.08919143676757812 minutes)
# Batch 153 with 10000 observations : Done! (0.09029518365859986 minutes)
# Batch 154 with 10000 observations : Done! (0.08941398859024048 minutes)
# Batch 155 with 10000 observations : Done! (0.09167672793070475 minutes)
# Batch 156 with 10000 observations : Done! (0.09096587101618449 minutes)
# Batch 157 with 10000 observations : Done! (0.08950766324996948 minutes)
# Batch 158 with 10000 observations : Done! (0.08994554281234741 minutes)
# Batch 159 with 10000 observations : Done! (0.09015959103902181 minutes)
# Batch 160 with 10000 observations : Done! (0.09068479935328165 minutes)
# Batch 161 with 10000 observations : Done! (0.09168117841084798 minutes)
# Batch 162 with 10000 observations : Done! (0.08953611056009929 minutes)
# Batch 163 with 10000 observations : Done! (0.09015367031097413 minutes)
# Batch 164 with 10000 observations : Done! (0.09450618426005046 minutes)
# Batch 165 with 10000 observations : Done! (0.09180339177449544 minutes)
# Batch 166 with 10000 observations : Done! (0.09315782388051351 minutes)
# Batch 167 with 10000 observations : Done! (0.08915881315867107 minutes)
# Batch 168 with 10000 observations : Done! (0.09020740191141764 minutes)
# Batch 169 with 10000 observations : Done! (0.08994322220484416 minutes)
# Batch 170 with 10000 observations : Done! (0.09009665648142497 minutes)
# Batch 171 with 10000 observations : Done! (0.09167944590250651 minutes)
# Batch 172 with 10000 observations : Done! (0.09066276947657267 minutes)
# Batch 173 with 10000 observations : Done! (0.09145960013071695 minutes)
# Batch 174 with 10000 observations : Done! (0.08958270947138468 minutes)
# Batch 175 with 10000 observations : Done! (0.09094208478927612 minutes)
# Batch 176 with 10000 observations : Done! (0.09045770565668741 minutes)
# Batch 177 with 10000 observations : Done! (0.09018765687942505 minutes)
# Batch 178 with 10000 observations : Done! (0.0931558092435201 minutes)
# Batch 179 with 10000 observations : Done! (0.09517110586166382 minutes)
# Batch 180 with 10000 observations : Done! (0.09119629859924316 minutes)
# Batch 181 with 10000 observations : Done! (0.09232542117436728 minutes)
# Batch 182 with 10000 observations : Done! (0.090313720703125 minutes)
# Batch 183 with 10000 observations : Done! (0.09200990597407023 minutes)
# Batch 184 with 10000 observations : Done! (0.09005678097407023 minutes)
# Batch 185 with 10000 observations : Done! (0.09527000983556112 minutes)
# Batch 186 with 10000 observations : Done! (0.09044891198476156 minutes)
# Batch 187 with 10000 observations : Done! (0.09945946137110392 minutes)
# Batch 188 with 10000 observations : Done! (0.09080236355463664 minutes)
# Batch 189 with 10000 observations : Done! (0.1780062993367513 minutes)
# Batch 190 with 10000 observations : Done! (0.17767191727956136 minutes)
# Batch 191 with 10000 observations : Done! (0.17977420886357626 minutes)
# Batch 192 with 10000 observations : Done! (0.17943105300267537 minutes)
# Batch 193 with 10000 observations : Done! (0.17892178297042846 minutes)
# Batch 194 with 10000 observations : Done! (0.12686185042063394 minutes)
# Batch 195 with 10000 observations : Done! (0.08910841941833496 minutes)
# Batch 196 with 10000 observations : Done! (0.09076708555221558 minutes)
# Batch 197 with 10000 observations : Done! (0.09517165025075276 minutes)
# Batch 198 with 10000 observations : Done! (0.08960583607355753 minutes)
# Batch 199 with 10000 observations : Done! (0.09128438234329224 minutes)
# Batch 200 with 10000 observations : Done! (0.09047776858011881 minutes)
# Batch 201 with 10000 observations : Done! (0.09303471644719442 minutes)
# Batch 202 with 10000 observations : Done! (0.08992050488789877 minutes)
# Batch 203 with 10000 observations : Done! (0.09017696380615234 minutes)
# Batch 204 with 10000 observations : Done! (0.08955945173899332 minutes)
# Batch 205 with 10000 observations : Done! (0.0911775549252828 minutes)
# Batch 206 with 10000 observations : Done! (0.09046138525009155 minutes)
# Batch 207 with 10000 observations : Done! (0.08982028166453043 minutes)
# Batch 208 with 10000 observations : Done! (0.09042652050654093 minutes)
# Batch 209 with 10000 observations : Done! (0.09653192361195882 minutes)
# Batch 210 with 10000 observations : Done! (0.09201131264368693 minutes)
# Batch 211 with 10000 observations : Done! (0.09234495162963867 minutes)
# Batch 212 with 10000 observations : Done! (0.09177318811416627 minutes)
# Batch 213 with 10000 observations : Done! (0.09176597197850546 minutes)
# Batch 214 with 10000 observations : Done! (0.0924531896909078 minutes)
# Batch 215 with 10000 observations : Done! (0.09220088322957357 minutes)
# Batch 216 with 10000 observations : Done! (0.09176281690597535 minutes)
# Batch 217 with 10000 observations : Done! (0.09033290545145671 minutes)
# Batch 218 with 10000 observations : Done! (0.09223560492197673 minutes)
# Batch 219 with 10000 observations : Done! (0.0925600012143453 minutes)
# Batch 220 with 10000 observations : Done! (0.09172572294871012 minutes)
# Batch 221 with 10000 observations : Done! (0.09301885763804117 minutes)
# Batch 222 with 10000 observations : Done! (0.18463253180185954 minutes)
# Batch 223 with 10000 observations : Done! (0.20407063563664754 minutes)
# Batch 224 with 10000 observations : Done! (0.1822745084762573 minutes)
# Batch 225 with 10000 observations : Done! (0.18197837670644124 minutes)
# Batch 226 with 10000 observations : Done! (0.19131207863489788 minutes)
# Batch 227 with 10000 observations : Done! (0.10112402041753134 minutes)
# Batch 228 with 10000 observations : Done! (0.10107351144154866 minutes)
# Batch 229 with 10000 observations : Done! (0.0992782711982727 minutes)
# Batch 230 with 10000 observations : Done! (0.10161926349004109 minutes)
# Batch 231 with 10000 observations : Done! (0.20488021771113077 minutes)
# Batch 232 with 10000 observations : Done! (0.19336191018422444 minutes)
# Batch 233 with 10000 observations : Done! (0.19411122798919678 minutes)
# Batch 234 with 10000 observations : Done! (0.1846355398495992 minutes)
# Batch 235 with 10000 observations : Done! (0.2131385644276937 minutes)
# Batch 236 with 10000 observations : Done! (0.10215485493342082 minutes)
# Batch 237 with 10000 observations : Done! (0.09971534411112468 minutes)
# Batch 238 with 10000 observations : Done! (0.1888424555460612 minutes)
# Batch 239 with 10000 observations : Done! (0.18472460508346558 minutes)
# Batch 240 with 10000 observations : Done! (0.2283476988474528 minutes)
# Batch 241 with 10000 observations : Done! (0.18422780831654867 minutes)
# Batch 242 with 10000 observations : Done! (0.18801600138346355 minutes)
# Batch 243 with 10000 observations : Done! (0.09705746571222941 minutes)
# Batch 244 with 10000 observations : Done! (0.09556509256362915 minutes)
# Batch 245 with 10000 observations : Done! (0.09654612143834432 minutes)
# Batch 246 with 10000 observations : Done! (0.20279534657796225 minutes)
# Batch 247 with 10000 observations : Done! (0.20445890426635743 minutes)
# Batch 248 with 10000 observations : Done! (0.19359255234400433 minutes)
# Batch 249 with 10000 observations : Done! (0.18834232091903685 minutes)
# Batch 250 with 10000 observations : Done! (0.18465958833694457 minutes)
# Batch 251 with 10000 observations : Done! (0.09472162326176961 minutes)
# Batch 252 with 10000 observations : Done! (0.09409728844960531 minutes)
# Batch 253 with 10000 observations : Done! (0.0927351713180542 minutes)
# Batch 254 with 10000 observations : Done! (0.09438653389612833 minutes)
# Batch 255 with 10000 observations : Done! (0.09142253398895264 minutes)
# Batch 256 with 10000 observations : Done! (0.09122799237569174 minutes)
# Batch 257 with 10000 observations : Done! (0.0926480491956075 minutes)
# Batch 258 with 10000 observations : Done! (0.09194103479385377 minutes)
# Batch 259 with 10000 observations : Done! (0.09223960240681967 minutes)
# Batch 260 with 10000 observations : Done! (0.09376408259073893 minutes)
# Batch 261 with 10000 observations : Done! (0.09294646978378296 minutes)
# Batch 262 with 10000 observations : Done! (0.09157719612121581 minutes)
# Batch 263 with 10000 observations : Done! (0.09196268717447917 minutes)
# Batch 264 with 10000 observations : Done! (0.09283065795898438 minutes)
# Batch 265 with 10000 observations : Done! (0.0955503503481547 minutes)
# Batch 266 with 10000 observations : Done! (0.09280765056610107 minutes)
# Batch 267 with 10000 observations : Done! (0.0940064549446106 minutes)
# Batch 268 with 10000 observations : Done! (0.09116324583689371 minutes)
# Batch 269 with 10000 observations : Done! (0.09175384442011515 minutes)
# Batch 270 with 10000 observations : Done! (0.09000131686528524 minutes)
# Batch 271 with 10000 observations : Done! (0.09536587397257487 minutes)
# Batch 272 with 10000 observations : Done! (0.09147744576136271 minutes)
# Batch 273 with 10000 observations : Done! (0.09095432758331298 minutes)
# Batch 274 with 10000 observations : Done! (0.09071848789850871 minutes)
# Batch 275 with 10000 observations : Done! (0.09028471708297729 minutes)
# Batch 276 with 10000 observations : Done! (0.11936160723368326 minutes)
# Batch 277 with 10000 observations : Done! (0.09342757066090902 minutes)
# Batch 278 with 10000 observations : Done! (0.08931453625361124 minutes)
# Batch 279 with 10000 observations : Done! (0.0903557538986206 minutes)
# Batch 280 with 10000 observations : Done! (0.09082303444544475 minutes)
# Batch 281 with 10000 observations : Done! (0.09038394292195638 minutes)
# Batch 282 with 10000 observations : Done! (0.09050230979919434 minutes)
# Batch 283 with 10000 observations : Done! (0.08990761439005533 minutes)
# Batch 284 with 10000 observations : Done! (0.08910819292068481 minutes)
# Batch 285 with 10000 observations : Done! (0.09066171248753865 minutes)
# Batch 286 with 10000 observations : Done! (0.09037803014119467 minutes)
# Batch 287 with 10000 observations : Done! (0.0899481733640035 minutes)
# Batch 288 with 10000 observations : Done! (0.1940075914065043 minutes)
# Batch 289 with 10000 observations : Done! (0.17857941786448162 minutes)
# Batch 290 with 10000 observations : Done! (0.17912911574045817 minutes)
# Batch 291 with 10000 observations : Done! (0.1804498235384623 minutes)
# Batch 292 with 10000 observations : Done! (0.17653435468673706 minutes)
# Batch 293 with 10000 observations : Done! (0.11410064299901326 minutes)
# Batch 294 with 10000 observations : Done! (0.08982998530069987 minutes)
# Batch 295 with 10000 observations : Done! (0.09003048737843831 minutes)
# Batch 296 with 10000 observations : Done! (0.09102356831232707 minutes)
# Batch 297 with 10000 observations : Done! (0.08977135817209879 minutes)
# Batch 298 with 10000 observations : Done! (0.0893719474474589 minutes)
# Batch 299 with 10000 observations : Done! (0.08983433246612549 minutes)
# Batch 300 with 10000 observations : Done! (0.09011157353719075 minutes)
# Batch 301 with 10000 observations : Done! (0.09048184951146444 minutes)
# Batch 302 with 10000 observations : Done! (0.08940385580062866 minutes)
# Batch 303 with 10000 observations : Done! (0.0906661073366801 minutes)
# Batch 304 with 10000 observations : Done! (0.09070308605829874 minutes)
# Batch 305 with 10000 observations : Done! (0.09011030594507853 minutes)
# Batch 306 with 10000 observations : Done! (0.09056288003921509 minutes)
# Batch 307 with 10000 observations : Done! (0.09011687437693278 minutes)
# Batch 308 with 10000 observations : Done! (0.08920950889587402 minutes)
# Batch 309 with 10000 observations : Done! (0.08989884455998738 minutes)
# Batch 310 with 10000 observations : Done! (0.09009631077448527 minutes)
# Batch 311 with 10000 observations : Done! (0.08953843116760254 minutes)
# Batch 312 with 10000 observations : Done! (0.09012029568354289 minutes)
# Batch 313 with 10000 observations : Done! (0.09150035381317138 minutes)
# Batch 314 with 10000 observations : Done! (0.08982876141866049 minutes)
# Batch 315 with 10000 observations : Done! (0.0902193824450175 minutes)
# Batch 316 with 10000 observations : Done! (0.10030804077784221 minutes)
# Batch 317 with 10000 observations : Done! (0.09087843100229899 minutes)
# Batch 318 with 10000 observations : Done! (0.09071056842803955 minutes)
# Batch 319 with 10000 observations : Done! (0.09284945329030354 minutes)
# Batch 320 with 10000 observations : Done! (0.08895597457885743 minutes)
# Batch 321 with 10000 observations : Done! (0.09214619795481364 minutes)
# Batch 322 with 10000 observations : Done! (0.09837629795074462 minutes)
# Batch 323 with 10000 observations : Done! (0.0904118299484253 minutes)
# Batch 324 with 10000 observations : Done! (0.09060530265172323 minutes)
# Batch 325 with 10000 observations : Done! (0.09003967046737671 minutes)
# Batch 326 with 10000 observations : Done! (0.09043744007746378 minutes)
# Batch 327 with 10000 observations : Done! (0.09097795486450196 minutes)
# Batch 328 with 10000 observations : Done! (0.09090047677357992 minutes)
# Batch 329 with 10000 observations : Done! (0.08890434106190999 minutes)
# Batch 330 with 10000 observations : Done! (0.08983275095621744 minutes)
# Batch 331 with 10000 observations : Done! (0.0906319538752238 minutes)
# Batch 332 with 10000 observations : Done! (0.09230297009150187 minutes)
# Batch 333 with 10000 observations : Done! (0.09824591875076294 minutes)
# Batch 334 with 10000 observations : Done! (0.09167515436808268 minutes)
# Batch 335 with 10000 observations : Done! (0.08976436456044515 minutes)
# Batch 336 with 10000 observations : Done! (0.09085871378580729 minutes)
# Batch 337 with 10000 observations : Done! (0.09054495890935262 minutes)
# Batch 338 with 10000 observations : Done! (0.08932256698608398 minutes)
# Batch 339 with 10000 observations : Done! (0.09088515837987264 minutes)
# Batch 340 with 10000 observations : Done! (0.09339989423751831 minutes)
# Batch 341 with 10000 observations : Done! (0.09049037694931031 minutes)
# Batch 342 with 10000 observations : Done! (0.09149801333745321 minutes)
# Batch 343 with 10000 observations : Done! (0.09171346823374431 minutes)
# Batch 344 with 10000 observations : Done! (0.09002094268798828 minutes)
# Batch 345 with 10000 observations : Done! (0.09848012526830037 minutes)
# Batch 346 with 10000 observations : Done! (0.08981677691141764 minutes)
# 1933 observations: Done! (0.018567967414855956 minutes)
# Time for hlth_cd_asdr2: 40.33 minutes
# Total execution time: 91.01751405795416 minutes

# %% [markdown]
# > Check cypher query

# %% [markdown]
# Checking for NUTS Indicator observations that weren't imported properly to the graph ('mismatches' between graph and Eurostat database)

# %%
records=driver.execute_query("""\
    MATCH (:Source {name: 'EU_SDG'})<-[:COMES_FROM]-(i1:Indicator)-[r:ASSOCIATED_WITH]-(i2:Indicator)
    WHERE i1.code CONTAINS "sdg" AND r.relevance='correspondant'
    RETURN COUNT(DISTINCT i2) AS total_i2_matched
    """,routing_="r",database_=database_name,result_transformer_=neo4j.Result.to_df)
print("NUTS regional dataset Indicator nodes created: {number}, expected: {expected} as of 2025.".format(
    number=records['total_i2_matched'].iloc[0],
    expected=len(nuts_df)
))
# Out:
# NUTS regional dataset Indicator nodes created: 19, expected: 19 as of 2025.

# %%
#Checking outgoing relationships for NUTS Indicators
records = driver.execute_query("""\
    MATCH (so:Source{name:'EU_SDG'})<-[:COMES_FROM]-(i:Indicator)-[:ASSOCIATED_WITH]-(i2:Indicator)--(s:Series)--(sm:SeriesMetadata)-[r:HAS_OBSERVATION]-(o:Observation)-[r1:REFERS_TO_AREA]->(ga)
    WHERE ((ga:NUTS1) or (ga:NUTS2) or (ga:NUTS3))
    RETURN s.code as indicator, COUNT(DISTINCT r1) as refer, COUNT(DISTINCT r) as has_obs,count(distinct o) as obs
    order by indicator
        """,routing_="r",database_=database_name,
    result_transformer_=neo4j.Result.to_df)

print("Individual indicator records:")
records
# Out:
# Individual indicator records:
#            indicator    refer  has_obs      obs
# 0      aei_pr_soiler   375120   375120   375120
# 1       edat_lfse_04   507263   507263   507263
# 2       edat_lfse_16    23446    23446    23446
# 3       edat_lfse_22   101950   101950   101950
# 4    educ_uoe_enra22     2985     2985     2985
# 5      hlth_cd_asdr2  3461934  3461934  3461934
# 6    hlth_silc_08b_r      729      729      729
# 7           ilc_li41     3588     3588     3588
# 8        ilc_lvhl21n     2295     2295     2295
# 9         ilc_mdsd18     2164     2164     2164
# 10       ilc_peps11n     2290     2290     2290
# 11  lfst_r_lfe2emprt   345153   345153   345153
# 12    lfst_r_lfu2ltu  1266726  1266726  1266726
# 13     nama_10r_2gdp    58166    58166    58166
# 14      rd_e_gerdreg   202759   202759   202759
# 15      rd_p_persreg   462936   462936   462936
# 16       tepsr_lm220     5585     5585     5585
# 17       tran_r_acci    46341    46341    46341
# 18      trng_lfse_04    27033    27033    27033

# %%
# checking for data that weren't imported correctly to the graph for each NUTS Indicator per series metadata from Eurostat database, labeled 'mismatches'
check_df_nuts = pd.DataFrame(series_metadata_expected_nuts)
check_df_nuts['to_import'] = 1  
check_df_nuts['imported'] = 0   

# group expected counts per (indicator), (dim_code, att_code)->series metadata
expected_grouped_nuts = check_df_nuts.groupby(['indicator', 'dim_code', 'att_code']).size().reset_index(name='to_import')
expected_grouped_nuts['imported'] = 0  # initialize column to store actual counts

check_statement_nuts = """
UNWIND $parameters AS row
MATCH (i:Indicator {code: row.indicator})--(s:Series)--(sm:SeriesMetadata)--(o:Observation)
WHERE sm.dimensionsCode = row.dim_code AND sm.attributesCode = row.att_code
RETURN s.code AS series_code, count(distinct o) AS total
"""

results = []

# check imported counts per (indicator), (dim_code, att_code)->series metadata
for idx, row in expected_grouped_nuts.iterrows():
    params = {
        "indicator": str(row['indicator']),
        "dim_code": str(row['dim_code']),
        "att_code": str(row['att_code'])
    }
    records, summary, keys = driver.execute_query(
        check_statement_nuts,
        parameters=params,  
        database_=database_name,
        routing_="r"
    )
    for r in records:
        results.append({
            "indicator": row['indicator'],
            "dim_code": row['dim_code'],
            "att_code": row['att_code'],
            "to_import": row['to_import'],
            "series_code": r['series_code'],
            "imported": r['total']
        })

check_df_nuts_final = pd.DataFrame(results)

# add seriesmetadata column
check_df_nuts_final['seriesmetadata'] = check_df_nuts_final['dim_code'] + "|" + check_df_nuts_final['att_code']

# add eu sdg indicator column 
check_df_nuts_final['eu sdg indicator'] = check_df_nuts_final['indicator'].map(codes_nuts_dict)

check_df_nuts_final = check_df_nuts_final[
    ['indicator', 'eu sdg indicator', 'series_code', 'dim_code', 'att_code', 'seriesmetadata', 'to_import', 'imported']
]

# %%
total_observations_imported = check_df_nuts_final['imported'].sum()
total_observations_to_import = check_df_nuts_final['to_import'].sum()
print("Total UN SDG observations imported in SustainGraph", total_observations_imported, ", expected:",total_observations_to_import)

mismatches = check_df_nuts_final[check_df_nuts_final['to_import'] != check_df_nuts_final['imported']]
if len(mismatches)==0:
    print("Mismatches: 0")
else:
    print("\nMismatches:\n", mismatches)
# Out:
# Total UN SDG observations imported in SustainGraph 6898463 , expected: 6898463
# Mismatches: 0

# %%
check_df_nuts_final
# Out:
#           indicator eu sdg indicator    series_code         dim_code att_code  \
# 0     aei_pr_soiler        sdg_15_50  aei_pr_soiler  CLC23_321|A|MOD       HA
# 1     aei_pr_soiler        sdg_15_50  aei_pr_soiler  CLC23_321|A|MOD      KM2
# 2     aei_pr_soiler        sdg_15_50  aei_pr_soiler  CLC23_321|A|MOD       PC
# 3     aei_pr_soiler        sdg_15_50  aei_pr_soiler  CLC23_321|A|MOD        T
# 4     aei_pr_soiler        sdg_15_50  aei_pr_soiler  CLC23_321|A|MOD     T_HA
# ...             ...              ...            ...              ...      ...
# 1475    tran_r_acci        sdg_11_40    tran_r_acci            A|KIL       NR
# 1476    tran_r_acci        sdg_11_40    tran_r_acci            A|KIL   P_MHAB
# 1477   trng_lfse_04        sdg_04_60   trng_lfse_04       Y25-64|A|F       PC
# 1478   trng_lfse_04        sdg_04_60   trng_lfse_04       Y25-64|A|M       PC
# 1479   trng_lfse_04        sdg_04_60   trng_lfse_04       Y25-64|A|T       PC
#
#             seriesmetadata  to_import  imported
# 0       CLC23_321|A|MOD|HA       4689      4689
# 1      CLC23_321|A|MOD|KM2       4689      4689
# 2       CLC23_321|A|MOD|PC       4689      4689
# 3        CLC23_321|A|MOD|T       4689      4689
# 4     CLC23_321|A|MOD|T_HA       4689      4689
# ...                    ...        ...       ...
# 1475              A|KIL|NR      11816     11816
# 1476          A|KIL|P_MHAB      11526     11526
# 1477         Y25-64|A|F|PC       8970      8970
# 1478         Y25-64|A|M|PC       8887      8887
# 1479         Y25-64|A|T|PC       9176      9176
#
# [1480 rows x 8 columns]
