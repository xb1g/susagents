# %%
from neo4j import GraphDatabase, basic_auth
import neo4j
import time
import aiohttp
import asyncio
import json
import os
from dotenv import load_dotenv
from pathlib import Path
import pandas as pd
import requests
from datetime import datetime

# %%
#load the environment variables
dotenv_path = Path('~/.env')
load_dotenv(dotenv_path=dotenv_path)  # This line brings all environment variables from .env into os.environ

# Get variables
SUSTAINGRAPH_URI = os.getenv('SUSTAINGRAPH_URI')
SUSTAINGRAPH_USER = os.getenv('SUSTAINGRAPH_USER')
SUSTAINGRAPH_PASSWORD = os.getenv('SUSTAINGRAPH_PASSWORD')
database_name = os.getenv('DATABASE_NAME')

# Connect to database
driver = GraphDatabase.driver(SUSTAINGRAPH_URI, auth=(SUSTAINGRAPH_USER, SUSTAINGRAPH_PASSWORD))

# Verify connectivity
with driver.session(database=database_name) as session:
    print(session.run("RETURN 'Connected to ' + $db", db=database_name).single()[0])
# Out:
# Connected to neo4j

# %% [markdown]
# ### Constaints

# %%
def create_constraint(tx,statement):
    tx.run(statement)

# %% [markdown]
# > Uniqueness

# %%
statement_goal = """ 
CREATE CONSTRAINT goal_unique IF NOT EXISTS FOR (goal:Goal) 
REQUIRE (goal.code,goal.title,goal.description) IS NODE KEY;
"""
statement_target="""
CREATE CONSTRAINT target_unique IF NOT EXISTS FOR (t:Target) 
REQUIRE (t.code,t.title,t.description) IS NODE KEY;
"""
statement_indicator ="""
CREATE CONSTRAINT indicator_unique IF NOT EXISTS FOR (i:Indicator) 
REQUIRE (i.code,i.description) IS NODE KEY;
"""

statement_series ="""
CREATE CONSTRAINT series_unique IF NOT EXISTS FOR (s:Series) 
REQUIRE (s.code,s.description) IS NODE KEY;
"""

statement_sm ="""
CREATE CONSTRAINT sm_unique IF NOT EXISTS FOR ( seriesmetadata:SeriesMetadata )
 REQUIRE (seriesmetadata.attributesCode, seriesmetadata.dimensionsCode,seriesmetadata.seriesCode) IS NODE KEY;
"""

statement_has_obs = """ 
CREATE CONSTRAINT has_obs_unique IF NOT EXISTS
FOR ()-[has_obs:HAS_OBSERVATION]-() REQUIRE (has_obs.attributesCode, has_obs.dimensionsCode,has_obs.seriesCode,has_obs.geoCode,has_obs.time) IS RELATIONSHIP KEY
"""

statement_so ="""CREATE CONSTRAINT source_name IF NOT EXISTS FOR (s:Source) 
REQUIRE s.name IS NODE KEY;
"""

# %% [markdown]
# > Property types

# %%
## Goal
statement_goal_code = """ 
CREATE CONSTRAINT goal_type_code IF NOT EXISTS
FOR (g:Goal) REQUIRE g.code :: STRING
"""
statement_goal_desc = """ 
CREATE CONSTRAINT goal_type_desc IF NOT EXISTS
FOR (g:Goal) REQUIRE g.description :: STRING
"""
statement_goal_title = """ 
CREATE CONSTRAINT goal_type_title IF NOT EXISTS
FOR (g:Goal) REQUIRE g.title :: STRING
"""

## Target
statement_target_code = """ 
CREATE CONSTRAINT target_type_code IF NOT EXISTS
FOR (t:Target) REQUIRE t.code :: STRING
"""
statement_target_desc = """ 
CREATE CONSTRAINT target_type_desc IF NOT EXISTS
FOR (t:Target) REQUIRE t.description :: STRING
"""
statement_target_title = """ 
CREATE CONSTRAINT target_type_title IF NOT EXISTS
FOR (t:Target) REQUIRE t.title :: STRING
"""

## Indicator
statement_indicator_code = """ 
CREATE CONSTRAINT indicator_type_code IF NOT EXISTS
FOR (i:Indicator)  REQUIRE i.code :: STRING
"""
statement_indicator_desc = """ 
CREATE CONSTRAINT indicator_type_desc IF NOT EXISTS
FOR (i:Indicator)  REQUIRE i.description :: STRING
"""

## Series
statement_series_code = """ 
CREATE CONSTRAINT series_type_code IF NOT EXISTS
FOR (s:Series) REQUIRE s.code :: STRING
"""
statement_series_desc = """ 
CREATE CONSTRAINT series_type_desc IF NOT EXISTS
FOR (s:Series)  REQUIRE s.description :: STRING
"""
statement_series_provider = """ 
CREATE CONSTRAINT series_type_desc IF NOT EXISTS
FOR (s:Series)  REQUIRE s.dataProviderURL :: STRING
"""

## SeriesMetadata

statement_sm_atcode = """ 
CREATE CONSTRAINT sm_type_attcode IF NOT EXISTS
FOR (sm:SeriesMetadata) REQUIRE sm.attributesCode :: STRING
"""

statement_sm_dimcode = """ 
CREATE CONSTRAINT sm_type_dimcode IF NOT EXISTS
FOR (sm:SeriesMetadata) REQUIRE sm.dimensionsCode :: STRING
"""
statement_sm_dimdesc= """ 
CREATE CONSTRAINT sm_type_dimdesc IF NOT EXISTS
FOR (sm:SeriesMetadata) REQUIRE sm.dimensionsDescription :: STRING
"""
statement_sm_attdesc= """ 
CREATE CONSTRAINT sm_type_dimdesc IF NOT EXISTS
FOR (sm:SeriesMetadata) REQUIRE sm.attributesDescription :: STRING
"""
statement_sm_seriesCode= """ 
CREATE CONSTRAINT sm_type_dimdesc IF NOT EXISTS
FOR (sm:SeriesMetadata) REQUIRE sm.seriesCode :: STRING
"""

### Observation
statement_obs_value = """ 
CREATE CONSTRAINT obs_type_value IF NOT EXISTS
FOR (o:Observation) REQUIRE o.value :: FLOAT
"""
statement_obs_time = """ 
CREATE CONSTRAINT obs_type_date IF NOT EXISTS
FOR (o:Observation) REQUIRE o.time :: DATE
"""

### Source
statement_so_name = """ 
CREATE CONSTRAINT so_type_name IF NOT EXISTS
FOR (so:Source) REQUIRE so.name :: STRING
"""

# %%
statements = [statement_goal,statement_goal_code,statement_goal_desc,statement_goal_title,
  statement_indicator,statement_indicator_code,statement_indicator_desc,
  statement_obs_time,statement_obs_value,
  statement_series,statement_series_code,statement_series_desc,statement_series_provider,
  statement_sm,statement_sm_atcode,statement_sm_attdesc,statement_sm_dimcode,statement_sm_dimdesc,statement_sm_seriesCode,
  statement_so,statement_so_name,
  statement_target,statement_target_code,statement_target_desc,statement_target_title,statement_has_obs]

with driver.session(database=database_name) as session:
    for statement in statements:
        session.execute_write(create_constraint, statement)

# %%
def cypher_run(tx,statement):
    tx.run(statement)

def cypher_run_params(tx,statement, params):
    tx.run(statement,parameters={"parameters":params})

# %% [markdown]
# Goals, Targets, Series, Indicators were retrieved from the United Nations SDG API and with the help of the APOC Neo4j’s standard library were introduced into the SustainGraph.
#
# The final graph schema is provided below:
# ![Alt text](wiki/SustainGraph-Indicators.png)

# %% [markdown]
# ### Goals

# %%
statement_goals = """
    CALL apoc.load.json("https://unstats.un.org/SDGAPI/v1/sdg/Goal/List?includechildren=false")
    YIELD value
    UNWIND value AS goal
    MERGE (g:Goal {code: toString(goal.code)})
    SET g.title = toString(goal.title)
    SET g.description = toString(goal.description)
    RETURN COUNT(DISTINCT g)
"""
with driver.session(database=database_name) as session:
    session.execute_write(cypher_run, statement = statement_goals)

# %% [markdown]
# ### Targets per Goal

# %%
statement_targets = """
    MATCH (g:Goal)
    CALL apoc.load.json("https://unstats.un.org/SDGAPI/v1/sdg/Goal/"+g.code+"/Target/List?includechildren=true")
    YIELD value
    UNWIND value.targets AS target
    MERGE (t:Target {code: toString(target.code)})
    SET t.title = toString(target.title)
    SET t.description = toString(target.description)
    MERGE (t)<-[:HAS_TARGET]-(g)
"""
with driver.session(database=database_name) as session:
    session.execute_write(cypher_run, statement = statement_targets)

# %% [markdown]
# ### Indicators per Target

# %%
statement_ind = """
    MATCH (t:Target) 
    CALL apoc.load.json("https://unstats.un.org/SDGAPI/v1/sdg/Target/"+t.code+"/Indicator/List?includechildren=true")
    YIELD value
    UNWIND value.indicators AS indicator
    MERGE (i:Indicator {code: toString(indicator.code)})
    SET i.description = toString(indicator.description)
    MERGE (s:Source{name:'UN_SDG'})
    MERGE (t)-[:HAS_INDICATOR]->(i)-[:COMES_FROM]->(s)
"""
with driver.session(database=database_name) as session:
    session.execute_write(cypher_run, statement = statement_ind)

# %% [markdown]
# ### Series per Indicator

# %%
statement_series = """
    MATCH (i:Indicator)-[:COMES_FROM]-(:Source{name:'UN_SDG'})
    CALL apoc.load.json("https://unstats.un.org/SDGAPI/v1/sdg/Indicator/"+i.code+"/Series/List")
    YIELD value
    UNWIND value.series AS series
    MERGE (s:Series {code: toString(series.code)})
    SET s.description = toString(series.description)
    SET s.dataProviderURL = 'https://unstats.un.org/sdgapi/swagger/'
    MERGE (i)-[:HAS_SERIES]->(s)
"""
with driver.session(database=database_name) as session:
    session.execute_write(cypher_run, statement = statement_series)

# %% [markdown]
# > Check cypher queries

# %%
records, summary, keys = driver.execute_query("""\
       MATCH (n:Goal) RETURN count(distinct n) as goals
        """,routing_="r",database_=database_name)
nodes_created=records[0]['goals']
expected=len(requests.get("https://unstats.un.org/SDGAPI/v1/sdg/Goal/List?includechildren=false").json())
print("{nodes_created} Goals in {time} ms, expected: {expected}".format(
    nodes_created=nodes_created,
    time=summary.result_available_after,
    expected=expected
))

records, summary, keys = driver.execute_query("""\
       MATCH (n:Target) RETURN count(distinct n) as targets
        """,routing_="r",database_=database_name)
print("{nodes_created} Targets in {time} ms, expected: {expected}".format(
    nodes_created=records[0]['targets'],
    time=summary.result_available_after,
    expected=sum(
        len(group.get("targets", [])) 
        for goal in requests.get("https://unstats.un.org/SDGAPI/v1/sdg/Goal/List?includechildren=false").json()
        for group in requests.get(f"https://unstats.un.org/SDGAPI/v1/sdg/Goal/{goal['code']}/Target/List?includechildren=true").json()
    )
))


records, summary, keys = driver.execute_query("""\
       MATCH (n:Source {name: "UN_SDG"})--(i:Indicator) RETURN COUNT(i) as ind
        """,routing_="r",database_=database_name)
print("{nodes_created} UN Indicators in {time} ms, expected: {expected}".format(
    nodes_created=records[0]['ind'],
    time=summary.result_available_after,
    expected=sum(
        len(group.get("indicators", []))
        for target in requests.get("https://unstats.un.org/SDGAPI/v1/sdg/Target/List?includechildren=true").json()
        for group in requests.get(f"https://unstats.un.org/SDGAPI/v1/sdg/Target/{target['code']}/Indicator/List?includechildren=true").json()
    )
))

expected_series = {
    series["code"]
    for indicator in requests.get("https://unstats.un.org/SDGAPI/v1/sdg/Indicator/List").json()
    for group in requests.get(f"https://unstats.un.org/SDGAPI/v1/sdg/Indicator/{indicator['code']}/Series/List").json()
    for series in group.get("series", [])
}
len_expected_series = len(expected_series)
records, summary, keys = driver.execute_query("""\
    MATCH (n:Source {name: "UN_SDG"})--(i:Indicator)--(s:Series) RETURN count(distinct s) as series
""", routing_="r", database_=database_name)
print("{nodes_created} UN Series in {time} ms, expected: {expected}".format(
    nodes_created=records[0]['series'],
    time=summary.result_available_after,
    expected=len_expected_series
))
# Out:
# 17 Goals in 14 ms, expected: 17
# 169 Targets in 16 ms, expected: 169
# 251 UN Indicators in 49 ms, expected: 251
# 708 UN Series in 60 ms, expected: 708

# %% [markdown]
# ### Observations per Series

# %% [markdown]
# Each UN Series code has multiple observations for each GeoArea, for different time periods and also for different attributes and dimensions

# %%
def goal_series(tx,statement, goal):
    result = tx.run(statement,goal=goal)
    return result.data()[0]['s_codes']

# %%
# Get all series per goal and store them in a dictionary
series_per_goal ={}
statement = """
    MATCH (:Goal{code:$goal})-[:HAS_TARGET]->(:Target)-[:HAS_INDICATOR]->(:Indicator)-[:HAS_SERIES]->(s:Series)
    WITH COLLECT(DISTINCT s.code) as s_codes
    RETURN s_codes
    """
with driver.session(database=database_name) as session:
    for i in range(1,18):
        series_per_goal[str(i)] = session.execute_read(goal_series, statement = statement, goal = str(i))

# Function for mapping the code of an attribute or a dimension with its description (We dont consider NaN values)
def metadata_mapping(metadata) :
    mapping = {}
    for m in metadata:
        for  c in m["codes"]:
            mapping[c["code"]] = c["description"]
    return mapping

# %% [markdown]
# Collect data (observation per Series) only for European countries and countries of the European Union. <p>
# Note: Cyprus belongs to the European Union, but does not belong geographically to Europe.

# %%
def areas_codes(tx,statement):
    result = tx.run(statement)
    return result.data()[0]['geocodes']

# Collect the available GeoArea codes of Europe in the SustainGraph
statement_areas = """
    MATCH (r:Region{name:'Europe'})-[:HAS_SUBREGION]->(sr:SubRegion)-[:HAS_AREA]->(a:Area)
    MATCH (eu:EuropeanUnion)<-[:BELONGS_TO]-(eua:Area)
    WITH COLLECT(DISTINCT a.M49code)+COLLECT(DISTINCT eua.M49code) as geocodes
    UNWIND geocodes as codes
    RETURN COLLECT(DISTINCT codes) as geocodes
    """

with driver.session(database=database_name) as session:
    geocodes = session.execute_read(areas_codes,statement_areas)

# %%
def create_params(series_code, geoAreas):
    return {
        'seriesCode':series_code,
        'areaCode': geoAreas # list of geoarea codes in M49
    }
def create_params_pages(series_code, geoAreas, pageSize):
    return {
        'seriesCode':series_code,
        'areaCode': geoAreas, #list of integers M49 codes
        'pageSize': pageSize
    }

#Function to collect the data per series code from the API
async def get_observations(session,series_code, geoAreas):
    async with session.get("https://unstats.un.org/sdgapi/v1/sdg/Series/Data", 
                           params = create_params(series_code,geoAreas)) as response:
        result = await response.json()
        print('Total elements of %s: %s in %s pages'%(series_code,result['totalElements'], result['totalPages']))
        exceptions = 0 
        obs = 0 
        params = []
        
        async with session.get("https://unstats.un.org/sdgapi/v1/sdg/Series/Data",
                                params = create_params_pages(series_code,geoAreas,str(result['totalElements']))) as response:
            result = await response.json()
            attributes = metadata_mapping( result['attributes'])
            dimensions = metadata_mapping( result['dimensions'])
            data = result['data']
            for observation in data :
                if (observation['value']!='NaN'):
                    obs +=1
                    attributes_code_string = '|'.join(list( observation['attributes'].values()))
                    attr_description = []
                    for a in list( observation['attributes'].values()):
                        attr_description.append(attributes[a])
                    attributes_description_string = '|'.join(attr_description)

                    dimension_code_string = '|'.join(list( observation['dimensions'].values()))
                    dim_description = []
                    for d in list( observation['dimensions'].values()):
                        dim_description.append(dimensions[d])
                    dimension_description_string = '|'.join(dim_description)
                    
                    if (observation['valueType'] != "Float"):
                        #print ("Series: %s value" %observation["series"] )
                        #print(observation['value'])
                        exceptions +=1
                        if observation['value'][0] != '<' and observation['value'][0] != '>' :
                            print ("Series: %s value" %observation["series"] )
                            print(observation['value'])
                            continue
                        else:
                            value = observation['value'][1:]
                    else:
                        value = observation['value']
                        

                    params_dict={
                            'geo':str(observation['geoAreaCode']),
                            'year':str(int(observation['timePeriodStart'])),
                            'value':float(value),
                            'att_desc': attributes_description_string,
                            'att_codes': attributes_code_string,
                            'dim_desc': dimension_description_string,
                            'dim_codes': dimension_code_string,
                            's_code':observation['series']
                        }
                    params.append(params_dict)  
        print("Observations  %s %d" %(series_code,obs))
        if (exceptions>0):
            print("Exceptions %s %d" %(series_code,exceptions))
        
        return params #list of dictionaries per series code

# %% [markdown]
# ### Collect the data from the API

# %% [markdown]
# Collect all the data from the API per goal (defining the parameter "goal") and store them in a json file under the folder "Data/2.UN_observations".
# We make asynchronous requests for each goal, to collect the data of all its series. Due to the size of the datasets, the asynchronous requests are made in batches of 5 to prevent server request timeout.

# %%
def indicators_for_goal(tx, statement, goal):
    result = tx.run(statement, goal=goal)
    return result.data()[0]['i_codes']

def series_for_indicator(tx, statement, indicator):
    result = tx.run(statement, indicator=indicator)
    return result.data()[0]['s_codes']

# store list of indicators per goal so Series data can be passed later
indicators_per_goal = {}
statement_goal = """
    MATCH (:Goal {code:$goal})-[:HAS_TARGET]->(:Target)-[:HAS_INDICATOR]->(i:Indicator)
    WITH COLLECT(DISTINCT i.code) as i_codes
    RETURN i_codes
"""
# store list of series per indicator
series_per_indicator = {}
statement_indicator = """
    MATCH (:Indicator {code:$indicator})-[:HAS_SERIES]->(s:Series)
    WITH COLLECT(DISTINCT s.code) as s_codes
    RETURN s_codes
"""

with driver.session(database=database_name) as session:
    # build mapping: goal -> indicators
    for i in range(1, 18):
        indicators_per_goal[str(i)] = session.execute_read(
            indicators_for_goal, 
            statement=statement_goal, 
            goal=str(i)
        )

    # build mapping: indicator -> series
    for goal, indicators in indicators_per_goal.items():
        for indicator in indicators:
            series_per_indicator[indicator] = session.execute_read(
                series_for_indicator,
                statement=statement_indicator,
                indicator=indicator
            )

# invert series_per_indicator
series_to_indicator = {}
for indicator, series_list in series_per_indicator.items():
    for s_code in series_list:
        series_to_indicator[s_code] = indicator

def metadata_mapping(metadata) :
    mapping = {}
    for m in metadata:
        for  c in m["codes"]:
            mapping[c["code"]] = c["description"]
    return mapping

# %%
for goal in range(1,18):
    st = time.time()
    print("Goal", str(goal))
    params = []
    batch_size = 5  # can be changed
    series_codes = series_per_goal[str(goal)]

    async with aiohttp.ClientSession() as session: 
        for i in range(0, len(series_codes), batch_size):
            batch = series_codes[i:i + batch_size]
            tasks = []

            for code in batch:
                indicator_code = series_to_indicator.get(code)
                
                async def fetch_with_indicator(s_code=code, i_code=indicator_code):
                    obs_list = await get_observations(session, s_code, geocodes)
                    for obs in obs_list:
                        obs['indicator'] = i_code
                    return obs_list

                tasks.append(asyncio.ensure_future(fetch_with_indicator()))

            batch_result = await asyncio.gather(*tasks)
            params.extend(batch_result)

    et = time.time()
    elapsed_time = et - st  # get the execution time
    print('Collect data :', elapsed_time/60, 'minutes')

    filename = f"Data/2.UN_observations/observations{goal}.json"
    with open(filename, "w") as outfile:
        json.dump(params, outfile, indent=2)
    print(filename, "created")
# Out:
# Goal 1
# Total elements of SI_COV_DISAB: 587 in 24 pages
# Total elements of SI_COV_MATNL: 135 in 6 pages
# Total elements of SI_COV_SOCINS: 160 in 7 pages
# Total elements of SI_COV_CHLD: 277 in 12 pages
# Total elements of SI_COV_WKINJRY: 152 in 7 pages
# Observations  SI_COV_MATNL 135
# Observations  SI_COV_WKINJRY 152
# Observations  SI_COV_SOCINS 160
# Observations  SI_COV_CHLD 277
# Observations  SI_COV_DISAB 587
# Total elements of SI_COV_LMKT: 96 in 4 pages
# Total elements of SI_COV_SOCAST: 158 in 7 pages
# Total elements of SI_COV_UEMP: 595 in 24 pages
# Total elements of SI_COV_POOR: 59 in 3 pages
# Total elements of SI_COV_PENSN: 518 in 21 pages
# Observations  SI_COV_LMKT 96
# Observations  SI_COV_POOR 59
# Observations  SI_COV_SOCAST 158
# Observations  SI_COV_PENSN 518
# Observations  SI_COV_UEMP 595
# Total elements of DC_ODA_POVG: 0 in 0 pages
# Total elements of DC_ODA_POVDLG: 529 in 22 pages
# Total elements of DC_ODA_POVLG: 190 in 8 pages
# Total elements of SI_COV_BENFTS: 178 in 8 pages
# Total elements of SI_COV_VULN: 146 in 6 pages
# Observations  DC_ODA_POVG 0
# Observations  SI_COV_VULN 146
# Observations  SI_COV_BENFTS 178
# Observations  DC_ODA_POVLG 190
# Observations  DC_ODA_POVDLG 529
# Total elements of SG_XPD_HLTH: 821 in 33 pages
# Total elements of SG_XPD_PROT: 821 in 33 pages
# Total elements of SG_XPD_ESSRV: 821 in 33 pages
# Total elements of SG_XPD_EDUC: 821 in 33 pages
# Total elements of SD_XPD_ESED: 55 in 3 pages
# Observations  SD_XPD_ESED 55
# Observations  SG_XPD_ESSRV 821
# Observations  SG_XPD_PROT 821
# Observations  SG_XPD_EDUC 821
# Observations  SG_XPD_HLTH 821
# Total elements of SP_LGL_LNDSEC: 14 in 1 pages
# Total elements of SP_LGL_LNDDOC: 25 in 1 pages
# Total elements of SP_LGL_LNDSTR: 242 in 10 pages
# Total elements of SP_ACS_BSRVSAN: 2918 in 117 pages
# Total elements of SP_ACS_BSRVH2O: 2854 in 115 pages
# Observations  SP_LGL_LNDSEC 14
# Observations  SP_LGL_LNDDOC 25
# Observations  SP_LGL_LNDSTR 242
# Observations  SP_ACS_BSRVH2O 2854
# Observations  SP_ACS_BSRVSAN 2918
# Total elements of SG_XPD_PR_HLTH: 5 in 1 pages
# Total elements of SG_XPD_PR_EDUC: 7 in 1 pages
# Total elements of SG_XPD_PR_SOC: 60 in 3 pages
# Total elements of SD_MDP_MUHHC: 0 in 0 pages
# Total elements of SG_XPD_PR: 61 in 3 pages
# Observations  SG_XPD_PR_HLTH 5
# Observations  SG_XPD_PR_EDUC 7
# Observations  SD_MDP_MUHHC 0
# Observations  SG_XPD_PR_SOC 60
# Observations  SG_XPD_PR 61
# Total elements of SD_MDP_ANDI: 0 in 0 pages
# Total elements of SD_MDP_ANDIHH: 0 in 0 pages
# Total elements of SD_MDP_CSMP: 0 in 0 pages
# Total elements of SI_POV_NAHC: 489 in 20 pages
# Total elements of SD_MDP_MUHC: 2311 in 93 pages
# Observations  SD_MDP_ANDI 0
# Observations  SD_MDP_ANDIHH 0
# Observations  SD_MDP_CSMP 0
# Observations  SI_POV_NAHC 489
# Observations  SD_MDP_MUHC 2311
# Total elements of VC_DSR_LSGP: 530 in 22 pages
# Total elements of VC_DSR_AGLH: 322 in 13 pages
# Total elements of VC_DSR_DDPA: 306 in 13 pages
# Total elements of VC_DSR_CHLN: 262 in 11 pages
# Total elements of VC_DSR_GDPLS: 530 in 22 pages
# Observations  VC_DSR_CHLN 262
# Observations  VC_DSR_AGLH 322
# Observations  VC_DSR_DDPA 306
# Observations  VC_DSR_GDPLS 530
# Observations  VC_DSR_LSGP 530
# Total elements of SG_DSR_SFDRR: 0 in 0 pages
# Total elements of VC_DSR_AFFCT: 987 in 40 pages
# Total elements of SG_DSR_LGRGSR: 510 in 21 pages
# Total elements of VC_DSR_CILN: 374 in 15 pages
# Total elements of VC_DSR_HOLH: 498 in 20 pages
# Observations  SG_DSR_SFDRR 0
# Observations  VC_DSR_CILN 374
# Observations  VC_DSR_HOLH 498
# Observations  SG_DSR_LGRGSR 510
# Observations  VC_DSR_AFFCT 987
# Total elements of VC_DSR_DAFF: 987 in 40 pages
# Total elements of VC_DSR_MISS: 576 in 24 pages
# Total elements of VC_DSR_PDYN: 621 in 25 pages
# Total elements of VC_DSR_MTMP: 1176 in 48 pages
# Total elements of VC_DSR_MMHN: 1176 in 48 pages
# Observations  VC_DSR_MISS 576
# Observations  VC_DSR_PDYN 621
# Observations  VC_DSR_DAFF 987
# Observations  VC_DSR_MTMP 1176
# Observations  VC_DSR_MMHN 1176
# Total elements of VC_DSR_PDLN: 543 in 22 pages
# Total elements of VC_DSR_MORT: 1167 in 47 pages
# Total elements of SG_DSR_SILN: 537 in 22 pages
# Total elements of VC_DSR_IJILN: 912 in 37 pages
# Total elements of VC_DSR_PDAN: 762 in 31 pages
# Observations  SG_DSR_SILN 537
# Observations  VC_DSR_PDLN 543
# Observations  VC_DSR_PDAN 762
# Observations  VC_DSR_IJILN 912
# Observations  VC_DSR_MORT 1167
# Total elements of SG_DSR_SILS: 528 in 22 pages
# Total elements of SG_GOV_LOGV: 561 in 23 pages
# Total elements of SI_POV_EMP1: 1287 in 52 pages
# Total elements of SI_POV_DAY1: 4864 in 195 pages
# Observations  SG_DSR_SILS 528
# Observations  SG_GOV_LOGV 561
# Observations  SI_POV_EMP1 1287
# Observations  SI_POV_DAY1 4864
# Collect data : 0.8619334816932678 minutes
# Data/2.UN_observations/observations1.json created
# Goal 2
# Total elements of AG_FPA_HMFP: 0 in 0 pages
# Total elements of AG_FPA_COMM: 300 in 12 pages
# Total elements of AG_FPA_CFPI: 602 in 25 pages
# Total elements of PD_AGR_SSFP: 1458 in 59 pages
# Total elements of PD_AGR_LSFP: 1377 in 56 pages
# Observations  AG_FPA_HMFP 0
# Observations  AG_FPA_COMM 275
# Observations  AG_FPA_CFPI 602
# Observations  PD_AGR_LSFP 324
# Observations  PD_AGR_SSFP 322
# Total elements of AG_LND_LNDSTR: 144 in 6 pages
# Total elements of AG_LND_PSTCDSMG: 56 in 3 pages
# Total elements of SI_AGR_SSFP: 180 in 8 pages
# Total elements of SI_AGR_LSFP: 180 in 8 pages
# Total elements of AG_LND_FIES: 84 in 4 pages
# Observations  AG_LND_PSTCDSMG 34
# Observations  AG_LND_FIES 46
# Observations  AG_LND_LNDSTR 60
# Observations  SI_AGR_SSFP 9
# Observations  SI_AGR_LSFP 9
# Total elements of AG_LND_SUST: 12 in 1 pages
# Total elements of AG_LND_SUST_PRXCSS: 369 in 15 pages
# Total elements of AG_LND_FERTMG: 77 in 4 pages
# Total elements of AG_LND_NFI: 105 in 5 pages
# Total elements of AG_LND_RMM: 120 in 5 pages
# Observations  AG_LND_SUST 8
# Observations  AG_LND_FERTMG 42
# Observations  AG_LND_NFI 57
# Observations  AG_LND_RMM 61
# Observations  AG_LND_SUST_PRXCSS 342
# Total elements of AG_LND_AGRBIO: 80 in 4 pages
# Total elements of AG_LND_FOVH: 136 in 6 pages
# Total elements of AG_LND_SUST_PRXTS: 369 in 15 pages
# Total elements of AG_LND_AGRWAG: 112 in 5 pages
# Total elements of AG_LND_H2OAVAIL: 70 in 3 pages
# Observations  AG_LND_AGRBIO 34
# Observations  AG_LND_H2OAVAIL 30
# Observations  AG_LND_FOVH 63
# Observations  AG_LND_AGRWAG 48
# Observations  AG_LND_SUST_PRXTS 342
# Total elements of AG_LND_SDGRD: 24 in 1 pages
# Total elements of SN_ITK_DEFCN: 960 in 39 pages
# Total elements of SN_ITK_DEFC: 960 in 39 pages
# Total elements of AG_PRD_FIESMS: 1200 in 48 pages
# Observations  AG_LND_SDGRD 15
# Total elements of AG_PRD_FIESS: 1200 in 48 pages
# Observations  SN_ITK_DEFCN 158
# Exceptions SN_ITK_DEFCN 38
# Observations  SN_ITK_DEFC 920
# Exceptions SN_ITK_DEFC 762
# Observations  AG_PRD_FIESMS 1014
# Observations  AG_PRD_FIESS 1014
# Exceptions AG_PRD_FIESS 79
# Total elements of AG_XPD_AGSGB: 920 in 37 pages
# Total elements of AG_PRD_ORTIND: 920 in 37 pages
# Total elements of AG_PRD_FIESMSN: 1200 in 48 pages
# Total elements of DC_TOF_AGRL: 190 in 8 pages
# Total elements of AG_PRD_FIESSN: 1200 in 48 pages
# Observations  DC_TOF_AGRL 190
# Observations  AG_XPD_AGSGB 909
# Observations  AG_PRD_ORTIND 909
# Observations  AG_PRD_FIESSN 935
# Exceptions AG_PRD_FIESSN 563
# Observations  AG_PRD_FIESMSN 1014
# Exceptions AG_PRD_FIESMSN 203
# Total elements of AG_PRD_XSUBDY: 147 in 6 pages
# Total elements of ER_GRF_PLNTSTOR: 494 in 20 pages
# Total elements of ER_GRF_ANIMRCNTN_TRB: 725 in 29 pages
# Total elements of ER_GRF_ANIMKPT: 1025 in 41 pages
# Total elements of AG_PRD_AGVAS: 920 in 37 pages
# Observations  AG_PRD_XSUBDY 147
# Observations  ER_GRF_PLNTSTOR 494
# Observations  AG_PRD_AGVAS 909
# Observations  ER_GRF_ANIMRCNTN_TRB 306
# Observations  ER_GRF_ANIMKPT 1013
# Total elements of ER_GRF_ANIMRCNTN: 775 in 31 pages
# Total elements of ER_NOEX_LBREDN: 1025 in 41 pages
# Total elements of ER_RSK_TRBBREDS: 1000 in 40 pages
# Total elements of ER_UNK_TRBBREDN: 1025 in 41 pages
# Total elements of ER_GRF_ANIMKPT_TRB: 1025 in 41 pages
# Observations  ER_GRF_ANIMRCNTN 425
# Observations  ER_NOEX_LBREDN 1013
# Observations  ER_UNK_TRBBREDN 1013
# Observations  ER_GRF_ANIMKPT_TRB 1013
# Observations  ER_RSK_TRBBREDS 883
# Total elements of ER_RSK_LBREDS: 1025 in 41 pages
# Total elements of SH_STA_ANEM_NPRG: 1032 in 42 pages
# Total elements of ER_UNK_LBREDN: 1025 in 41 pages
# Total elements of ER_NOEX_TRBBREDN: 1025 in 41 pages
# Total elements of SH_STA_ANEM_PREG: 1032 in 42 pages
# Observations  ER_UNK_LBREDN 1013
# Observations  ER_RSK_LBREDS 898
# Observations  ER_NOEX_TRBBREDN 1013
# Observations  SH_STA_ANEM_PREG 1032
# Observations  SH_STA_ANEM_NPRG 1032
# Total elements of SH_STA_ANEM: 1032 in 42 pages
# Total elements of SN_STA_OVWGTN: 1875 in 75 pages
# Total elements of SH_STA_WASTN: 76 in 4 pages
# Total elements of SN_STA_OVWGT: 1875 in 75 pages
# Total elements of SH_STA_WAST: 76 in 4 pages
# Observations  SH_STA_WAST 76
# Observations  SH_STA_WASTN 76
# Observations  SH_STA_ANEM 1032
# Observations  SN_STA_OVWGT 1875
# Observations  SN_STA_OVWGTN 1875
# Total elements of SH_MDD_WMN_NPRG: 0 in 0 pages
# Total elements of SH_MDD_CHLD: 0 in 0 pages
# Total elements of SH_STA_STNT: 1800 in 72 pages
# Total elements of SH_STA_STNTN: 1800 in 72 pages
# Observations  SH_MDD_CHLD 0
# Observations  SH_MDD_WMN_NPRG 0
# Observations  SH_STA_STNT 1800
# Observations  SH_STA_STNTN 1800
# Collect data : 0.7468451301256815 minutes
# Data/2.UN_observations/observations2.json created
# Goal 3
# Total elements of SH_AAP_ASMORT: 43 in 2 pages
# Total elements of SH_STA_ASAIRP: 43 in 2 pages
# Total elements of SH_HAP_ASMORT: 42 in 2 pages
# Total elements of SH_STA_WASHARI: 40 in 2 pages
# Total elements of SH_STA_POISN: 840 in 34 pages
# Observations  SH_HAP_ASMORT 39
# Observations  SH_AAP_ASMORT 40
# Observations  SH_STA_ASAIRP 40
# Observations  SH_STA_WASHARI 40
# Observations  SH_STA_POISN 840
# Total elements of SH_ACS_PCV3: 688 in 28 pages
# Total elements of SH_ACS_HPV: 602 in 25 pages
# Total elements of SH_HLF_EMED: 2 in 1 pages
# Total elements of SH_ACS_MCV2: 1026 in 42 pages
# Total elements of SH_ACS_DTP3: 1026 in 42 pages
# Observations  SH_HLF_EMED 2
# Observations  SH_ACS_HPV 359
# Observations  SH_ACS_PCV3 391
# Observations  SH_ACS_MCV2 882
# Observations  SH_ACS_DTP3 1026
# Total elements of DC_TOF_HLTHNT: 113 in 5 pages
# Total elements of DC_TOF_HLTHL: 187 in 8 pages
# Total elements of SH_FPL_MTMM: 28 in 2 pages
# Total elements of SP_DYN_ADKL: 1978 in 80 pages
# Total elements of SH_ALC_CONSPT: 943 in 38 pages
# Observations  SH_FPL_MTMM 28
# Observations  DC_TOF_HLTHNT 113
# Observations  DC_TOF_HLTHL 187
# Observations  SH_ALC_CONSPT 943
# Observations  SP_DYN_ADKL 1978
# Total elements of SH_STA_SCIDE: 840 in 34 pages
# Total elements of SH_STA_BRTC: 662 in 27 pages
# Total elements of SH_DTH_NCOM: 840 in 34 pages
# Total elements of SH_SUD_TREAT: 938 in 38 pages
# Total elements of SH_SUD_ALCOL: 123 in 5 pages
# Observations  SH_SUD_ALCOL 123
# Observations  SH_STA_BRTC 662
# Observations  SH_STA_SCIDE 840
# Observations  SH_DTH_NCOM 840
# Observations  SH_SUD_TREAT 938
# Total elements of SH_DYN_MORTN: 3096 in 124 pages
# Total elements of SH_DYN_NMRTN: 1032 in 42 pages
# Total elements of SH_DYN_NMRT: 1032 in 42 pages
# Total elements of SH_PRV_SMOK: 720 in 29 pages
# Total elements of SH_STA_MORT: 1032 in 42 pages
# Observations  SH_PRV_SMOK 720
# Observations  SH_DYN_NMRTN 1032
# Observations  SH_DYN_NMRT 1032
# Observations  SH_STA_MORT 1032
# Observations  SH_DYN_MORTN 3096
# Total elements of SH_BLD_MRSA: 160 in 7 pages
# Total elements of SH_DYN_IMRT: 3096 in 124 pages
# Total elements of SH_DYN_IMRTN: 3096 in 124 pages
# Total elements of SH_DYN_MORT: 3096 in 124 pages
# Total elements of SH_IHR_CAPS: 6825 in 273 pages
# Observations  SH_BLD_MRSA 160
# Observations  SH_DYN_IMRT 3096
# Observations  SH_DYN_IMRTN 3096
# Observations  SH_DYN_MORT 3096
# Observations  SH_IHR_CAPS 6825
# Total elements of SH_MED_HWRKDIS: 2002 in 81 pages
# Total elements of SH_MED_DEN: 3662 in 147 pages
# Total elements of SH_STA_TRAFN: 43 in 2 pages
# Total elements of SH_BLD_ECOLI: 156 in 7 pages
# Total elements of SH_STA_TRAF: 43 in 2 pages
# Observations  SH_STA_TRAFN 43
# Observations  SH_STA_TRAF 43
# Observations  SH_BLD_ECOLI 156
# Observations  SH_MED_HWRKDIS 2002
# Observations  SH_MED_DEN 3662
# Total elements of SH_STA_MALR: 0 in 0 pages
# Total elements of SH_XPD_EARN25: 332 in 14 pages
# Total elements of SH_XPD_EARN10: 332 in 14 pages
# Total elements of SH_ACS_UNHC: 301 in 13 pages
# Observations  SH_STA_MALR 0
# Total elements of SH_TBS_INCD: 1022 in 41 pages
# Observations  SH_ACS_UNHC 301
# Observations  SH_XPD_EARN10 332
# Observations  SH_XPD_EARN25 332
# Observations  SH_TBS_INCD 1022
# Total elements of SH_TRP_INTVN: 602 in 25 pages
# Total elements of SH_HAP_HBSAG: 43 in 2 pages
# Total elements of SH_HIV_INCD: 12480 in 500 pages
# Observations  SH_HAP_HBSAG 43
# Observations  SH_TRP_INTVN 602
# Observations  SH_HIV_INCD 8062
# Collect data : 2.3184816002845765 minutes
# Data/2.UN_observations/observations3.json created
# Goal 4
# Total elements of SE_GCEDESD_CUR: 81 in 4 pages
# Total elements of SE_GCEDESD_SAS: 81 in 4 pages
# Total elements of SE_GCEDESD_TED: 81 in 4 pages
# Total elements of SE_TOT_PRFL: 2110 in 85 pages
# Observations  SE_GCEDESD_SAS 81
# Observations  SE_GCEDESD_CUR 81
# Observations  SE_GCEDESD_TED 81
# Total elements of SE_TOT_CPLR: 13120 in 525 pages
# Observations  SE_TOT_PRFL 2110
# Observations  SE_TOT_CPLR 13120
# Total elements of SE_GCEDESD_NEP: 90 in 4 pages
# Total elements of SE_DEV_ONTRKWB: 0 in 0 pages
# Total elements of SE_DEV_ONTRK: 21 in 1 pages
# Total elements of SE_PRE_PARTN: 2414 in 97 pages
# Observations  SE_GCEDESD_NEP 90
# Observations  SE_DEV_ONTRKWB 0
# Total elements of SE_TRA_GRDL: 1825 in 73 pages
# Observations  SE_DEV_ONTRK 21
# Observations  SE_TRA_GRDL 1825
# Observations  SE_PRE_PARTN 2414
# Total elements of SE_INF_DSBL: 322 in 13 pages
# Total elements of SE_ACS_CMPTR: 1481 in 60 pages
# Total elements of SE_ACS_ELECT: 1218 in 49 pages
# Total elements of SE_ADT_ACTS: 67930 in 2718 pages
# Total elements of SE_ADT_FUNS: 138 in 6 pages
# Observations  SE_ADT_FUNS 138
# Observations  SE_INF_DSBL 322
# Observations  SE_ACS_ELECT 1218
# Observations  SE_ACS_CMPTR 1481
# Observations  SE_ADT_ACTS 67930
# Total elements of SE_ACC_HNDWSH: 1205 in 49 pages
# Total elements of SE_ACS_H2O: 1187 in 48 pages
# Total elements of SE_ACS_INTNT: 1391 in 56 pages
# Total elements of DC_TOF_SCHIPSL: 149 in 6 pages
# Total elements of SE_ACS_SANIT: 1115 in 45 pages
# Observations  DC_TOF_SCHIPSL 149
# Observations  SE_ACS_SANIT 1115
# Observations  SE_ACC_HNDWSH 1205
# Observations  SE_ACS_H2O 1187
# Observations  SE_ACS_INTNT 1391
# Total elements of SE_IMP_FPOF: 44 in 2 pages
# Total elements of SE_TOT_GPI_FS: 46 in 2 pages
# Total elements of SE_TOT_RUPI: 488 in 20 pages
# Total elements of SE_ADT_EDUCTRN: 8716 in 349 pages
# Total elements of SE_GPI_TCAQ: 573 in 23 pages
# Observations  SE_IMP_FPOF 44
# Observations  SE_TOT_GPI_FS 46
# Observations  SE_TOT_RUPI 488
# Observations  SE_GPI_TCAQ 573
# Observations  SE_ADT_EDUCTRN 8716
# Total elements of SE_GPI_ICTS: 5946 in 238 pages
# Total elements of SE_NAP_ACHI: 573 in 23 pages
# Total elements of SE_TOT_SESPI_FS: 46 in 2 pages
# Total elements of SE_GPI_PART: 2849 in 114 pages
# Total elements of SE_TOT_GPI: 670 in 27 pages
# Observations  SE_TOT_SESPI_FS 46
# Observations  SE_NAP_ACHI 573
# Observations  SE_TOT_GPI 670
# Observations  SE_GPI_PART 2849
# Observations  SE_GPI_ICTS 5946
# Total elements of SE_TOT_SESPI: 651 in 27 pages
# Total elements of SE_LGP_ACHI: 654 in 27 pages
# Total elements of SE_GPI_PTNPRE: 798 in 32 pages
# Total elements of SE_AGP_CPRA: 2024 in 81 pages
# Total elements of SE_ALP_CPLR: 1961 in 79 pages
# Observations  SE_LGP_ACHI 654
# Observations  SE_TOT_SESPI 651
# Observations  SE_GPI_PTNPRE 798
# Observations  SE_ALP_CPLR 1961
# Observations  SE_AGP_CPRA 2024
# Total elements of SE_AWP_CPRA: 474 in 19 pages
# Observations  SE_AWP_CPRA 474
# Collect data : 6.512226474285126 minutes
# Data/2.UN_observations/observations4.json created
# Goal 5
# Total elements of IC_GEN_MGTN: 828 in 34 pages
# Total elements of IC_GEN_MGTN_19ICLS: 301 in 13 pages
# Total elements of IC_GEN_MGTL_19ICLS: 331 in 14 pages
# Total elements of SG_GEN_LOCGELS: 152 in 7 pages
# Total elements of IC_GEN_MGTL: 922 in 37 pages
# Observations  IC_GEN_MGTN_19ICLS 301
# Observations  IC_GEN_MGTL_19ICLS 331
# Observations  SG_GEN_LOCGELS 151
# Observations  IC_GEN_MGTN 828
# Observations  IC_GEN_MGTL 922
# Total elements of SG_GEN_EQPWN: 0 in 0 pages
# Total elements of SG_GEN_EQPWNN: 28 in 2 pages
# Total elements of SG_GEN_PARLNT: 220 in 9 pages
# Observations  SG_GEN_EQPWN 0
# Total elements of SG_GEN_PARL: 1130 in 46 pages
# Total elements of SG_GEN_PARLN: 1130 in 46 pages
# Observations  SG_GEN_EQPWNN 28
# Observations  SG_GEN_PARLNT 220
# Observations  SG_GEN_PARL 1130
# Observations  SG_GEN_PARLN 1130
# Total elements of SG_LGL_GENEQLFP: 130 in 6 pages
# Total elements of SL_DOM_TSPDDC: 1158 in 47 pages
# Total elements of SL_DOM_TSPDCW: 1118 in 45 pages
# Total elements of VC_VAW_MARR: 76 in 4 pages
# Total elements of SL_DOM_TSPD: 1163 in 47 pages
# Observations  SG_LGL_GENEQLFP 130
# Observations  VC_VAW_MARR 76
# Observations  SL_DOM_TSPDCW 1118
# Observations  SL_DOM_TSPDDC 1158
# Observations  SL_DOM_TSPD 1163
# Total elements of SG_LGL_GENEQEMP: 130 in 6 pages
# Total elements of SP_DYN_MRBF15: 13 in 1 pages
# Total elements of SG_LGL_GENEQVAW: 130 in 6 pages
# Total elements of SG_LGL_GENEQMAR: 130 in 6 pages
# Total elements of IT_MOB_OWN: 406 in 17 pages
# Observations  SP_DYN_MRBF15 13
# Observations  SG_LGL_GENEQMAR 130
# Observations  SG_LGL_GENEQEMP 130
# Observations  SG_LGL_GENEQVAW 130
# Observations  IT_MOB_OWN 406
# Total elements of SH_STA_FGMS: 0 in 0 pages
# Total elements of SH_LGR_ACSRHEC12: 34 in 2 pages
# Total elements of SH_LGR_ACSRHEC1: 34 in 2 pages
# Total elements of SP_DYN_MRBF18: 16 in 1 pages
# Total elements of SH_LGR_ACSRHEC13: 34 in 2 pages
# Observations  SH_STA_FGMS 0
# Observations  SH_LGR_ACSRHEC1 33
# Observations  SH_LGR_ACSRHEC12 34
# Observations  SP_DYN_MRBF18 16
# Observations  SH_LGR_ACSRHEC13 34
# Total elements of SH_LGR_ACSRHEC11: 34 in 2 pages
# Total elements of SH_LGR_ACSRHES4: 34 in 2 pages
# Total elements of SH_LGR_ACSRHEC5: 34 in 2 pages
# Total elements of SH_LGR_ACSRHES3: 34 in 2 pages
# Total elements of SH_LGR_ACSRHES1: 34 in 2 pages
# Observations  SH_LGR_ACSRHES3 31
# Observations  SH_LGR_ACSRHES1 30
# Observations  SH_LGR_ACSRHEC11 34
# Observations  SH_LGR_ACSRHES4 34
# Observations  SH_LGR_ACSRHEC5 34
# Total elements of SH_LGR_ACSRHEC6: 34 in 2 pages
# Total elements of SH_LGR_ACSRHE: 34 in 2 pages
# Total elements of SH_LGR_ACSRHEC2: 34 in 2 pages
# Total elements of SH_LGR_ACSRHEC3: 34 in 2 pages
# Total elements of SH_LGR_ACSRHEC10: 34 in 2 pages
# Observations  SH_LGR_ACSRHEC10 34
# Observations  SH_LGR_ACSRHEC6 34
# Observations  SH_LGR_ACSRHEC3 31
# Observations  SH_LGR_ACSRHE 28
# Observations  SH_LGR_ACSRHEC2 33
# Total elements of SH_LGR_ACSRHEC4: 34 in 2 pages
# Total elements of SH_LGR_ACSRHEC9: 34 in 2 pages
# Total elements of SH_LGR_ACSRHES2: 34 in 2 pages
# Total elements of SH_LGR_ACSRHEC8: 34 in 2 pages
# Total elements of SH_LGR_ACSRHEC7: 34 in 2 pages
# Observations  SH_LGR_ACSRHEC7 32
# Observations  SH_LGR_ACSRHEC8 33
# Observations  SH_LGR_ACSRHEC4 34
# Observations  SH_LGR_ACSRHEC9 32
# Observations  SH_LGR_ACSRHES2 32
# Total elements of SH_FPL_INFMCU: 11 in 1 pages
# Total elements of SG_LGL_LNDFEMOD: 108 in 5 pages
# Total elements of SH_FPL_INFMSR: 11 in 1 pages
# Total elements of SH_FPL_INFMRH: 11 in 1 pages
# Total elements of SH_FPL_INFM: 11 in 1 pages
# Observations  SH_FPL_INFMRH 11
# Observations  SH_FPL_INFMSR 11
# Observations  SH_FPL_INFM 11
# Observations  SH_FPL_INFMCU 11
# Observations  SG_LGL_LNDFEMOD 18
# Total elements of SP_GNP_WNOWNS: 15 in 1 pages
# Total elements of SP_LGL_LNDAGSEC: 45 in 2 pages
# Observations  SP_GNP_WNOWNS 1
# Observations  SP_LGL_LNDAGSEC 3
# Collect data : 0.3512820482254028 minutes
# Data/2.UN_observations/observations5.json created
# Goal 6
# Total elements of EN_WWT_WWDS: 134 in 6 pages
# Total elements of EN_WWT_TREATR: 56 in 3 pages
# Total elements of EN_WWT_TREAT: 62 in 3 pages
# Total elements of EN_WWT_TREAT_SF: 62 in 3 pages
# Total elements of EN_WWT_TREATR_SF: 30 in 2 pages
# Observations  EN_WWT_TREATR_SF 23
# Observations  EN_WWT_TREATR 39
# Observations  EN_WWT_TREAT 44
# Observations  EN_WWT_TREAT_SF 25
# Observations  EN_WWT_WWDS 134
# Total elements of EN_H2O_OPAMBQ: 85 in 4 pages
# Total elements of EN_H2O_GRAMBQ: 92 in 4 pages
# Total elements of EN_H2O_WBAMBQ: 112 in 5 pages
# Total elements of EN_H2O_RVAMBQ: 107 in 5 pages
# Total elements of EN_WWT_GEN: 385 in 16 pages
# Observations  EN_H2O_OPAMBQ 85
# Observations  EN_H2O_RVAMBQ 107
# Observations  EN_H2O_GRAMBQ 92
# Observations  EN_H2O_WBAMBQ 112
# Observations  EN_WWT_GEN 252
# Total elements of EN_WBE_INWTL: 30 in 2 pages
# Total elements of EN_RSRV_MNWAC: 805 in 33 pages
# Total elements of EN_LKRV_SWAC: 846 in 34 pages
# Total elements of EN_RSRV_MXWAP: 1035 in 42 pages
# Total elements of EN_LKRV_PWAN: 1127 in 46 pages
# Observations  EN_WBE_INWTL 30
# Observations  EN_RSRV_MNWAC 805
# Observations  EN_RSRV_MXWAP 1035
# Observations  EN_LKRV_SWAC 846
# Observations  EN_LKRV_PWAN 1127
# Total elements of EN_WBE_MANGN: 0 in 0 pages
# Total elements of EN_LKRV_PWAP: 1012 in 41 pages
# Total elements of EN_RSRV_MXWAN: 1127 in 46 pages
# Total elements of EN_WBE_WTLN: 49 in 2 pages
# Total elements of EN_LKRV_PWAC: 846 in 34 pages
# Observations  EN_WBE_MANGN 0
# Observations  EN_WBE_WTLN 49
# Observations  EN_LKRV_PWAC 846
# Observations  EN_RSRV_MXWAN 1127
# Observations  EN_LKRV_PWAP 1012
# Total elements of EN_RVR_MXRVFLC: 980 in 40 pages
# Total elements of EN_WBE_NDQTGRW: 12 in 1 pages
# Total elements of EN_WBE_WTLP: 46 in 2 pages
# Total elements of EN_LKRV_SWAN: 1127 in 46 pages
# Total elements of EN_LKW_QLTRB: 640 in 26 pages
# Observations  EN_WBE_NDQTGRW 3
# Observations  EN_WBE_WTLP 46
# Observations  EN_LKW_QLTRB 640
# Observations  EN_RVR_MXRVFLC 980
# Observations  EN_LKRV_SWAN 1127
# Total elements of EN_RVR_MNRVFLC: 980 in 40 pages
# Total elements of EN_WBE_NDQTRVR: 12 in 1 pages
# Total elements of EN_LKW_QLTRST: 640 in 26 pages
# Total elements of EN_RSRV_MNWAP: 1035 in 42 pages
# Total elements of EN_RSRV_MNWAN: 1127 in 46 pages
# Observations  EN_WBE_NDQTRVR 8
# Observations  EN_LKW_QLTRST 640
# Observations  EN_RSRV_MNWAN 1127
# Observations  EN_RVR_MNRVFLC 980
# Observations  EN_RSRV_MNWAP 1035
# Total elements of EN_WBE_MANGC: 0 in 0 pages
# Total elements of EN_WBE_HMWTL: 10 in 1 pages
# Total elements of EN_LKRV_SWAP: 1012 in 41 pages
# Total elements of EN_RVR_MXRVFLN: 980 in 40 pages
# Total elements of EN_RVR_MNRVFLN: 980 in 40 pages
# Observations  EN_WBE_MANGC 0
# Observations  EN_WBE_HMWTL 10
# Observations  EN_RVR_MXRVFLN 980
# Observations  EN_RVR_MNRVFLN 980
# Observations  EN_LKRV_SWAP 1012
# Total elements of DC_TOF_WASHL: 191 in 8 pages
# Total elements of SH_SAN_DEFECT: 2918 in 117 pages
# Total elements of SH_SAN_SAFE: 2067 in 83 pages
# Total elements of ER_WAT_PART: 38 in 2 pages
# Total elements of SH_SAN_HNDWSH: 177 in 8 pages
# Observations  ER_WAT_PART 38
# Observations  SH_SAN_HNDWSH 177
# Observations  DC_TOF_WASHL 191
# Observations  SH_SAN_SAFE 2067
# Observations  SH_SAN_DEFECT 2918
# Total elements of ER_WAT_PROCED: 0 in 0 pages
# Total elements of ER_WAT_PARTIC: 0 in 0 pages
# Total elements of ER_H2O_RURP: 45 in 2 pages
# Total elements of ER_WAT_PRDU: 38 in 2 pages
# Total elements of ER_H2O_PRDU: 45 in 2 pages
# Observations  ER_WAT_PROCED 0
# Observations  ER_WAT_PARTIC 0
# Observations  ER_WAT_PRDU 38
# Observations  ER_H2O_RURP 45
# Observations  ER_H2O_PRDU 45
# Total elements of ER_H2O_PROCED: 0 in 0 pages
# Total elements of ER_H2O_PARTIC: 0 in 0 pages
# Total elements of EG_TBA_H2CO: 156 in 7 pages
# Total elements of EG_TBA_H2COAQ: 156 in 7 pages
# Total elements of EG_TBA_H2CORL: 156 in 7 pages
# Observations  ER_H2O_PROCED 0
# Observations  ER_H2O_PARTIC 0
# Observations  EG_TBA_H2CO 103
# Observations  EG_TBA_H2CORL 112
# Observations  EG_TBA_H2COAQ 92
# Total elements of ER_H2O_IWRMD_MI: 131 in 6 pages
# Total elements of ER_H2O_IWRMD: 131 in 6 pages
# Total elements of ER_H2O_IWRMD_EE: 131 in 6 pages
# Total elements of ER_H2O_IWRMD_IP: 131 in 6 pages
# Total elements of ER_H2O_IWRMD_FI: 130 in 6 pages
# Observations  ER_H2O_IWRMD_FI 130
# Observations  ER_H2O_IWRMD_IP 131
# Observations  ER_H2O_IWRMD_MI 131
# Observations  ER_H2O_IWRMD 131
# Observations  ER_H2O_IWRMD_EE 131
# Total elements of ER_H2O_IWRMP: 0 in 0 pages
# Total elements of ER_H2O_WUEYST: 3680 in 148 pages
# Total elements of SH_H2O_SAFE: 1646 in 66 pages
# Total elements of ER_H2O_STRESS: 3519 in 141 pages
# Observations  ER_H2O_IWRMP 0
# Observations  SH_H2O_SAFE 1646
# Observations  ER_H2O_STRESS 3445
# Observations  ER_H2O_WUEYST 3327
# Collect data : 0.8352775136629741 minutes
# Data/2.UN_observations/observations6.json created
# Goal 7
# Total elements of EG_FEC_RNEW: 1081 in 44 pages
# Total elements of EG_ACS_ELEC: 3384 in 136 pages
# Total elements of EG_EGY_CLEAN: 3048 in 122 pages
# Total elements of EG_IFF_RANDN: 1536 in 62 pages
# Total elements of EG_EGY_RNEW: 14112 in 565 pages
# Observations  EG_FEC_RNEW 1074
# Observations  EG_IFF_RANDN 1536
# Observations  EG_ACS_ELEC 3371
# Observations  EG_EGY_CLEAN 3024
# Observations  EG_EGY_RNEW 14112
# Total elements of EG_EGY_PRIM: 1081 in 44 pages
# Observations  EG_EGY_PRIM 961
# Collect data : 0.8199737111727396 minutes
# Data/2.UN_observations/observations7.json created
# Goal 8
# Total elements of EN_MAT_FTPRTN: 0 in 0 pages
# Total elements of EN_MAT_FTPRPG: 0 in 0 pages
# Total elements of EN_MAT_FTPRPC: 0 in 0 pages
# Observations  EN_MAT_FTPRTN 0
# Observations  EN_MAT_FTPRPG 0
# Observations  EN_MAT_FTPRPC 0
# Total elements of EN_MAT_DOMCMPC: 34716 in 1389 pages
# Total elements of EN_MAT_DOMCMPG: 33196 in 1328 pages
# Observations  EN_MAT_DOMCMPG 33196
# Observations  EN_MAT_DOMCMPC 34716
# Total elements of EN_MAT_DOMCMPT: 35212 in 1409 pages
# Total elements of FB_CBK_BRCH: 777 in 32 pages
# Total elements of FB_BNK_ACCSS: 1372 in 55 pages
# Total elements of FB_BNK_ACCSS_OLF: 149 in 6 pages
# Total elements of FB_BNK_ACCSS_ILF: 149 in 6 pages
# Observations  FB_BNK_ACCSS_OLF 149
# Observations  FB_BNK_ACCSS_ILF 149
# Observations  FB_CBK_BRCH 777
# Observations  FB_BNK_ACCSS 1372
# Observations  EN_MAT_DOMCMPT 35212
# Total elements of FB_ATM_TOTL: 784 in 32 pages
# Total elements of DC_TOF_TRDDBMDL: 442 in 18 pages
# Total elements of DC_TOF_TRDCMDL: 442 in 18 pages
# Total elements of SL_ISV_IFEM_19ICLS: 2335 in 94 pages
# Total elements of SL_ISV_IFEM: 4570 in 183 pages
# Observations  DC_TOF_TRDDBMDL 442
# Observations  DC_TOF_TRDCMDL 442
# Observations  FB_ATM_TOTL 784
# Observations  SL_ISV_IFEM_19ICLS 2335
# Observations  SL_ISV_IFEM 4570
# Total elements of DC_TOF_TRDCML: 149 in 6 pages
# Total elements of DC_TOF_TRDDBML: 149 in 6 pages
# Total elements of SL_LBR_NTLCPL: 369 in 15 pages
# Total elements of SL_EMP_FTLINJUR: 1709 in 69 pages
# Total elements of SL_EMP_INJUR: 1695 in 68 pages
# Observations  DC_TOF_TRDDBML 149
# Observations  DC_TOF_TRDCML 149
# Observations  SL_LBR_NTLCPL 369
# Observations  SL_EMP_INJUR 1695
# Observations  SL_EMP_FTLINJUR 1709
# Total elements of NY_GDP_PCAP: 1056 in 43 pages
# Total elements of SL_EMP_PCAP: 997 in 40 pages
# Total elements of SL_CPA_YEMP: 158 in 7 pages
# Total elements of SL_TLF_UEMDIS_19ICLS: 2607 in 105 pages
# Total elements of SL_TLF_UEMDIS: 5275 in 211 pages
# Observations  SL_CPA_YEMP 158
# Observations  NY_GDP_PCAP 1056
# Observations  SL_EMP_PCAP 997
# Observations  SL_TLF_UEMDIS_19ICLS 2607
# Observations  SL_TLF_UEMDIS 5275
# Total elements of SL_TLF_UEM: 8331 in 334 pages
# Total elements of SL_TLF_UEM_19ICLS: 2984 in 120 pages
# Total elements of SL_TLF_NEET_19ICLS: 975 in 39 pages
# Total elements of SL_TLF_NEET: 2577 in 104 pages
# Total elements of SL_EMP_EARN: 8329 in 334 pages
# Observations  SL_TLF_NEET_19ICLS 975
# Observations  SL_TLF_NEET 2577
# Observations  SL_TLF_UEM_19ICLS 2984
# Observations  SL_EMP_EARN 8329
# Observations  SL_TLF_UEM 8331
# Total elements of ST_GDP_ZS: 337 in 14 pages
# Total elements of ST_EMP_TRSMN: 451 in 19 pages
# Total elements of SL_TLF_CHLDEC: 18 in 1 pages
# Total elements of SL_TLF_CHLDEA: 18 in 1 pages
# Observations  SL_TLF_CHLDEA 18
# Observations  SL_TLF_CHLDEC 18
# Observations  ST_GDP_ZS 337
# Observations  ST_EMP_TRSMN 451
# Collect data : 4.506284002463023 minutes
# Data/2.UN_observations/observations8.json created
# Goal 9
# Total elements of IT_MOB_5GNTWK: 1176 in 48 pages
# Total elements of IT_MOB_2GNTWK: 976 in 40 pages
# Total elements of IT_MOB_4GNTWK: 521 in 21 pages
# Total elements of EN_ATM_CO2GDP: 920 in 37 pages
# Total elements of IT_MOB_3GNTWK: 667 in 27 pages
# Observations  IT_MOB_4GNTWK 521
# Observations  IT_MOB_3GNTWK 667
# Observations  EN_ATM_CO2GDP 915
# Observations  IT_MOB_2GNTWK 976
# Observations  IT_MOB_5GNTWK 146
# Total elements of IS_RDP_LULFRG: 0 in 0 pages
# Total elements of IS_RDP_PFVOL: 224 in 9 pages
# Total elements of EN_ATM_CO2MVA: 915 in 37 pages
# Total elements of IS_RDP_PORFVOL: 400 in 16 pages
# Total elements of EN_ATM_CO2: 1886 in 76 pages
# Observations  IS_RDP_LULFRG 0
# Observations  IS_RDP_PFVOL 224
# Observations  IS_RDP_PORFVOL 400
# Observations  EN_ATM_CO2MVA 915
# Observations  EN_ATM_CO2 1875
# Total elements of SP_ROD_R2KM: 0 in 0 pages
# Total elements of DC_TOF_INFRAL: 194 in 8 pages
# Total elements of GB_XPD_RSDV: 863 in 35 pages
# Total elements of IS_RDP_FRGVOL: 214 in 9 pages
# Total elements of GB_POP_SCIERD: 798 in 32 pages
# Observations  SP_ROD_R2KM 0
# Observations  IS_RDP_FRGVOL 214
# Observations  DC_TOF_INFRAL 194
# Observations  GB_XPD_RSDV 863
# Observations  GB_POP_SCIERD 798
# Total elements of NV_IND_MANFPC: 1100 in 44 pages
# Total elements of NV_IND_TECH: 842 in 34 pages
# Total elements of NV_IND_MANF_CD: 1056 in 43 pages
# Total elements of SL_TLF_MANF_19ICLS: 329 in 14 pages
# Total elements of NV_IND_MANF: 1100 in 44 pages
# Observations  SL_TLF_MANF_19ICLS 329
# Observations  NV_IND_TECH 842
# Observations  NV_IND_MANFPC 1100
# Observations  NV_IND_MANF_CD 1056
# Observations  NV_IND_MANF 1100
# Total elements of NV_IND_SSIS: 695 in 28 pages
# Total elements of FC_ACC_SSID: 93 in 4 pages
# Total elements of NV_IND_SSIS_NC: 580 in 24 pages
# Total elements of SL_TLF_MANF: 937 in 38 pages
# Observations  FC_ACC_SSID 93
# Observations  NV_IND_SSIS_NC 580
# Observations  NV_IND_SSIS 695
# Observations  SL_TLF_MANF 937
# Collect data : 0.39581472873687745 minutes
# Data/2.UN_observations/observations9.json created
# Goal 10
# Total elements of SI_HEI_TOTL: 76 in 4 pages
# Total elements of SL_EMP_GTOTL: 714 in 29 pages
# Total elements of TM_TRF_ZERO: 3235 in 130 pages
# Total elements of SI_DST_FISP: 753 in 31 pages
# Total elements of SI_RMT_COST_SC: 1213 in 49 pages
# Observations  SI_HEI_TOTL 76
# Observations  SL_EMP_GTOTL 714
# Observations  SI_DST_FISP 518
# Observations  SI_RMT_COST_SC 1155
# Observations  TM_TRF_ZERO 3235
# Total elements of SI_RMT_COST_SND: 126 in 6 pages
# Total elements of SI_RMT_COST: 132 in 6 pages
# Total elements of SI_POV_50MI: 1000 in 40 pages
# Total elements of SI_RMT_COST_BC: 1213 in 49 pages
# Total elements of VC_VOV_GDSD: 3412 in 137 pages
# Observations  SI_RMT_COST 126
# Observations  SI_RMT_COST_SND 119
# Observations  SI_POV_50MI 1000
# Observations  SI_RMT_COST_BC 1187
# Observations  VC_VOV_GDSD 3412
# Total elements of SG_CPA_MIGRP: 0 in 0 pages
# Total elements of SM_DTH_MIGR: 175 in 7 pages
# Total elements of SM_POP_REFG_OR: 1150 in 46 pages
# Total elements of SG_CPA_MIGRS: 483 in 20 pages
# Total elements of SL_EMP_RCOST_MO: 0 in 0 pages
# Observations  SG_CPA_MIGRP 0
# Observations  SL_EMP_RCOST_MO 0
# Observations  SM_DTH_MIGR 175
# Series: SG_CPA_MIGRS value
# N
# Series: SG_CPA_MIGRS value
# N
# Series: SG_CPA_MIGRS value
# N
# Series: SG_CPA_MIGRS value
# N
# Series: SG_CPA_MIGRS value
# N
# Series: SG_CPA_MIGRS value
# N
# Series: SG_CPA_MIGRS value
# N
# Series: SG_CPA_MIGRS value
# N
# Series: SG_CPA_MIGRS value
# N
# Series: SG_CPA_MIGRS value
# N
# Series: SG_CPA_MIGRS value
# N
# Series: SG_CPA_MIGRS value
# N
# Series: SG_CPA_MIGRS value
# N
# Series: SG_CPA_MIGRS value
# N
# Series: SG_CPA_MIGRS value
# N
# Series: SG_CPA_MIGRS value
# N
# Series: SG_CPA_MIGRS value
# N
# Series: SG_CPA_MIGRS value
# N
# Series: SG_CPA_MIGRS value
# N
# Series: SG_CPA_MIGRS value
# N
# Series: SG_CPA_MIGRS value
# N
# Series: SG_CPA_MIGRS value
# N
# Series: SG_CPA_MIGRS value
# N
# Series: SG_CPA_MIGRS value
# N
# Series: SG_CPA_MIGRS value
# N
# Series: SG_CPA_MIGRS value
# N
# Series: SG_CPA_MIGRS value
# N
# Series: SG_CPA_MIGRS value
# N
# Series: SG_CPA_MIGRS value
# N
# Series: SG_CPA_MIGRS value
# N
# Series: SG_CPA_MIGRS value
# N
# Series: SG_CPA_MIGRS value
# N
# Series: SG_CPA_MIGRS value
# N
# Series: SG_CPA_MIGRS value
# N
# Series: SG_CPA_MIGRS value
# N
# Series: SG_CPA_MIGRS value
# N
# Series: SG_CPA_MIGRS value
# N
# Series: SG_CPA_MIGRS value
# N
# Series: SG_CPA_MIGRS value
# N
# Series: SG_CPA_MIGRS value
# N
# Series: SG_CPA_MIGRS value
# N
# Series: SG_CPA_MIGRS value
# N
# Series: SG_CPA_MIGRS value
# N
# Series: SG_CPA_MIGRS value
# N
# Series: SG_CPA_MIGRS value
# N
# Series: SG_CPA_MIGRS value
# N
# Series: SG_CPA_MIGRS value
# N
# Series: SG_CPA_MIGRS value
# N
# Series: SG_CPA_MIGRS value
# N
# Observations  SG_CPA_MIGRS 483
# Exceptions SG_CPA_MIGRS 49
# Observations  SM_POP_REFG_OR 1150
# Total elements of FI_FSI_FSERA: 653 in 27 pages
# Total elements of FI_FSI_FSKNL: 592 in 24 pages
# Total elements of FI_FSI_FSSNO: 499 in 20 pages
# Total elements of FI_FSI_FSKRTC: 659 in 27 pages
# Total elements of FI_FSI_FSANL: 630 in 26 pages
# Observations  FI_FSI_FSSNO 499
# Observations  FI_FSI_FSKNL 592
# Observations  FI_FSI_FSERA 653
# Observations  FI_FSI_FSKRTC 659
# Observations  FI_FSI_FSANL 630
# Total elements of DC_TRF_TFDV: 0 in 0 pages
# Total elements of FI_FSI_FSLS: 589 in 24 pages
# Total elements of DC_TRF_TOTL: 196 in 8 pages
# Total elements of FI_FSI_FSKA: 623 in 25 pages
# Total elements of DC_TRF_TOTDL: 750 in 30 pages
# Observations  DC_TRF_TFDV 0
# Observations  DC_TRF_TOTL 196
# Observations  FI_FSI_FSLS 589
# Observations  FI_FSI_FSKA 623
# Observations  DC_TRF_TOTDL 750
# Total elements of SG_INT_MBRDEV: 6566 in 263 pages
# Total elements of SG_INT_VRTDEV: 6566 in 263 pages
# Observations  SG_INT_VRTDEV 6566
# Observations  SG_INT_MBRDEV 6566
# Collect data : 0.9052310109138488 minutes
# Data/2.UN_observations/observations10.json created
# Goal 11
# Total elements of VC_DSR_PDAN: 762 in 31 pages
# Total elements of VC_DSR_PDLN: 543 in 22 pages
# Total elements of VC_DSR_MTMP: 1176 in 48 pages
# Total elements of VC_DSR_AFFCT: 987 in 40 pages
# Total elements of VC_DSR_DAFF: 987 in 40 pages
# Observations  VC_DSR_PDLN 543
# Observations  VC_DSR_PDAN 762
# Observations  VC_DSR_AFFCT 987
# Observations  VC_DSR_MTMP 1176
# Observations  VC_DSR_DAFF 987
# Total elements of VC_DSR_MORT: 1167 in 47 pages
# Total elements of VC_DSR_MISS: 576 in 24 pages
# Total elements of VC_DSR_PDYN: 621 in 25 pages
# Total elements of VC_DSR_MMHN: 1176 in 48 pages
# Total elements of VC_DSR_IJILN: 912 in 37 pages
# Observations  VC_DSR_MISS 576
# Observations  VC_DSR_PDYN 621
# Observations  VC_DSR_MMHN 1176
# Observations  VC_DSR_MORT 1167
# Observations  VC_DSR_IJILN 912
# Total elements of VC_DSR_BSDN: 132 in 6 pages
# Total elements of VC_DSR_ESDN: 112 in 5 pages
# Total elements of VC_DSR_EFDN: 130 in 6 pages
# Total elements of VC_DSR_HFDN: 125 in 5 pages
# Total elements of VC_DSR_CDAN: 140 in 6 pages
# Observations  VC_DSR_ESDN 112
# Observations  VC_DSR_EFDN 130
# Observations  VC_DSR_BSDN 132
# Observations  VC_DSR_HFDN 125
# Observations  VC_DSR_CDAN 140
# Total elements of VC_DSR_CDYN: 99 in 4 pages
# Total elements of VC_DSR_HSDN: 111 in 5 pages
# Total elements of VC_DSR_OBDN: 101 in 5 pages
# Total elements of VC_DSR_CHLN: 262 in 11 pages
# Total elements of VC_DSR_AGLH: 322 in 13 pages
# Observations  VC_DSR_OBDN 101
# Observations  VC_DSR_HSDN 111
# Observations  VC_DSR_CDYN 99
# Observations  VC_DSR_CHLN 262
# Observations  VC_DSR_AGLH 322
# Total elements of VC_DSR_DDPA: 306 in 13 pages
# Total elements of VC_DSR_CILN: 374 in 15 pages
# Total elements of VC_DSR_GDPLS: 530 in 22 pages
# Total elements of VC_DSR_HOLH: 498 in 20 pages
# Total elements of VC_DSR_LSGP: 530 in 22 pages
# Observations  VC_DSR_DDPA 306
# Observations  VC_DSR_CILN 374
# Observations  VC_DSR_GDPLS 530
# Observations  VC_DSR_HOLH 498
# Observations  VC_DSR_LSGP 530
# Total elements of VC_VOH_SXPH: 16 in 1 pages
# Total elements of SG_URB_CSPART: 255 in 11 pages
# Observations  VC_VOH_SXPH 16
# Total elements of EN_LND_CNSPOP: 1292 in 52 pages
# Total elements of EN_URB_OPENSP: 1051 in 43 pages
# Total elements of EN_ACS_URB_OPENSP: 254 in 11 pages
# Observations  SG_URB_CSPART 255
# Observations  EN_ACS_URB_OPENSP 254
# Observations  EN_URB_OPENSP 1051
# Observations  EN_LND_CNSPOP 1292
# Total elements of SG_DSR_SFDRR: 0 in 0 pages
# Total elements of SG_DSR_LGRGSR: 510 in 21 pages
# Total elements of SG_GOV_LOGV: 561 in 23 pages
# Total elements of SG_DSR_SILN: 537 in 22 pages
# Total elements of SG_DSR_SILS: 528 in 22 pages
# Observations  SG_DSR_SFDRR 0
# Observations  SG_DSR_LGRGSR 510
# Observations  SG_GOV_LOGV 561
# Observations  SG_DSR_SILN 537
# Observations  SG_DSR_SILS 528
# Total elements of SD_CPA_UPRDP: 104 in 5 pages
# Total elements of GB_XPD_CULNAT_PBPV: 67 in 3 pages
# Total elements of GB_XPD_CUL_PBPV: 58 in 3 pages
# Total elements of EN_LND_SLUM: 479 in 20 pages
# Total elements of EN_LND_INDQTHSNG: 1888 in 76 pages
# Observations  GB_XPD_CULNAT_PBPV 67
# Observations  GB_XPD_CUL_PBPV 58
# Observations  SD_CPA_UPRDP 104
# Observations  EN_LND_SLUM 479
# Observations  EN_LND_INDQTHSNG 1888
# Total elements of GB_XPD_CULNAT_PB: 311 in 13 pages
# Total elements of GB_XPD_NAT_PBPV: 49 in 2 pages
# Total elements of GB_XPD_CULNAT_PV: 71 in 3 pages
# Total elements of EN_ATM_PM25: 2330 in 94 pages
# Observations  GB_XPD_NAT_PBPV 49
# Observations  GB_XPD_CULNAT_PV 71
# Total elements of EN_REF_WASCOL: 636 in 26 pages
# Observations  GB_XPD_CULNAT_PB 311
# Observations  EN_REF_WASCOL 636
# Observations  EN_ATM_PM25 2330
# Total elements of SP_TRN_PUBL: 908 in 37 pages
# Observations  SP_TRN_PUBL 908
# Collect data : 0.7091745535532633 minutes
# Data/2.UN_observations/observations11.json created
# Goal 12
# Total elements of EN_MAT_FTPRTN: 0 in 0 pages
# Total elements of EN_MAT_FTPRPG: 0 in 0 pages
# Total elements of EN_MAT_DOMCMPC: 34716 in 1389 pages
# Total elements of EN_MAT_DOMCMPT: 35212 in 1409 pages
# Observations  EN_MAT_FTPRPG 0
# Observations  EN_MAT_FTPRTN 0
# Total elements of EN_MAT_DOMCMPG: 33196 in 1328 pages
# Observations  EN_MAT_DOMCMPT 35212
# Observations  EN_MAT_DOMCMPG 33196
# Observations  EN_MAT_DOMCMPC 34716
# Total elements of EN_MAT_FTPRPC: 0 in 0 pages
# Total elements of SG_SCP_TOTLN: 22 in 1 pages
# Total elements of SG_SCP_POLINS: 52 in 3 pages
# Observations  EN_MAT_FTPRPC 0
# Observations  SG_SCP_TOTLN 22
# Observations  SG_SCP_POLINS 52
# Total elements of SG_SCP_CNTRY: 22 in 1 pages
# Total elements of EG_EGY_RNEW: 14112 in 565 pages
# Observations  SG_SCP_CNTRY 22
# Observations  EG_EGY_RNEW 14112
# Total elements of SE_GCEDESD_SAS: 81 in 4 pages
# Total elements of SG_SCP_PROCN_HS: 13 in 1 pages
# Total elements of SE_GCEDESD_NEP: 90 in 4 pages
# Total elements of SE_GCEDESD_TED: 81 in 4 pages
# Total elements of SE_GCEDESD_CUR: 81 in 4 pages
# Observations  SE_GCEDESD_SAS 81
# Observations  SG_SCP_PROCN_HS 13
# Observations  SE_GCEDESD_NEP 90
# Observations  SE_GCEDESD_TED 81
# Observations  SE_GCEDESD_CUR 81
# Total elements of AG_FLS_INDEX: 0 in 0 pages
# Total elements of SG_SCP_PROCN_LS: 6 in 1 pages
# Total elements of SG_SCP_PROCN: 44 in 2 pages
# Total elements of AG_FOOD_WST: 603 in 25 pages
# Total elements of AG_FOOD_WST_PC: 603 in 25 pages
# Observations  AG_FLS_INDEX 0
# Observations  SG_SCP_PROCN_LS 6
# Observations  SG_SCP_PROCN 44
# Observations  AG_FOOD_WST_PC 603
# Observations  AG_FOOD_WST 603
# Total elements of AG_FLS_PCT: 0 in 0 pages
# Total elements of SG_HAZ_CMRBASEL: 130 in 6 pages
# Total elements of SG_HAZ_CMRMNMT: 68 in 3 pages
# Total elements of SG_HAZ_CMRROTDAM: 118 in 5 pages
# Total elements of SG_HAZ_CMRMNTRL: 135 in 6 pages
# Observations  AG_FLS_PCT 0
# Observations  SG_HAZ_CMRMNMT 68
# Observations  SG_HAZ_CMRBASEL 130
# Observations  SG_HAZ_CMRROTDAM 118
# Observations  SG_HAZ_CMRMNTRL 135
# Total elements of SG_HAZ_CMRSTHOLM: 125 in 5 pages
# Total elements of EN_MWT_COLLV: 895 in 36 pages
# Total elements of EN_EWT_COLLV: 518 in 21 pages
# Total elements of EN_MWT_TREATR: 2949 in 118 pages
# Total elements of EN_HAZ_TREATV: 1877 in 76 pages
# Observations  SG_HAZ_CMRSTHOLM 125
# Observations  EN_EWT_COLLV 518
# Observations  EN_MWT_COLLV 895
# Observations  EN_HAZ_TREATV 1877
# Observations  EN_MWT_TREATR 2949
# Total elements of EN_EWT_GENV: 48 in 2 pages
# Total elements of EN_MWT_GENV: 833 in 34 pages
# Total elements of EN_EWT_COLLPCAP: 544 in 22 pages
# Total elements of EN_MWT_IMP: 93 in 4 pages
# Total elements of EN_MWT_TREATV: 4347 in 174 pages
# Observations  EN_EWT_GENV 48
# Observations  EN_MWT_IMP 93
# Observations  EN_EWT_COLLPCAP 544
# Observations  EN_MWT_GENV 833
# Observations  EN_MWT_TREATV 4347
# Total elements of EN_EWT_COLLR: 136 in 6 pages
# Total elements of EN_EWT_GENPCAP: 49 in 2 pages
# Total elements of EN_MWT_EXP: 94 in 4 pages
# Total elements of EN_HAZ_IMP: 468 in 19 pages
# Total elements of EN_HAZ_GENV: 453 in 19 pages
# Observations  EN_EWT_GENPCAP 49
# Observations  EN_MWT_EXP 94
# Observations  EN_EWT_COLLR 136
# Observations  EN_HAZ_GENV 453
# Observations  EN_HAZ_IMP 468
# Total elements of EN_HAZ_TRTDISR: 401 in 17 pages
# Total elements of EN_HAZ_PCAP: 452 in 19 pages
# Total elements of EN_HAZ_EXP: 487 in 20 pages
# Total elements of EN_HAZ_TRTDISV: 424 in 17 pages
# Total elements of EN_HAZ_GENGDP: 453 in 19 pages
# Observations  EN_HAZ_GENGDP 453
# Observations  EN_HAZ_TRTDISR 401
# Observations  EN_HAZ_TRTDISV 424
# Observations  EN_HAZ_PCAP 452
# Observations  EN_HAZ_EXP 487
# Total elements of ST_EEV_STDACCT: 651 in 27 pages
# Total elements of ER_FFS_CMPT_CD: 377 in 16 pages
# Total elements of ER_FFS_CMPT_PC_CD: 377 in 16 pages
# Total elements of ER_FFS_CMPT_GDP: 376 in 16 pages
# Total elements of EN_TWT_GENV: 3338 in 134 pages
# Observations  ER_FFS_CMPT_CD 377
# Observations  ER_FFS_CMPT_PC_CD 377
# Observations  ER_FFS_CMPT_GDP 376
# Observations  ST_EEV_STDACCT 651
# Observations  EN_TWT_GENV 3338
# Total elements of EN_MWT_RCYV: 839 in 34 pages
# Total elements of ST_EEV_ACCTSA: 641 in 26 pages
# Total elements of ST_EEV_ACCSEEA: 632 in 26 pages
# Total elements of EN_EWT_RCYPCAP: 540 in 22 pages
# Total elements of EN_EWT_RCYV: 540 in 22 pages
# Observations  EN_EWT_RCYPCAP 540
# Observations  EN_EWT_RCYV 540
# Observations  ST_EEV_ACCSEEA 632
# Observations  ST_EEV_ACCTSA 641
# Observations  EN_MWT_RCYV 839
# Total elements of EN_MWT_RCYR: 818 in 33 pages
# Total elements of EN_EWT_RCYR: 385 in 16 pages
# Total elements of EN_SCP_FRMN: 2220 in 89 pages
# Observations  EN_EWT_RCYR 385
# Observations  EN_MWT_RCYR 818
# Observations  EN_SCP_FRMN 2220
# Collect data : 3.470733924706777 minutes
# Data/2.UN_observations/observations12.json created
# Goal 13
# Total elements of VC_DSR_MISS: 576 in 24 pages
# Total elements of VC_DSR_MORT: 1167 in 47 pages
# Total elements of VC_DSR_AFFCT: 987 in 40 pages
# Total elements of VC_DSR_PDYN: 621 in 25 pages
# Total elements of VC_DSR_MMHN: 1176 in 48 pages
# Observations  VC_DSR_MISS 576
# Observations  VC_DSR_PDYN 621
# Observations  VC_DSR_MMHN 1176
# Observations  VC_DSR_AFFCT 987
# Observations  VC_DSR_MORT 1167
# Total elements of VC_DSR_IJILN: 912 in 37 pages
# Total elements of VC_DSR_PDLN: 543 in 22 pages
# Total elements of VC_DSR_PDAN: 762 in 31 pages
# Total elements of VC_DSR_DAFF: 987 in 40 pages
# Total elements of VC_DSR_MTMP: 1176 in 48 pages
# Observations  VC_DSR_PDLN 543
# Observations  VC_DSR_PDAN 762
# Observations  VC_DSR_IJILN 912
# Observations  VC_DSR_DAFF 987
# Observations  VC_DSR_MTMP 1176
# Total elements of SG_DSR_SFDRR: 0 in 0 pages
# Total elements of SG_DSR_LGRGSR: 510 in 21 pages
# Total elements of SG_DSR_SILS: 528 in 22 pages
# Total elements of SG_DSR_SILN: 537 in 22 pages
# Total elements of SG_GOV_LOGV: 561 in 23 pages
# Observations  SG_DSR_SFDRR 0
# Observations  SG_GOV_LOGV 561
# Observations  SG_DSR_SILN 537
# Observations  SG_DSR_LGRGSR 510
# Observations  SG_DSR_SILS 528
# Total elements of EN_BIUREP_NAIP_DV: 0 in 0 pages
# Total elements of SE_GCEDESD_TED: 81 in 4 pages
# Total elements of SE_GCEDESD_NEP: 90 in 4 pages
# Total elements of SE_GCEDESD_CUR: 81 in 4 pages
# Total elements of SE_GCEDESD_SAS: 81 in 4 pages
# Observations  EN_BIUREP_NAIP_DV 0
# Observations  SE_GCEDESD_NEP 90
# Observations  SE_GCEDESD_TED 81
# Observations  SE_GCEDESD_SAS 81
# Observations  SE_GCEDESD_CUR 81
# Total elements of EN_NAA_PLAN_DV: 0 in 0 pages
# Total elements of EN_NACOM_NAIP_DV: 0 in 0 pages
# Total elements of EN_ADAP_COM_DV: 0 in 0 pages
# Total elements of EN_NAD_CONTR_DV: 0 in 0 pages
# Total elements of EN_ATM_GHGT_AIP: 792 in 32 pages
# Observations  EN_NAA_PLAN_DV 0
# Observations  EN_ADAP_COM_DV 0
# Observations  EN_NACOM_NAIP_DV 0
# Observations  EN_NAD_CONTR_DV 0
# Observations  EN_ATM_GHGT_AIP 792
# Total elements of EN_NAA_PLAN: 0 in 0 pages
# Total elements of EN_BIUREP_NAIP: 0 in 0 pages
# Total elements of EN_NAD_CONTR: 0 in 0 pages
# Total elements of EN_NACOM_AIP: 0 in 0 pages
# Total elements of EN_ATM_GHGT_NAIP: 126 in 6 pages
# Observations  EN_NAA_PLAN 0
# Observations  EN_BIUREP_NAIP 0
# Observations  EN_NAD_CONTR 0
# Observations  EN_NACOM_AIP 0
# Observations  EN_ATM_GHGT_NAIP 126
# Total elements of DC_FIN_CLIMT: 0 in 0 pages
# Total elements of EN_ADAP_COM: 0 in 0 pages
# Total elements of EN_NACOM_NAIP: 0 in 0 pages
# Total elements of EN_BIUREP_AIP: 0 in 0 pages
# Total elements of DC_FIN_CLIMB: 0 in 0 pages
# Observations  DC_FIN_CLIMT 0
# Observations  EN_NACOM_NAIP 0
# Observations  EN_ADAP_COM 0
# Observations  EN_BIUREP_AIP 0
# Observations  DC_FIN_CLIMB 0
# Total elements of DC_FIN_TOT: 0 in 0 pages
# Total elements of DC_FIN_CLIMM: 0 in 0 pages
# Total elements of DC_FIN_GEN: 0 in 0 pages
# Observations  DC_FIN_TOT 0
# Observations  DC_FIN_GEN 0
# Observations  DC_FIN_CLIMM 0
# Collect data : 0.3020585497220357 minutes
# Data/2.UN_observations/observations13.json created
# Goal 14
# Total elements of ER_UNCLOS_IMPLE: 27 in 2 pages
# Total elements of ER_UNCLOS_RATACC: 27 in 2 pages
# Total elements of ER_H2O_FWTL: 312 in 13 pages
# Total elements of EN_MAR_BEALIT_EXP: 174 in 7 pages
# Total elements of EN_MAR_TP_MML: 1900 in 76 pages
# Observations  ER_UNCLOS_IMPLE 26
# Observations  ER_UNCLOS_RATACC 27
# Observations  EN_MAR_BEALIT_EXP 174
# Observations  ER_H2O_FWTL 40
# Observations  EN_MAR_TP_MML 1900
# Total elements of EN_MAR_TN: 0 in 0 pages
# Total elements of EN_MAR_BEALIT_PUSA: 246 in 10 pages
# Total elements of EN_MAR_BEALIT_OP: 145 in 6 pages
# Total elements of EN_MAR_CHLDEV: 602 in 25 pages
# Total elements of EN_MAR_TN_MML: 1885 in 76 pages
# Observations  EN_MAR_TN 0
# Observations  EN_MAR_BEALIT_OP 145
# Observations  EN_MAR_BEALIT_PUSA 246
# Observations  EN_MAR_CHLDEV 602
# Observations  EN_MAR_TN_MML 1885
# Total elements of EN_MAR_TP: 0 in 0 pages
# Total elements of EN_MAR_PLASDD: 10 in 1 pages
# Total elements of EN_MAR_COEUPO: 0 in 0 pages
# Total elements of EN_MAR_DSI_MML: 9 in 1 pages
# Total elements of EN_MAR_CHLCONC: 12 in 1 pages
# Observations  EN_MAR_TP 0
# Observations  EN_MAR_PLASDD 10
# Observations  EN_MAR_COEUPO 0
# Observations  EN_MAR_DSI_MML 9
# Observations  EN_MAR_CHLCONC 12
# Total elements of EN_MAR_DSI: 0 in 0 pages
# Total elements of EN_MAR_BEALIT_OV: 145 in 6 pages
# Total elements of EN_MAR_BEALIT_BP: 145 in 6 pages
# Total elements of EN_MAR_CHLANM: 507 in 21 pages
# Total elements of EN_MAR_BEALIT_BV: 3012 in 121 pages
# Observations  EN_MAR_DSI 0
# Observations  EN_MAR_BEALIT_OV 145
# Observations  EN_MAR_BEALIT_BP 145
# Observations  EN_MAR_CHLANM 507
# Observations  EN_MAR_BEALIT_BV 3012
# Total elements of ER_RDE_OSEX: 65 in 3 pages
# Total elements of ER_REG_SSFRAR: 168 in 7 pages
# Total elements of ER_REG_UNFCIM: 168 in 7 pages
# Total elements of EN_SCP_FSHGDP: 189 in 8 pages
# Total elements of ER_OAW_MNACD: 857 in 35 pages
# Observations  ER_RDE_OSEX 65
# Observations  ER_REG_UNFCIM 131
# Observations  ER_REG_SSFRAR 128
# Observations  EN_SCP_FSHGDP 151
# Observations  ER_OAW_MNACD 857
# Total elements of ER_MRN_MPA: 1200 in 48 pages
# Total elements of EN_SCP_ECSYBA: 81 in 4 pages
# Observations  EN_SCP_ECSYBA 81
# Observations  ER_MRN_MPA 875
# Collect data : 0.5879722038904825 minutes
# Data/2.UN_observations/observations14.json created
# Goal 15
# Total elements of ER_IAS_NBSAPP: 0 in 0 pages
# Total elements of ER_IAS_GLOFUNP: 0 in 0 pages
# Observations  ER_IAS_NBSAPP 0
# Observations  ER_IAS_GLOFUNP 0
# Total elements of ER_IAS_NATBUD: 93 in 4 pages
# Total elements of ER_IAS_NBSAP: 132 in 6 pages
# Total elements of ER_IAS_LEGIS: 176 in 8 pages
# Observations  ER_IAS_NATBUD 91
# Observations  ER_IAS_NBSAP 132
# Observations  ER_IAS_LEGIS 176
# Total elements of ER_IAS_NATBUDP: 0 in 0 pages
# Total elements of DC_ODA_BDVL: 340 in 14 pages
# Total elements of DC_ODA_BDVDL: 878 in 36 pages
# Total elements of ER_IAS_GLOFUN: 93 in 4 pages
# Total elements of ER_WLD_TRPOACH: 712 in 29 pages
# Observations  ER_IAS_NATBUDP 0
# ...
# Total elements of ER_CBD_ORSPGRFA: 468 in 19 pages
# Total elements of ER_CBD_SMTA: 676 in 28 pages
# Total elements of ER_RSK_LST: 1664 in 67 pages
# Observations  ER_CBD_ABSCLRHS 207
# Observations  ER_CBD_NAGOYA 179
# Observations  ER_CBD_ORSPGRFA 468
# Observations  ER_CBD_SMTA 676
# Observations  ER_RSK_LST 1664
# Total elements of AG_LND_DGRD: 56 in 3 pages
# Total elements of ER_CBD_PTYPGRFA: 676 in 28 pages
# Total elements of AG_LND_FRSTCHG: 102 in 5 pages
# Total elements of AG_LND_FRSTMGT: 336 in 14 pages
# Total elements of AG_LND_FRSTBIOPHA: 360 in 15 pages
# Observations  AG_LND_DGRD 39
# Observations  AG_LND_FRSTCHG 94
# Observations  AG_LND_FRSTMGT 255
# Observations  AG_LND_FRSTBIOPHA 360
# Observations  ER_CBD_PTYPGRFA 676
# Total elements of AG_LND_FRSTCERT: 624 in 25 pages
# Total elements of AG_LND_FRSTPRCT: 352 in 15 pages
# Total elements of ER_MTN_DGRDA: 514 in 21 pages
# Total elements of ER_MTN_TOTL: 1542 in 62 pages
# Total elements of ER_MTN_GRNCOV: 16962 in 679 pages
# Observations  AG_LND_FRSTPRCT 272
# Observations  ER_MTN_DGRDA 234
# Observations  AG_LND_FRSTCERT 624
# Observations  ER_MTN_TOTL 702
# Observations  ER_MTN_GRNCOV 7722
# Total elements of ER_MTN_GRNCVI: 16962 in 679 pages
# Total elements of AG_LND_FRSTN: 408 in 17 pages
# Total elements of AG_LND_FRST: 408 in 17 pages
# Total elements of ER_MTN_DGRDP: 514 in 21 pages
# Total elements of ER_PTD_MTN: 1200 in 48 pages
# Observations  AG_LND_FRSTN 408
# Observations  AG_LND_FRST 408
# Observations  ER_MTN_DGRDP 234
# Observations  ER_PTD_MTN 925
# Observations  ER_MTN_GRNCVI 7722
# Total elements of AG_LND_TOTL: 416 in 17 pages
# Total elements of ER_BDY_ABT2NP: 88 in 4 pages
# Total elements of ER_BDY_SEEA: 78 in 4 pages
# Total elements of ER_PTD_TERR: 1200 in 48 pages
# Total elements of ER_PTD_FRHWTR: 1200 in 48 pages
# Observations  ER_BDY_SEEA 78
# Observations  ER_BDY_ABT2NP 88
# Observations  AG_LND_TOTL 416
# Observations  ER_PTD_TERR 1200
# Observations  ER_PTD_FRHWTR 1000
# Collect data : 2.1757370829582214 minutes
# Data/2.UN_observations/observations15.json created
# Goal 16
# Total elements of SP_DISP_RESOL: 0 in 0 pages
# Total elements of VC_PRR_PSYCHV: 3 in 1 pages
# Total elements of VC_PRR_PHY_VIO: 18 in 1 pages
# Total elements of VC_PRR_ROBB: 78 in 4 pages
# Total elements of VC_PRR_SEXV: 55 in 3 pages
# Observations  VC_PRR_PSYCHV 3
# Observations  SP_DISP_RESOL 0
# Observations  VC_PRR_PHY_VIO 18
# Observations  VC_PRR_SEXV 55
# Observations  VC_PRR_ROBB 78
# Total elements of DI_ILL_IN: 0 in 0 pages
# Total elements of VC_PRR_SEX_VIO: 13 in 1 pages
# Total elements of VC_PRR_PHYV: 90 in 4 pages
# Total elements of VC_PRS_UNSNT: 1538 in 62 pages
# Observations  DI_ILL_IN 0
# Observations  VC_PRR_SEX_VIO 13
# Total elements of VC_VOV_GDSD: 3412 in 137 pages
# Observations  VC_PRR_PHYV 90
# Observations  VC_PRS_UNSNT 1538
# Observations  VC_VOV_GDSD 3412
# Total elements of DI_ILL_OUT: 0 in 0 pages
# Total elements of VC_ARM_SZTRACE: 49 in 2 pages
# Total elements of SG_DMK_PARLYN_UC: 82 in 4 pages
# Total elements of SG_DMK_PARLSP_UC: 86 in 4 pages
# Total elements of SG_DMK_PARLYR_UC: 79 in 4 pages
# Observations  DI_ILL_OUT 0
# Observations  VC_ARM_SZTRACE 49
# Observations  SG_DMK_PARLSP_UC 85
# Observations  SG_DMK_PARLYN_UC 82
# Observations  SG_DMK_PARLYR_UC 79
# Total elements of SG_DMK_PARLYR_LC: 201 in 9 pages
# Total elements of SG_DMK_PARLCC_LC: 1054 in 43 pages
# Total elements of SG_DMK_JDC_LWR: 642 in 26 pages
# Total elements of SG_DMK_JDC_HGR: 606 in 25 pages
# Total elements of SG_DMK_JDC: 755 in 31 pages
# Observations  SG_DMK_PARLYR_LC 201
# Observations  SG_DMK_JDC_HGR 606
# Observations  SG_DMK_JDC_LWR 642
# Observations  SG_DMK_JDC 755
# Observations  SG_DMK_PARLCC_LC 1054
# Total elements of SG_DMK_PARLYP_LC: 213 in 9 pages
# Total elements of SG_DMK_PARLYP_UC: 82 in 4 pages
# Total elements of SG_DMK_PARLCC_JC: 33 in 2 pages
# Total elements of SG_DMK_PARLCC_UC: 358 in 15 pages
# Total elements of SG_DMK_JDC_CNS: 554 in 23 pages
# Observations  SG_DMK_PARLCC_JC 33
# Observations  SG_DMK_PARLYP_UC 82
# Observations  SG_DMK_PARLYP_LC 213
# Observations  SG_DMK_PARLCC_UC 358
# Observations  SG_DMK_JDC_CNS 554
# Total elements of SG_DMK_PARLMP_UC: 81 in 4 pages
# Total elements of SG_DMK_PARLMP_LC: 207 in 9 pages
# Total elements of SG_DMK_PARLYN_LC: 213 in 9 pages
# Total elements of SG_DMK_PARLSP_LC: 227 in 10 pages
# Total elements of SG_DMK_PSRVC: 1171 in 47 pages
# Observations  SG_DMK_PARLMP_UC 81
# Observations  SG_DMK_PARLMP_LC 207
# Observations  SG_DMK_PARLYN_LC 213
# Observations  SG_DMK_PARLSP_LC 227
# Observations  SG_DMK_PSRVC 1171
# Total elements of SG_INT_VRTDEV: 6566 in 263 pages
# Total elements of SG_INT_MBRDEV: 6566 in 263 pages
# Total elements of IU_DMK_INCL: 221 in 9 pages
# Total elements of IU_DMK_RESP: 89 in 4 pages
# Total elements of IU_DMK_ICRS: 38 in 2 pages
# Observations  IU_DMK_ICRS 38
# Observations  IU_DMK_RESP 89
# Observations  IU_DMK_INCL 221
# Observations  SG_INT_VRTDEV 6566
# Observations  SG_INT_MBRDEV 6566
# Total elements of VC_DTH_TONCVN: 0 in 0 pages
# Total elements of VC_SNS_WALN_DRK: 207 in 9 pages
# Observations  VC_DTH_TONCVN 0
# Total elements of VC_DTH_TOUNN: 0 in 0 pages
# Total elements of VC_DTH_TOTPT: 0 in 0 pages
# Total elements of VC_DTH_TOTN: 190 in 8 pages
# Observations  VC_DTH_TOUNN 0
# Observations  VC_DTH_TOTPT 0
# Observations  VC_SNS_WALN_DRK 207
# Observations  VC_DTH_TOTN 190
# Total elements of VC_VOV_SEXL: 61 in 3 pages
# Total elements of VC_DTH_TOCVN: 10 in 1 pages
# Total elements of VC_IHR_PSRCN: 3530 in 142 pages
# Total elements of VC_DTH_TOTR: 10 in 1 pages
# Total elements of VC_IHR_PSRC: 2716 in 109 pages
# Observations  VC_DTH_TOCVN 10
# Observations  VC_DTH_TOTR 10
# Observations  VC_VOV_SEXL 61
# Observations  VC_IHR_PSRC 2716
# Observations  VC_IHR_PSRCN 3530
# Total elements of VC_VOV_PHYL: 59 in 3 pages
# Total elements of VC_VOV_PHY_ASLT: 190 in 8 pages
# Total elements of VC_VOV_ROBB: 245 in 10 pages
# Total elements of VC_VOV_PSYCHL: 52 in 3 pages
# Total elements of VC_VOV_SEX_ASLT: 210 in 9 pages
# Observations  VC_VOV_PHYL 59
# Observations  VC_VOV_PSYCHL 52
# Observations  VC_VOV_PHY_ASLT 190
# Observations  VC_VOV_SEX_ASLT 210
# Observations  VC_VOV_ROBB 245
# Total elements of VC_VAW_PHYPYV: 8 in 1 pages
# Total elements of VC_VAW_SXVLN: 9 in 1 pages
# Total elements of VC_HTF_DETVSXR: 1981 in 80 pages
# Total elements of VC_HTF_DETVFLR: 1826 in 74 pages
# Total elements of VC_HTF_DETV: 5311 in 213 pages
# Observations  VC_VAW_PHYPYV 8
# Observations  VC_VAW_SXVLN 9
# Observations  VC_HTF_DETVFLR 849
# Observations  VC_HTF_DETVSXR 1135
# Observations  VC_HTF_DETV 3629
# Total elements of VC_HTF_DETVFL: 1826 in 74 pages
# Total elements of VC_HTF_DETVOGR: 1107 in 45 pages
# Total elements of VC_HTF_DETVSX: 1981 in 80 pages
# Total elements of VC_HTF_DETVOPR: 1745 in 70 pages
# Total elements of VC_HTF_DETVOP: 1745 in 70 pages
# Observations  VC_HTF_DETVOGR 18
# Observations  VC_HTF_DETVFL 852
# Observations  VC_HTF_DETVOP 678
# Observations  VC_HTF_DETVOPR 676
# Observations  VC_HTF_DETVSX 1146
# Total elements of SG_REG_BRTH: 79 in 4 pages
# Total elements of SG_NHR_CMPLNC: 572 in 23 pages
# Total elements of SG_NHR_IMPL: 572 in 23 pages
# Total elements of VC_HTF_DETVOG: 1107 in 45 pages
# Total elements of VC_HTF_DETVR: 5311 in 213 pages
# Observations  SG_REG_BRTH 79
# Observations  SG_NHR_IMPL 572
# Observations  SG_NHR_CMPLNC 572
# Observations  VC_HTF_DETVOG 18
# Observations  VC_HTF_DETVR 3604
# Total elements of SG_INF_ACCSS: 44 in 2 pages
# Total elements of VC_VOC_ENFDIS: 0 in 0 pages
# Total elements of VC_VAW_MTUHRA: 0 in 0 pages
# Total elements of VC_VOC_ENFDISN: 88 in 4 pages
# Total elements of VC_VAW_MTUHRAN: 88 in 4 pages
# Observations  VC_VOC_ENFDIS 0
# Observations  VC_VAW_MTUHRA 0
# Observations  SG_INF_ACCSS 44
# Observations  VC_VOC_ENFDISN 41
# Observations  VC_VAW_MTUHRAN 42
# Total elements of IU_COR_BRIB: 115 in 5 pages
# Total elements of IC_FRM_BRIB: 93 in 4 pages
# Total elements of GF_XPD_GBPC: 492 in 20 pages
# Total elements of SP_PSR_SATIS_HLTH: 25 in 1 pages
# Total elements of SP_PSR_SATIS_PRM: 30 in 2 pages
# Observations  IC_FRM_BRIB 93
# Observations  IU_COR_BRIB 115
# Observations  SP_PSR_SATIS_HLTH 25
# Observations  SP_PSR_SATIS_PRM 30
# Observations  GF_XPD_GBPC 492
# Total elements of SP_PSR_OSATIS_GOV: 141 in 6 pages
# Total elements of SP_PSR_OSATIS_PRM: 25 in 1 pages
# Total elements of SP_PSR_OSATIS_SEC: 125 in 5 pages
# Total elements of SP_PSR_SATIS_SEC: 30 in 2 pages
# Total elements of SP_PSR_SATIS_GOV: 293 in 12 pages
# Observations  SP_PSR_OSATIS_PRM 25
# Observations  SP_PSR_SATIS_SEC 30
# Observations  SP_PSR_OSATIS_GOV 141
# Observations  SP_PSR_OSATIS_SEC 125
# Observations  SP_PSR_SATIS_GOV 293
# Total elements of SP_PSR_OSATIS_HLTH: 326 in 14 pages
# Observations  SP_PSR_OSATIS_HLTH 326
# Collect data : 1.7623663385709127 minutes
# Data/2.UN_observations/observations16.json created
# Goal 17
# Total elements of DT_TDS_DECT: 178 in 8 pages
# Total elements of TX_IMP_GBMRCH: 1016 in 41 pages
# Total elements of TX_IMP_GBSVR: 963 in 39 pages
# Total elements of TX_EXP_GBMRCH: 1016 in 41 pages
# Total elements of IT_USE_ii99: 2529 in 102 pages
# Observations  DT_TDS_DECT 178
# Observations  TX_IMP_GBSVR 963
# Observations  TX_EXP_GBMRCH 1016
# Observations  TX_IMP_GBMRCH 1016
# Observations  IT_USE_ii99 2529
# Total elements of SG_PLN_MSTKSDG_R: 7 in 1 pages
# Total elements of SG_PLN_MSTKSDG_P: 23 in 1 pages
# Total elements of TX_EXP_GBSVR: 960 in 39 pages
# Total elements of SG_STT_NSDSFDDNR: 312 in 13 pages
# Total elements of SG_STT_NSDSFND: 312 in 13 pages
# Observations  SG_PLN_MSTKSDG_R 7
# Observations  SG_PLN_MSTKSDG_P 23
# Observations  SG_STT_NSDSFDDNR 42
# Observations  SG_STT_NSDSFND 237
# Observations  TX_EXP_GBSVR 960
# Total elements of SG_STT_NSDSIMPL: 312 in 13 pages
# Total elements of SG_STT_NSDSFDOTHR: 312 in 13 pages
# Total elements of SG_STT_FPOS: 312 in 13 pages
# Total elements of SG_STT_NSDSFDGVT: 312 in 13 pages
# Total elements of IQ_SPI_PIL4: 376 in 16 pages
# Observations  IQ_SPI_PIL4 322
# Observations  SG_STT_NSDSFDGVT 222
# Observations  SG_STT_FPOS 254
# Observations  SG_STT_NSDSIMPL 246
# Observations  SG_STT_NSDSFDOTHR 44
# Total elements of SG_STT_ODIN: 86 in 4 pages
# Total elements of IQ_SPI_PIL5: 376 in 16 pages
# Total elements of BX_TRF_PWKR: 1011 in 41 pages
# Total elements of SG_CPA_SDEVP: 23 in 1 pages
# Total elements of DC_OSSD_MPF: 60 in 3 pages
# Observations  SG_CPA_SDEVP 23
# Observations  DC_OSSD_MPF 60
# Observations  SG_STT_ODIN 86
# Observations  IQ_SPI_PIL5 331
# Observations  BX_TRF_PWKR 1011
# Total elements of DC_OSSD_PRVGRT: 46 in 2 pages
# Total elements of DC_OSSD_OFFNL: 40 in 2 pages
# Total elements of DC_OSSD_OFFCL: 40 in 2 pages
# Total elements of DC_OSSD_GRT: 40 in 2 pages
# Total elements of GF_FRN_FDI: 1286 in 52 pages
# Observations  DC_OSSD_PRVGRT 46
# Observations  DC_OSSD_OFFNL 40
# Observations  DC_OSSD_OFFCL 40
# Observations  DC_OSSD_GRT 40
# Observations  GF_FRN_FDI 1286
# Total elements of SG_PLN_RECNDI: 9 in 1 pages
# Total elements of SG_PLN_RECRIMON: 9 in 1 pages
# Total elements of SG_PLN_PRVNDI: 42 in 2 pages
# Total elements of DC_FTA_TOTAL: 197 in 8 pages
# Total elements of SG_PLN_PRVRIMON: 42 in 2 pages
# Observations  SG_PLN_RECNDI 9
# Observations  SG_PLN_RECRIMON 9
# Observations  SG_PLN_PRVNDI 42
# Observations  SG_PLN_PRVRIMON 42
# Observations  DC_FTA_TOTAL 197
# Total elements of SG_PLN_RECRICTRY: 9 in 1 pages
# Total elements of SG_PLN_REPOLRES: 9 in 1 pages
# Total elements of SG_PLN_PRPOLRES: 42 in 2 pages
# Total elements of SG_PLN_PRVRICTRY: 42 in 2 pages
# Total elements of GC_GOB_TAXD: 905 in 37 pages
# Observations  SG_PLN_RECRICTRY 9
# Observations  SG_PLN_REPOLRES 9
# Observations  SG_PLN_PRPOLRES 42
# Observations  SG_PLN_PRVRICTRY 42
# Observations  GC_GOB_TAXD 905
# Total elements of GF_COM_PPPI_KD: 225 in 9 pages
# Total elements of GF_COM_PPPI: 230 in 10 pages
# Total elements of FB_BNK_CAPA_ZS: 602 in 25 pages
# Total elements of GR_G14_GDP: 916 in 37 pages
# Total elements of GR_G14_XDC: 916 in 37 pages
# Observations  GF_COM_PPPI 230
# Observations  GF_COM_PPPI_KD 225
# Observations  FB_BNK_CAPA_ZS 602
# Observations  GR_G14_XDC 916
# Observations  GR_G14_GDP 916
# Total elements of FM_LBL_BMNY_ZG: 463 in 19 pages
# Total elements of NE_CON_GOVT_KD_ZG: 958 in 39 pages
# Total elements of GC_TAX_TOTL_GD_ZS: 883 in 36 pages
# Total elements of NE_GDI_TOTL_KD_ZG: 958 in 39 pages
# Total elements of NY_GDP_MKTP_KD_ZG: 1078 in 44 pages
# Observations  FM_LBL_BMNY_ZG 463
# Observations  NY_GDP_MKTP_KD_ZG 1078
# Observations  GC_TAX_TOTL_GD_ZS 883
# Observations  NE_CON_GOVT_KD_ZG 958
# Observations  NE_GDI_TOTL_KD_ZG 958
# Total elements of GC_BAL_CASH_GD_ZS: 880 in 36 pages
# Total elements of BN_CAB_XOKA_GD_ZS: 956 in 39 pages
# Total elements of BX_KLT_DINV_WD_GD_ZS: 963 in 39 pages
# Total elements of DP_DOD_DLD2_CR_CG_Z1: 726 in 30 pages
# Total elements of FM_LBL_BMNY_IR_ZS: 454 in 19 pages
# Observations  FM_LBL_BMNY_IR_ZS 454
# Observations  GC_BAL_CASH_GD_ZS 880
# Observations  DP_DOD_DLD2_CR_CG_Z1 726
# Observations  BN_CAB_XOKA_GD_ZS 956
# Observations  BX_KLT_DINV_WD_GD_ZS 963
# Total elements of BN_KLT_PTXL_CD: 938 in 38 pages
# Total elements of FP_CPI_TOTL_ZG: 960 in 39 pages
# Total elements of NE_IMP_GNFS_KD_ZG: 957 in 39 pages
# Total elements of NE_EXP_GNFS_KD_ZG: 957 in 39 pages
# Total elements of PA_NUS_ATLS: 1103 in 45 pages
# Observations  NE_EXP_GNFS_KD_ZG 957
# Observations  BN_KLT_PTXL_CD 938
# Observations  FP_CPI_TOTL_ZG 960
# Observations  PA_NUS_ATLS 1103
# Observations  NE_IMP_GNFS_KD_ZG 957
# Total elements of DT_DOD_DECT_GN_ZS: 186 in 8 pages
# Total elements of NE_CON_PRVT_KD_ZG: 958 in 39 pages
# Total elements of FI_RES_TOTL_MO: 940 in 38 pages
# Total elements of TG_VAL_TOTL_GD_ZS: 975 in 39 pages
# Total elements of TM_TAX_DPRF: 4448 in 178 pages
# Observations  DT_DOD_DECT_GN_ZS 186
# Observations  NE_CON_PRVT_KD_ZG 958
# Observations  FI_RES_TOTL_MO 940
# Observations  TG_VAL_TOTL_GD_ZS 975
# Observations  TM_TAX_DPRF 4448
# Total elements of DC_ENVTECH_TT: 438 in 18 pages
# Total elements of TM_TAX_DMFN: 4448 in 178 pages
# Total elements of SG_CPA_OFDI: 180 in 8 pages
# Total elements of TM_TAX_WMPS: 834 in 34 pages
# Total elements of TM_TAX_WMFN: 834 in 34 pages
# Observations  SG_CPA_OFDI 180
# Observations  DC_ENVTECH_TT 438
# Observations  TM_TAX_WMFN 834
# Observations  TM_TAX_WMPS 834
# Observations  TM_TAX_DMFN 4448
# Total elements of DC_ENVTECH_REXP: 55 in 3 pages
# Total elements of DC_ENVTECH_EXP: 438 in 18 pages
# Total elements of DC_ENVTECH_RIMP: 107 in 5 pages
# Total elements of DC_ENVTECH_IMP: 438 in 18 pages
# Total elements of DC_ENVTECH_INV: 162 in 7 pages
# Observations  DC_ENVTECH_REXP 55
# Observations  DC_ENVTECH_RIMP 107
# Observations  DC_ENVTECH_INV 162
# Observations  DC_ENVTECH_EXP 438
# Observations  DC_ENVTECH_IMP 438
# Total elements of DC_ODA_SIDSG: 689 in 28 pages
# Total elements of DC_ODA_TOTLGE: 230 in 10 pages
# Total elements of DC_ODA_TOTG: 511 in 21 pages
# Total elements of IT_NET_BBNDN: 2904 in 117 pages
# Total elements of IT_NET_BBND: 2904 in 117 pages
# Observations  DC_ODA_TOTLGE 230
# Observations  DC_ODA_TOTG 511
# Observations  DC_ODA_SIDSG 689
# Observations  IT_NET_BBND 2904
# Observations  IT_NET_BBNDN 2904
# Total elements of DC_ODA_LLDCG: 692 in 28 pages
# Total elements of DC_ODA_LDCG: 692 in 28 pages
# Total elements of DC_ODA_TOTGGE: 222 in 9 pages
# Total elements of DC_ODA_LLDC: 746 in 30 pages
# Total elements of DC_ODA_LDCS: 746 in 30 pages
# Observations  DC_ODA_TOTGGE 222
# Observations  DC_ODA_LDCG 692
# Observations  DC_ODA_LLDCG 692
# Observations  DC_ODA_LDCS 746
# Observations  DC_ODA_LLDC 746
# Total elements of SG_REG_CENSUS: 0 in 0 pages
# Total elements of SG_STT_CAPTY: 117 in 5 pages
# Total elements of SG_REG_CENSUSN: 49 in 2 pages
# Total elements of DC_ODA_TOTL: 750 in 30 pages
# Total elements of DC_ODA_SIDS: 743 in 30 pages
# Observations  SG_REG_CENSUS 0
# Observations  SG_REG_CENSUSN 49
# Observations  SG_STT_CAPTY 103
# Observations  DC_ODA_TOTL 750
# Observations  DC_ODA_SIDS 743
# Total elements of SG_REG_BRTH90: 0 in 0 pages
# Total elements of SG_REG_DETH75: 0 in 0 pages
# Total elements of SG_REG_DETH75N: 358 in 15 pages
# Total elements of SG_REG_BRTH90N: 358 in 15 pages
# Observations  SG_REG_BRTH90 0
# Observations  SG_REG_DETH75 0
# Observations  SG_REG_DETH75N 358
# Observations  SG_REG_BRTH90N 358
# Collect data : 1.2887897650400797 minutes
# Data/2.UN_observations/observations17.json created

# %%
now = datetime.now()
print("API was last accessed at:", now)
# Out:
# API was last accessed at: 2025-09-17 18:12:56.337272

# %% [markdown]
# ### Import data  to the SustainGraph using the json file per goal

# %%
def write_obs(tx,statement, params):
    result = tx.run(statement,parameters={"parameters":params})
    return result.data()[0]['total']

# %%
statement = """ 
    UNWIND $parameters as row
    MATCH (ga:GeoArea),(s:Series{code:row.s_code})
    WHERE row.geo = ga.M49code
    MATCH (src:Source{name:'UN_SDG'})-[:COMES_FROM]-(i:Indicator)-[:HAS_SERIES]->(s)
    MERGE (s)-[:HAS_METADATA]->(sm:SeriesMetadata{attributesCode:row.att_codes,attributesDescription:row.att_desc,
                            dimensionsCode:row.dim_codes,dimensionsDescription:row.dim_desc,seriesCode:row.s_code})
    MERGE (sm)-[:HAS_OBSERVATION{attributesCode:row.att_codes,dimensionsCode:row.dim_codes,
                                seriesCode:row.s_code,time:date(row.year),
                                geoCode:row.geo}]->(o:Observation{time:date(row.year)})
    SET o.value = toFloat(row.value)
    MERGE (o)-[:REFERS_TO_AREA]->(ga)
    MERGE (i) -[:HAS_OBSERVATIONS]->(ga)
    RETURN COUNT(DISTINCT o) as total
"""

total_start = time.time()

for goal in range(1,18):
    print("Goal ", goal)
    f = open(os.getcwd()+'\\Data\\2.UN_observations\\observations'+str(goal)+'.json')
    dataToImport = json.load(f)
    print("Start importing to neo4j")
    st = time.time()
    with driver.session(database=database_name) as session:
        for p in dataToImport:
            results = session.execute_write(write_obs,statement, p)
            et = time.time()

    elapsed_time = et - st
    print('Import data :', elapsed_time/60, 'minutes')

total_end = time.time()
total_elapsed = total_end - total_start
print('Total import time: ', total_elapsed/60, 'minutes')
# Out:
# Goal  1
# Start importing to neo4j
# <>:35: SyntaxWarning: invalid escape sequence '\T'
# <>:35: SyntaxWarning: invalid escape sequence '\T'
# C:\Users\Eleftheria\AppData\Local\Temp\ipykernel_10208\2382416835.py:35: SyntaxWarning: invalid escape sequence '\T'
#   print('\Total import time: ', total_elapsed/60, 'minutes')
# Import data : 0.487278946240743 minutes
# Goal  2
# Start importing to neo4j
# Import data : 0.39811888535817463 minutes
# Goal  3
# Start importing to neo4j
# Import data : 0.6892135620117188 minutes
# Goal  4
# Start importing to neo4j
# Import data : 1.8750510255495707 minutes
# Goal  5
# Start importing to neo4j
# Import data : 0.16781112353007 minutes
# Goal  6
# Start importing to neo4j
# Import data : 0.4870819807052612 minutes
# Goal  7
# Start importing to neo4j
# Import data : 0.37057942946751915 minutes
# Goal  8
# Start importing to neo4j
# Import data : 2.437811227639516 minutes
# Goal  9
# Start importing to neo4j
# Import data : 0.24255380630493165 minutes
# Goal  10
# Start importing to neo4j
# Import data : 0.5163045287132263 minutes
# Goal  11
# Start importing to neo4j
# Import data : 0.4132896264394124 minutes
# Goal  12
# Start importing to neo4j
# Import data : 2.356424033641815 minutes
# Goal  13
# Start importing to neo4j
# Import data : 0.20491911172866822 minutes
# Goal  14
# Start importing to neo4j
# Import data : 0.201362939675649 minutes
# Goal  15
# Start importing to neo4j
# Import data : 0.5361886421839396 minutes
# Goal  16
# Start importing to neo4j
# Import data : 0.8667204658190409 minutes
# Goal  17
# Start importing to neo4j
# Import data : 1.0440929770469665 minutes
# \Total import time:  13.35949825445811 minutes

# %% [markdown]
# > Check cypher query

# %% [markdown]
# Checking for observations that weren't imported properly to the graph ('mismatches' between graph and json files from UN database)

# %%
statement = """
UNWIND $parameters AS row
MATCH (sm:SeriesMetadata {
    attributesCode: row.att_codes,
    dimensionsCode: row.dim_codes,
    seriesCode: row.s_code
})-[:HAS_OBSERVATION {
    attributesCode: row.att_codes,
    dimensionsCode: row.dim_codes,
    seriesCode: row.s_code,
    geoCode: row.geo,
    time: date(row.year)
}]->(o:Observation)
RETURN count((o)) AS total
"""

check_data_un = []

for goal in range(1, 18):
    with open(os.path.join(os.getcwd()+'\\Data\\2.UN_observations\\observations'+str(goal)+'.json')) as f:
        dataToImport = json.load(f)

    with driver.session(database=database_name) as session:
        for p in dataToImport:
            expected_count = len(p)
            results = session.execute_write(write_obs, statement, p)

            if (len(p)!=0): #not empty observations
                first_entry = p[0]
                s_code = first_entry['s_code']
                att_code = first_entry['att_codes']
                dim_code = first_entry['dim_codes']
                indicator_code = first_entry["indicator"]

                check_data_un.append({
                    "indicator": indicator_code,
                    "series": s_code,
                    "dim_code": dim_code,
                    "att_code": att_code,
                    "seriesmetadata": f"{dim_code}|{att_code}",
                    "to_import": expected_count,
                    "imported": results
                })

check_df_un = pd.DataFrame(check_data_un)

# %%
check_df_un
# Out:
#     indicator          series        dim_code     att_code  \
# 0       1.3.1  SI_COV_WKINJRY   15+|BOTHSEX|G  E|PERCENT|A
# 1       1.3.1     SI_COV_CHLD  <15Y|BOTHSEX|G  E|PERCENT|A
# 2       1.3.1    SI_COV_MATNL  15-49|FEMALE|G  E|PERCENT|A
# 3       1.3.1   SI_COV_SOCINS            G|_T   CA|PERCENT
# 4       1.3.1    SI_COV_DISAB       BOTHSEX|G  E|PERCENT|A
# ..        ...             ...             ...          ...
# 688    17.2.1     DC_ODA_SIDS               G  C|CON_USD_M
# 689   17.19.1    SG_STT_CAPTY               G     G|CU_USD
# 690   17.19.2  SG_REG_CENSUSN               G     C|NUMBER
# 691   17.19.2  SG_REG_DETH75N               G     C|NUMBER
# 692   17.19.2  SG_REG_BRTH90N               G     C|NUMBER
#
#                  seriesmetadata  to_import  imported
# 0     15+|BOTHSEX|G|E|PERCENT|A        152       152
# 1    <15Y|BOTHSEX|G|E|PERCENT|A        277       277
# 2    15-49|FEMALE|G|E|PERCENT|A        135       135
# 3               G|_T|CA|PERCENT        160       160
# 4         BOTHSEX|G|E|PERCENT|A        587       587
# ..                          ...        ...       ...
# 688               G|C|CON_USD_M        743       743
# 689                  G|G|CU_USD        103       103
# 690                  G|C|NUMBER         49        49
# 691                  G|C|NUMBER        358       358
# 692                  G|C|NUMBER        358       358
#
# [693 rows x 7 columns]

# %%
total_observations_imported = check_df_un['imported'].sum()
total_observations_to_import = check_df_un['to_import'].sum()
print("Total UN SDG observations imported in SustainGraph", total_observations_imported, ", expected:",total_observations_to_import)

mismatches = check_df_un[check_df_un['to_import'] != check_df_un['imported']]
if len(mismatches)==0:
    print("Mismatches: 0")
else:
    print("\nMismatches:\n", mismatches)
# Out:
# Total UN SDG observations imported in SustainGraph  834104 , expected: 834104
# Mismatches: 0
